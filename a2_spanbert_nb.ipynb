# %%
from util import load_pickle
from a2_spanbert import load_csv, NERResult, load_entry
extracted_entities = load_pickle("extracted_entities.pickle")
dataset = load_csv()

# %%
dataset.iloc[0]
# Out:
# Unnamed: 0                                                    0
# sample_id                                                108809
# raw           Admission Date:  [**2112-10-6**]              ...
# annotated     T1\tDrug 19078 19085\tAspirin\nT2\tStrength 19...
# Name: 0, dtype: object

# %%
def clean_entities(entities,thresh=0.8):
    return [term for term, scores in entities if scores.mean() > thresh]

drugs_entities_dict = {sample_id: ner_result.drugs for sample_id, ner_result in extracted_entities.items()}
advs_entities_dict = {sample_id: ner_result.advs for sample_id, ner_result in extracted_entities.items()}

# %%
certain_drug_entities = {sample_id : clean_entities(drug_entities,thresh=0.95) for sample_id, drug_entities in drugs_entities_dict.items()}
certain_adv_entities = {sample_id : clean_entities(adv_entities,thresh=0.95) for sample_id, adv_entities in advs_entities_dict.items()}

# %%
certain_drug_entities
# Out:
# {108809: ['ativan',
#   'iv',
#   'ativan',
#   'ativan',
#   'omeprazole',
#   'donnatol',
#   'atorvastatin',
#   'aspirin',
#   'dicyclomine',
#   'aspirin ec',
#   'atorvastatin',
#   'dicyclomine',
#   'omeprazole',
#   'acetaminophen',
#   'butalbital',
#   'butalbital',
#   'acetaminophen',
#   'ciprofloxacin',
#   'ciprofloxacin',
#   'cipro',
#   'metoprolol tartrate',
#   'metoprolol tartrate',
#   'donnatol',
#   'ativan',
#   'aspirin',
#   'aspirin',
#   'tylenol'],
#  115143: ['ibuprofen',
#   'insulin',
#   'dka x 3',
#   'pantoprazole',
#   'insulin lispro',
#   'insulin glargine',
#   'lantus',
#   'humalog insulin',
#   'motrin',
#   'pantoprazole',
#   'motrin'],
#  159079: ['zithromax',
#   'vicodin',
#   'biaxin',
#   'solu - medrol',
#   'dexamethasone',
#   'coccaine',
#   'rass - 3',
#   'baso',
#   'totbili',
#   'req o2 - 56',
#   'cl - 106',
#   'decadron',
#   'omeprazole',
#   'diphenhydramine',
#   'amitriptyline',
#   'amoxicillin',
#   'sulfameth',
#   'trimethoprim d',
#   'fluocinonide',
#   'triamcinolone acetonide',
#   'omeprazole',
#   'oxycodone',
#   'gabapentin',
#   'amitriptyline',
#   'diphenhydramine',
#   'fluocinonide',
#   'oxycodone',
#   'triamcinolone acetonide',
#   'albuterol',
#   'albuterol',
#   'omeprazole',
#   'amoxicillin',
#   'amoxicillin',
#   'gabapentin',
#   'prednisone',
#   'prednisone',
#   'prednisone',
#   'prednisone',
#   'prednisone',
#   'prednisone',
#   'prednisone',
#   'prednisone',
#   'sulfameth',
#   'trimethoprim',
#   'prednisone'],
#  102027: ['afib',
#   'coumadin',
#   'ffp',
#   'coumadin',
#   'insulin',
#   'coumadin',
#   'totbili',
#   'coumadin',
#   'vancomycin',
#   'coumadin',
#   'coumadin',
#   'vancomycin',
#   'levothyroxine',
#   'carvedilol',
#   'vancomycin',
#   'statin',
#   'statin',
#   'lidocaine',
#   'gabapentin',
#   'carvedilol',
#   'asa',
#   'lorazepam',
#   'lisinopril',
#   'percocet 5 - 325',
#   'tramadol',
#   'warfarin',
#   'zolpidem',
#   'bisocodyl',
#   'enulose',
#   'vicadin',
#   'lidoderm',
#   'levothyroxine',
#   'aspirin',
#   'docusate sodium',
#   'senna',
#   'acetaminophen',
#   'zolpidem',
#   'bisacodyl',
#   'lorazepam',
#   'lidocaine',
#   'oxycodone',
#   'guaifenesin',
#   'insulin glargine',
#   'warfarin',
#   'fluticasone',
#   'albuterol sulfate',
#   'gabapentin',
#   'inr 2',
#   'hemodialysis',
#   'inr',
#   'coumadin',
#   'warfarin',
#   'levothyroxine',
#   'carvedilol',
#   'lisinopril',
#   'dextromethorphan',
#   'guaifenesin',
#   'gabapentin'],
#  102296: ['quinolones',
#   'sodium 151',
#   'pt',
#   'gi',
#   'troponin',
#   'ekg',
#   'simvastatin',
#   'keppra',
#   'travatan',
#   'keppra',
#   'simvastatin',
#   'levobunolol',
#   'simvastatin',
#   'levobunolol',
#   'latanoprost',
#   'ferrous sulfate',
#   'pantoprazole',
#   'senna',
#   'sig',
#   'levetiracetam',
#   'lisinopril',
#   'lasix'],
#  114976: ['penicillin',
#   'haldol',
#   'elavil',
#   'dulcolax',
#   'thorazine',
#   'zantac',
#   'lasix',
#   'glyburide',
#   'xanax',
#   'cpap',
#   'lasix',
#   'flovent'],
#  128041: ['bal',
#   'coumadin',
#   'dilantin',
#   'nimodipine',
#   'etoh',
#   'propofol',
#   'asbestos',
#   'dilantin',
#   'coumadin',
#   'keppra',
#   'avr',
#   'heparin',
#   'warfarin',
#   'iv',
#   'coumadin',
#   'coumadin',
#   'coumadin',
#   'bal',
#   'vancomycin',
#   'cefepime',
#   'colchicine',
#   'pt',
#   'metoprolol',
#   'betimol',
#   'isosorbide',
#   'levetiracetam',
#   'levobunolol',
#   'albuterol sulfate',
#   'colchicine',
#   'pravastatin',
#   'pantoprazole',
#   'isosorbide mononitrate',
#   'metoprolol succinate',
#   'zetia',
#   'warfarin'],
#  123244: ['t6 - 9',
#   'advil',
#   'acetominophen',
#   'acetominophen',
#   'gastrocnemius',
#   'gadolinium',
#   'gadolinium',
#   'cephalosporins',
#   'carbapenems',
#   'quinolones',
#   'mic',
#   'clindamycin',
#   'erythromycin',
#   'gentamicin',
#   'levofloxacin',
#   'oxacillin',
#   'penicillin',
#   'ceftriaxone',
#   'vancomycin',
#   'flagyl iv',
#   'ceftriaxone',
#   'flagyl',
#   'vancomycin',
#   'vancomycin',
#   'tb',
#   'nafcillin',
#   'nitroglycerine',
#   'cpk - mb',
#   'aspirin',
#   'epinephrine',
#   'atropine',
#   'ccu',
#   'gi',
#   'narcotics',
#   'benzodiazepines',
#   'benzodiazepines',
#   'bp',
#   'levofloxicin',
#   'ppi',
#   'heparin',
#   'c diff b toxin potassium',
#   'acetaminophen',
#   'pantoprazole',
#   'nitroglycerin',
#   'albuterol sulfate',
#   'aspirin',
#   'isosorbide mononitrate',
#   'haloperidol',
#   'haloperidol',
#   'captopril',
#   'potassium chloride',
#   'nafcillin',
#   'captopril',
#   'metoprolol tartrate',
#   'cyanocobalamin',
#   'levofloxacin',
#   'oxycodone',
#   'acetaminophen',
#   'ipratropium bromide',
#   'nafcillin'],
#  111458: ['oxaliplatin',
#   'gemcitabine',
#   'xelox',
#   'oxaliplatin',
#   'capecitabice',
#   'xeloda',
#   'coumadin',
#   'lactate',
#   'oxaliplatin',
#   'c2d1',
#   'cdiff',
#   'prn',
#   'cdiff',
#   'octreotide',
#   'levophed',
#   'icu',
#   'coumadin',
#   'ucx',
#   'cipro',
#   'coumadin',
#   'coumadin',
#   'compazine prn'],
#  110863: ['niacin',
#   'osh',
#   'paclitaxel',
#   'ceftriaxone',
#   'vancomycin',
#   'furosemide',
#   'ceftriaxone',
#   'vancomycin',
#   'etoh',
#   'bibasilar',
#   'morphine',
#   'benadryl',
#   'haldol',
#   'furosemide',
#   'ckd',
#   'hydralazine',
#   'labetolol',
#   'ranolazine',
#   'fluc',
#   'acyclovir',
#   'fluconazole',
#   'famotidine',
#   'prochlorperazine prn',
#   'furosemide',
#   'aspirin',
#   'labetalol',
#   'calcitriol',
#   'cholecalciferol',
#   'vitamin d3',
#   'atorvastatin',
#   'finasteride',
#   'ranolazine sr',
#   'ranitidine',
#   'hydralazine',
#   'epoetin alfa',
#   'clopidogrel',
#   'renal caps'],
#  188551: ['lisinopril',
#   'atorvastatin',
#   'lovenox',
#   'lactate',
#   'glucose - 197 *',
#   'subfalcine',
#   'dilantin',
#   'dilantin',
#   'dilantin',
#   'dilantin',
#   'levofloxacin',
#   'cymbalta',
#   'protonix',
#   'advair',
#   'dulcolax',
#   'nystatin',
#   'lansoprazole',
#   'levofloxacin',
#   'albuterol',
#   'ipratropium bromide',
#   'metoprolol tartrate',
#   'furosemide'],
#  101331: ['atropine',
#   'vanc',
#   'levaquin',
#   'urean - 582',
#   'osmolal - 431',
#   'synthroid',
#   'synthroid',
#   'epogen',
#   'bm',
#   'prbcs',
#   'glyburide',
#   'glyburide',
#   'glipizide',
#   'statin',
#   'levaquin',
#   'prazosin',
#   'protonix',
#   'glyburide',
#   'zoloft',
#   'alprazolam',
#   'simvastatin',
#   'isosorbide mononitrate',
#   'magnesium hydroxide',
#   'protonix',
#   'ipratropium bromide',
#   'epoetin alfa',
#   'albuterol sulfate',
#   'docusate sodium',
#   'ipratropium bromide',
#   'levofloxacin',
#   'amlodipine besylate',
#   'levothyroxine sodium',
#   'fs qid',
#   'insulin qid',
#   'overdiuresis 8'],
#  109667: ['pentostatin',
#   'linezolid',
#   'prednisone',
#   'fdg',
#   'fdg',
#   'vancomycin',
#   'levofloxacin',
#   'cefepime',
#   'hc',
#   'benadryl',
#   'rituximab',
#   'prednisone',
#   'csa',
#   'haptoglob - 147',
#   'lactate',
#   'fibrinoge - 340',
#   'fdg',
#   'fdg',
#   'cefepime',
#   'levofloxacin',
#   'hydrocortisone',
#   'acyclovir',
#   'creatinine',
#   'acyclovir',
#   'protonix',
#   'acyclovir',
#   'trimethoprim - sulfamethoxazole',
#   'pantoprazole',
#   'citalopram',
#   'folic acid',
#   'zantac',
#   'benadryl',
#   'zantac'],
#  106629: ['oxycontin',
#   'doxepin',
#   'librium',
#   'neurontin',
#   'ambien',
#   'baclofen',
#   'ativan',
#   'fentanyl',
#   'haldol',
#   'ancef',
#   'tylenol',
#   'lipitor',
#   'detrol',
#   'oxycontin',
#   'bzd',
#   'salicylates',
#   'amphetamines',
#   'propofol',
#   'propofol',
#   'ativan',
#   'ativan',
#   'clonidine',
#   '-',
#   'bicarb 21',
#   'quetiapine fumarate',
#   'lorazepam',
#   'clonidine',
#   'benzo'],
#  116451: ['cyberknife',
#   'etoh',
#   'pulm - ctab',
#   'ibili',
#   'fentanyl',
#   'hydralazine iv',
#   'po',
#   'po',
#   'lasix iv',
#   'glargine',
#   'insulin',
#   'bactrim',
#   'valcyte',
#   'fluconazole',
#   'solumedrol',
#   'cellcept',
#   'solumedrol',
#   'cellcept',
#   'prograf',
#   'heparin',
#   'pantoprazole',
#   'nadolol',
#   'lasix',
#   'spironolactone',
#   'fluconazole',
#   'prednisone',
#   'docusate sodium',
#   'sulfamethoxazole - trimethoprim',
#   'mycophenolate mofetil',
#   'pantoprazole',
#   'amlodipine',
#   'metoprolol tartrate',
#   'tacrolimus',
#   'valganciclovir',
#   'oxycodone',
#   'insulin glargine',
#   'insulin lispro',
#   'tacrolimus',
#   'tacrolimus'],
#  102365: ['lasix',
#   'diuril',
#   'keflex',
#   'iodine',
#   'prednisone',
#   'vitamin k',
#   'prednisone',
#   'urean - 40',
#   'basos',
#   'osmolal - 335',
#   'urea n - 451 creat - 71',
#   'caltibc',
#   'ipf',
#   'guiac',
#   'nadolol',
#   'fe',
#   'chf',
#   'torsemide',
#   'prednisone',
#   'heparin gtt',
#   'vancomycin',
#   'cefepime',
#   'vancomycin',
#   'meropenem',
#   'vancomycin',
#   'heparin',
#   'warfarin',
#   'hep gtt',
#   'coumadin',
#   'hep gtt',
#   'coumadin',
#   'creatinine',
#   'nadolol',
#   'amlodipine',
#   'spironolactone',
#   'prednisone',
#   'prednisone',
#   'npo',
#   'meropenem',
#   'flagyl',
#   'po bumex',
#   'coumadin',
#   'dofetilide',
#   'pcp',
#   'amlodipine',
#   'fexofenadine',
#   'levothyroxine',
#   'omeprazole',
#   'multivitamin',
#   'tiotropium bromide',
#   'atorvastatin',
#   'docusate sodium',
#   'dofetilide',
#   'albuterol sulfate',
#   'cholecalciferol',
#   'fluticasone',
#   'warfarin',
#   'warfarin',
#   'guaifenesin',
#   'bumetanide',
#   'prednisone',
#   'ferrous sulfate',
#   'spironolactone',
#   'bumetanide',
#   'warfarin',
#   'vancomycin',
#   'prednisone',
#   'fexofenadine',
#   'levothyroxine',
#   'omeprazole',
#   'sig',
#   'tiotropium bromide',
#   'atorvastatin',
#   'dofetilide',
#   'albuterol sulfate',
#   'cholecalciferol',
#   'fluticasone',
#   'morphine',
#   'morphine',
#   'calcium carbonate',
#   'epogen',
#   'ferrous sulfate',
#   'metronidazole',
#   'heparin',
#   'nadolol',
#   'meropenem',
#   'rbcs',
#   'nadolol'],
#  107251: ['codeine',
#   'morphine',
#   'penicillins',
#   'darvon',
#   'coumadin',
#   'dysfunciton',
#   'procainamide',
#   'procainamide',
#   'lasix',
#   'acei',
#   'bblocker',
#   'creatinine',
#   'phenylephrine',
#   'pt',
#   'warfarin',
#   'methadone',
#   'levothyroxine',
#   'plavix',
#   'lisinopril',
#   'pravachol',
#   'methadone'],
#  109191: ['il - 2',
#   'il - 2',
#   'lisinopril',
#   'flomax',
#   'proscar',
#   'naprosyn',
#   'interleukin - ii',
#   'il - 2',
#   'il - 2',
#   'lorazepam',
#   'compazine',
#   'flagyl',
#   'oxycodone',
#   'zantac',
#   'il - 2'],
#  164366: ['bactrim ds',
#   'dapsone',
#   'delavirdine',
#   'abacavir sulfate',
#   'amoxicillin',
#   'amoxicillin',
#   'lactate',
#   'ceftriaxone 2 gm',
#   'vancomycin',
#   'flagyl',
#   'levophed',
#   'levofloxacin',
#   'amoxicillin',
#   'levofloxacin',
#   'atenolol',
#   'metoprolol',
#   'lisinopril',
#   'aspirin',
#   'pravastatin',
#   'androgel',
#   'aspirin',
#   'folic acid',
#   'fosamprenavir',
#   'lisinopril',
#   'loratadine',
#   'lorazepam',
#   'metoprolol tartrate',
#   'patanol',
#   'pravastatin sodium',
#   'tenofovir',
#   'tricor',
#   'zantac',
#   'aspirin',
#   'fosamprenavir',
#   'lopinavir - ritonavir',
#   'tenofovir',
#   'disoproxil fumarate',
#   'levofloxacin',
#   'oxycodone',
#   'acetaminophen',
#   'pravastatin',
#   'patanol',
#   'atenolol',
#   'androgel',
#   'folic acid',
#   'loratadine',
#   'tricor',
#   'compazine',
#   'amoxicillin',
#   'amoxicillin',
#   'atenolol'],
#  112747: ['amiodarone',
#   'cabg',
#   'etoh',
#   'phenylephrine',
#   'epinephrine',
#   'hco3 - 29',
#   'urean - 17',
#   'flomax',
#   'amiodarone',
#   'citalopram',
#   'celexa',
#   'tablet - 1',
#   'folic acid',
#   'levothyroxine',
#   'lorazepam',
#   'metoprolol tartrate',
#   'tablet - 1',
#   'simvastatin',
#   'zocor',
#   'tablet - 1',
#   'aspirin',
#   'aspirin',
#   'chlorhexidine gluconate',
#   'chlorhexidine',
#   'lutein',
#   'centrum silver',
#   'thiamine hcl',
#   'lorazepam',
#   'amiodarone',
#   'citalopram',
#   'folic acid',
#   'levothyroxine',
#   'simvastatin',
#   'metoprolol tartrate',
#   'aspirin',
#   'tamsulosin',
#   'docusate sodium',
#   'oxycodone',
#   'acetaminophen',
#   'furosemide',
#   'furosemide',
#   'acetaminophen',
#   'amiodarone',
#   'cabg'],
#  106621: ['bactrim',
#   'penicillins',
#   'kayexalate',
#   'ativan',
#   'solumedrol',
#   'propofol gtt',
#   'vancomycin',
#   'warfarin',
#   'decadron',
#   'thalidomide',
#   'decadron',
#   'cytoxan',
#   'decadron',
#   'melphalan',
#   'decadron',
#   'decadron',
#   'kappa light chains',
#   'zometa qo',
#   'velcade',
#   'creatinine',
#   'ddavp',
#   'phos - 83',
#   'vancomycin',
#   'warfarin',
#   'vancomycin',
#   'levofloxacin',
#   'ceftriaxone',
#   'warfarin',
#   'haldol',
#   'cogentin',
#   'haldol',
#   'ativan',
#   'dilaudid',
#   'cogentin',
#   'haldol',
#   'ceftriaxone',
#   'steorids',
#   'velcade',
#   'dexamethasone',
#   'ddavp',
#   'o2',
#   'warfarin',
#   'warfarin',
#   'dexamethasone',
#   'metoprolol',
#   'diltiazem',
#   'po',
#   'albuterol',
#   'ipratropium bromide',
#   'docusate sodium',
#   'oxycodone',
#   'oxycodone',
#   'fentanyl',
#   'diltiazem hcl',
#   'oxycodone',
#   'warfarin',
#   'coumadin',
#   'ddavp'],
#  114735: ['azithromycin',
#   'azithro',
#   'atropine',
#   'ativan',
#   'ceftriaxone',
#   'levoquin',
#   'ativan',
#   'hydrocortisone',
#   'dilantin',
#   'carbamazepin',
#   'dilantin',
#   'vancomycin',
#   'carbamazepine',
#   'tegretol xr',
#   'fexofenadine',
#   'hydrocortisone',
#   'levetiracetam',
#   'keppra',
#   'timolol maleate',
#   'bacitracin',
#   'vancomycin',
#   'carbamazepine',
#   'keppra',
#   'phenytoin'],
#  114836: ['ampicillin',
#   'piperacillin sodium',
#   'tazobactam',
#   'cholangiogram',
#   'alk',
#   'totbili',
#   'meropenum',
#   'vanco',
#   'daptomycin',
#   'iv',
#   'prograf',
#   'prograf',
#   'prograf',
#   'prograf',
#   'hcv',
#   'prograf',
#   'ptc',
#   'prograf',
#   'fluconazole 400',
#   'valganciclovir 900',
#   'fluconazole',
#   'valganciclovir',
#   'thiamine hcl',
#   'folic acid',
#   'mycophenolate mofetil',
#   'trimethoprim - sulfamethoxazole',
#   'pantoprazole',
#   'ursodiol',
#   'prednisone',
#   'tacrolimus',
#   'prograf',
#   'prograf'],
#  109566: ['dilaudid',
#   'tylenol',
#   'creatinine',
#   'carbidopa',
#   'levodopa',
#   'valtrex',
#   'ctab',
#   'nitrate',
#   'bactrim',
#   'bactrim',
#   'terazosin',
#   'lovenox',
#   '# ams : pt',
#   'narcotics',
#   'lovenox',
#   'lasix',
#   'metoprolol',
#   'valsartan',
#   'hctz',
#   'finasteride',
#   'terazosin',
#   'carbidopa',
#   'levodopa',
#   'finasteride',
#   'mirtazapine',
#   'clopidogrel',
#   'carbidopa',
#   'levodopa',
#   'pravastatin',
#   'metoprolol succinate',
#   'clopidogrel',
#   'omeprazole',
#   'acetaminophen',
#   'docusate sodium',
#   'senna',
#   'sig',
#   'bisacodyl',
#   'finasteride',
#   'mirtazapine',
#   'enoxaparin',
#   'lovenox',
#   'oxycodone',
#   'terazosin',
#   'celebrex',
#   'ibuprofen',
#   'advil',
#   'aleve',
#   'motrin',
#   'lovenox',
#   'aspirin'],
#  101857: ['macrodantin',
#   'heparin',
#   'etoh',
#   'octreotide',
#   'etoh',
#   'lactate',
#   'lactate',
#   'basos',
#   'octreotide',
#   'levofloxacin',
#   'lactulose',
#   'rifaximin',
#   'pentoxyfilline',
#   'ursodiol',
#   'pentoxyfilline',
#   'ursodiol',
#   'octreotide',
#   'midodrine',
#   'creatinine',
#   'midodrine',
#   'octreotide',
#   'gib',
#   'zosyn',
#   'vancomycin',
#   'levaquin',
#   'metformin',
#   'glargine',
#   'glargine',
#   'metformin',
#   'heparin',
#   'metformin 500',
#   'protonix',
#   'docusate sodium',
#   'folic acid',
#   'thiamine hcl',
#   'pantoprazole',
#   'miconazole nitrate'],
#  160707: ['ampicillin',
#   'deferasirox',
#   'clofarabine',
#   'vancomycin',
#   'cefepime',
#   'ciprofloxacin',
#   'hsv 1',
#   'nitro',
#   'flomax',
#   'azacitidine',
#   'vidaza',
#   'deferasirox',
#   'exjade',
#   'etoh',
#   'angap - 14',
#   'totbili',
#   'dirbili',
#   'indbili',
#   'vps',
#   'ground - glass',
#   'clofarabine',
#   'clofarabine',
#   'vancomycin',
#   'cefepime',
#   'meropenem',
#   'levofloxacin',
#   'voriconazole',
#   'voriconazole',
#   'clofarabine',
#   'posaconazole',
#   'ambisome',
#   'epinephrine',
#   'cpr',
#   'bisoprolol fumarate',
#   'folic acid',
#   'insulin glargine',
#   'lantus',
#   'insulin lispro',
#   'humalog',
#   'isosorbide dinitrate',
#   'lisinopril',
#   'nitroglycerin',
#   'oxybutynin chloride',
#   'pravastatin',
#   'tamsulosin',
#   'flomax',
#   'cholecalciferol',
#   'cyanocobalamin',
#   'pyridoxine'],
#  127356: ['compazine',
#   'droperidol',
#   'demerol',
#   'morphine',
#   'epinephrine sq',
#   'epi im',
#   'methylprednisolone',
#   'pepcid',
#   'atarax 25',
#   'zofran 4',
#   'ativan',
#   'albuterol neb',
#   'benadryl',
#   'portacath',
#   'portacath',
#   'etoh',
#   'totbili',
#   'baso',
#   'baso',
#   'sq epi',
#   'hydrocort',
#   'gastrocrom',
#   'cromolyn',
#   'ranitidine',
#   'atarax',
#   'benadryl',
#   'fexofenadine',
#   'prednisone',
#   'diltiazem',
#   'cymbalta',
#   'adderall',
#   'diltiazem hcl',
#   'hydroxyzine hcl',
#   'ranitidine hcl',
#   'amphetamine - dextroamphetamine',
#   'sig',
#   'cromolyn',
#   'hydroxychloroquine',
#   'duloxetine',
#   'fexofenadine',
#   'albuterol',
#   'calcium carbonate',
#   'prednisone',
#   'vitamin d',
#   'epi',
#   'epi'],
#  103293: ['abx',
#   'cryoprecpitate',
#   'all - trans retinoic acid',
#   'metformin',
#   'sulfer',
#   'hco3 - 28',
#   'atra',
#   'atra',
#   'idarubicin',
#   'allopurinol',
#   'allopurinol',
#   'apml',
#   'midazolam',
#   'fentanyl',
#   'dic',
#   'lasix',
#   'metolazone',
#   'afib',
#   'diltiazem',
#   'diltiazem',
#   'metoprolol',
#   'verapamil',
#   'amiodarone',
#   'amiodarone',
#   'amiodarone',
#   'amiodarone',
#   'metoprolol',
#   'labetalol',
#   'vancomycin',
#   'meropenem',
#   'vancomycin',
#   'cefepime',
#   'vancomycin',
#   'zosyn',
#   'micafungin',
#   'vancomycin',
#   'diazepam',
#   'daptomycin',
#   'metformin',
#   'metoprolol tartrate',
#   'cimetidine',
#   'amlodipine',
#   'lisinopril'],
#  178143: ['penicillins',
#   'codeine',
#   'tah',
#   'bso',
#   'ns 1l',
#   'cipro iv',
#   'narcan',
#   'flagyl',
#   'morphine',
#   'ptx',
#   'creatinine',
#   'po',
#   'ciprofloxacin',
#   'kub',
#   'seroquel',
#   'zantac',
#   'quetiapine',
#   'ranitidine hcl',
#   'duloxetine',
#   'acetaminophen',
#   'docusate sodium',
#   'hydrocodone',
#   'acetaminophen',
#   'acetaminophen',
#   'gatorade',
#   'pcp'],
#  160574: ['morphine',
#   'dilaudid',
#   'lactate wnl',
#   'vanc',
#   'zosyn',
#   'flagyl',
#   'jfa',
#   'aaox3',
#   'angap - 18',
#   'indx',
#   'rheufac',
#   'bnzodzp - neg',
#   'barbitr - neg',
#   'tricycl - neg',
#   'urean - 206',
#   'bnzodzp - neg',
#   'barbitr - neg',
#   'c - t - lspine',
#   'c7 - t1',
#   'methyl methacrylate',
#   'methyl methacrylate',
#   'vanco',
#   'zosyn',
#   'vancomycin',
#   'ceftriaxone',
#   'htn',
#   'asa',
#   'metoprolol succinate',
#   'diovan',
#   'asacol',
#   'ciprofloxacin',
#   'ciprofloxacin',
#   'ciprofloxacin',
#   'topimax',
#   'gabapentin',
#   'duloxetine',
#   'oxycontin',
#   'acetaminophen',
#   'oxycontin',
#   'narcotics',
#   'hydromorphone',
#   'hydromorphone',
#   'asa',
#   'plavix',
#   'ciprofloxacin',
#   'ciprofloxacin',
#   'ciprofloxacin',
#   'mesalamine',
#   'aspirin',
#   'metoprolol succinate',
#   'calcium carbonate',
#   'cymbalta',
#   'valsartan',
#   'folic acid',
#   'insulin glargine',
#   'lidoderm',
#   'lomotil',
#   'neurontin',
#   'oxycodone',
#   'oxycodone',
#   'clopidogrel',
#   'simvastatin',
#   'topiramate',
#   'docusate sodium',
#   'enoxaparin',
#   'cholecalciferol',
#   'acetaminophen',
#   'ceftriaxone - dextrose',
#   'vancomycin',
#   'vancomycin'],
#  117156: ['aspirin',
#   'lipitor',
#   'plavix',
#   'nitroglycerin',
#   'morphine',
#   'zofran',
#   'morphine',
#   'nitro x2',
#   'ivf',
#   'aspirin',
#   'basos',
#   'notdone ctropnt',
#   'lactate',
#   'urine gr',
#   'plavix',
#   'ranolazine',
#   'plavix',
#   'cv',
#   'metoprolol',
#   'triamterene',
#   'simvastatin',
#   'pneumoboots',
#   'razolazine',
#   'plavix',
#   'omeprazole',
#   'simvastatin',
#   'triamterene',
#   'simvastatin',
#   'ranolazine',
#   'omeprazole',
#   'glipizide',
#   'pioglitazone',
#   'insulin glargine',
#   'triamterene',
#   'hydrochlorthiazide',
#   'diltiazem',
#   'metoprolol',
#   'isosorbide mononitrate'],
#  106939: ['rifampin',
#   'pyrazinamide',
#   'rifampin',
#   'pyrazinamide',
#   'streptomycin',
#   'streptomycin',
#   'rifampin',
#   'rifabutin',
#   'iv drug',
#   'uric acid',
#   'chloride - 97',
#   'on',
#   'rifampin',
#   'pyrazinamide',
#   'allopurinol',
#   'lasix',
#   'rasburicase',
#   'ivermectin x 2',
#   'charcot -',
#   'inh',
#   'pza',
#   'rifabutin',
#   'tb',
#   'arv',
#   'nystatin',
#   'isoniazid',
#   'pyrazinamide',
#   'rifabutin',
#   'pyridoxine',
#   'isoniazid',
#   'pyrazinamide',
#   'rifabutin',
#   'pyridoxine',
#   'folic acid',
#   'nystatin',
#   'trimethoprim - sulfamethoxazole',
#   'bactrim',
#   'folic acid',
#   'folic acid',
#   'nystatin'],
#  106064: ['heparin',
#   "po ' s",
#   'percocet',
#   'methadone',
#   'unasyn',
#   'vancomycin',
#   'flagyl',
#   'di',
#   'methadone',
#   'dx',
#   'iv',
#   'etoh',
#   'dts',
#   'ctab',
#   'bnzodzpn - neg',
#   'barbitrt - neg',
#   'lactate',
#   'totbili',
#   'hbcab',
#   'etoh',
#   'hep c',
#   'dm',
#   'vancomycin',
#   'amphotericin',
#   'vancomycin',
#   'amphotericin',
#   'amphotericin',
#   'vancomycin',
#   'amphotericin',
#   'caspofungin',
#   'heparin',
#   'vancomycin',
#   'vancomycin',
#   'erythropoeitin',
#   'pt',
#   'vancomycin',
#   'vancomycin',
#   'vancomycin',
#   'fentanyl',
#   'methadone',
#   'morphine',
#   'oxycodone',
#   'fentanyl',
#   'methadone',
#   'mscontin',
#   'neurontin',
#   'tylenol',
#   'dilaudid',
#   'tramadol',
#   'dilaudid',
#   'glyburide',
#   'metformin',
#   'pt',
#   'spironolactone',
#   'spironolactone',
#   'sodium of 124',
#   'ucx',
#   'ciprofloxacin',
#   'fen',
#   'heparin',
#   'ppi',
#   'methadone',
#   'atenolol',
#   'zestril',
#   'aldactone',
#   'glyburide',
#   'caspofungin',
#   'senna',
#   'bisacodyl',
#   'magnesium oxide',
#   'metformin',
#   'hydromorphone',
#   'gabapentin',
#   'tramadol',
#   'acetaminophen',
#   'morphine',
#   'morphine',
#   'po',
#   'tslo',
#   'caspofungin'],
#  104468: ['atropine',
#   'diltiazem',
#   'metoprolol',
#   'ctab',
#   'totbili',
#   'afib',
#   'atropine',
#   'diltiazem',
#   'afib',
#   'coumadin',
#   'levothyroxine',
#   'levothyroxine',
#   'levothyroxine',
#   'levothyroxine',
#   'asa',
#   'ferrous gluconate',
#   'folic acid',
#   'plavix',
#   'prilosec',
#   'vitamin d',
#   'coumadin',
#   'metoprolol',
#   'diltiazem',
#   'calcium carbonate',
#   'levothyroxine',
#   'aspirin',
#   'folic acid',
#   'clopidogrel',
#   'pantoprazole',
#   'cholecalciferol',
#   'hexavitamin',
#   'warfarin',
#   'calcium carbonate',
#   'senna',
#   'docusate sodium',
#   'metoprolol tartrate',
#   'tramadol',
#   'metoprolol',
#   'diltiazem'],
#  109527: ['penicillins',
#   'ivf',
#   'vanc',
#   'zosyn',
#   'moxifloxacin',
#   'osh',
#   'atn',
#   'vanc',
#   'zosyn',
#   'ercp',
#   'penicillin',
#   'zosyn',
#   'benedryl',
#   'sarna',
#   'ct',
#   'prilosec',
#   'levothyroxine'],
#  114004: ['furosemide',
#   'klor - con',
#   'zpack',
#   'pradaxa',
#   'afib',
#   'lactate',
#   'cipro',
#   'flagyl',
#   'cnii - xii',
#   'totbili',
#   'pradaxa',
#   'ciprofloxacin',
#   'cefpodoxime',
#   'amiodarone',
#   'creatinine',
#   'amiodarone',
#   'atenolol',
#   'amiodarone',
#   'levothyroxine',
#   'alprazolam',
#   'cholecalciferol',
#   'cefpodoxime',
#   'phenazopyridine',
#   'atenolol',
#   'lisinopril',
#   'triamterene - hydrochlorothiazid',
#   'aspirin',
#   'sig',
#   'flovent hfa',
#   'asiprin'],
#  143451: ['lisinopril',
#   'diovan',
#   'presyncope',
#   'aspirin',
#   'plavix',
#   'heparin',
#   'etoh',
#   'notdone ctropnt',
#   'notdone ctropnt',
#   'sl nitro',
#   'nstemi',
#   'heparin',
#   'integrelin gtt',
#   'plavix',
#   'valsartan',
#   'diltiazem',
#   'isosorbide',
#   'metoprolol',
#   'valsartan',
#   'heparin',
#   'atenolol',
#   'diltiazem hcl',
#   'valsartan',
#   'aspirin',
#   'rosuvastatin',
#   'isosorbide mononitrate',
#   'latanoprost',
#   'betimol',
#   'valsartan',
#   'isosorbide mononitrate',
#   'latanoprost',
#   'timolol maleate',
#   'diltiazem hcl',
#   'aspirin',
#   'atorvastatin',
#   'clopidogrel',
#   'omeprazole',
#   'aspirin',
#   'plavix',
#   'diltiazem',
#   'omeprazole'],
#  102629: ['aspirin',
#   'codeine',
#   'penicillins',
#   'iodine',
#   'aspirin',
#   'dop',
#   'laa',
#   'phenylephrine',
#   'baso',
#   'ldlcalc - 80',
#   'statin',
#   'aspirin',
#   'metformin',
#   'humalin - n',
#   'humalin - r',
#   'lisinopril',
#   'paroxetine',
#   'docusate sodium',
#   'aspirin',
#   'omeprazole',
#   'metformin',
#   'acetaminophen',
#   'metoprolol tartrate',
#   'senna',
#   'glucometer',
#   'humulin',
#   'furosemide'],
#  130153: ['valium', 'effexor', 'buspar', 'seroquel', 'seroquel'],
#  108949: ['cdiff', 'metformin'],
#  115267: ['levaquin',
#   'vancomycin',
#   'bactrim',
#   'vancomycin',
#   'vancomycin',
#   'vancomycin',
#   'vancomycin',
#   'iv fosphenytoin',
#   'baclofen',
#   'bipap',
#   'ativan',
#   'ativan',
#   'acyclivir',
#   'fosphenytoin iv',
#   'phenytoin po',
#   'vancomycin',
#   'ceftazidime',
#   'vancomycin',
#   'vancomycin',
#   'vancomycin',
#   'bseline',
#   'heparin',
#   'baclofen',
#   'amlodipine',
#   'amlodipine',
#   'oxybutynin chloride',
#   'baclofen',
#   'famotidine',
#   'ceftazidime',
#   'vancomycin',
#   'adryl',
#   'amlodipine',
#   'oxybutynin chloride',
#   'baclofen',
#   'famotidine',
#   'phenytoin',
#   'vancomycin',
#   'phenytoin',
#   'dilantin',
#   'vancomycin',
#   'ceftazidine',
#   'vancomycin'],
#  168936: ['aspirin',
#   'indomethacin',
#   'ciprofloxacin',
#   'probenecid',
#   'allopurinol',
#   'phenytoin',
#   'keflex',
#   'keflex',
#   'keflex',
#   'dexamethasone',
#   'vancomycin',
#   'levofloxacin',
#   'aox3',
#   'totbili',
#   'cns',
#   'vancomycin',
#   'levofloxacin',
#   'prednisone',
#   'dilantin',
#   'cephalosporins',
#   'dilantin',
#   'keflex',
#   'interferon',
#   'ribavirin',
#   'lactate',
#   'tamsulosin',
#   'amlodipine',
#   'levothyroxine',
#   'amlodipine',
#   'tamsulosin',
#   'oxycodone',
#   'multivitamin 5',
#   'cholecalciferol',
#   'vitamin e',
#   'levothyroxine',
#   'docusate sodium',
#   'phenytoin sodium',
#   'keflex',
#   'tamsulosin',
#   'sig',
#   'oxycodone',
#   'cholecalciferol',
#   'levothyroxine',
#   'docusate sodium',
#   'vitamin e',
#   'dilantin',
#   'phenytoin',
#   'keflex',
#   'cephalexin',
#   'keflex',
#   'amlodipin'],
#  185800: ['propofol',
#   'succ',
#   'rocuronium',
#   'fentanyl',
#   'glycopyrolate',
#   'micu',
#   'neosynephrine',
#   'cefazolin',
#   'alprazolam',
#   'hcc',
#   'cnii - xii',
#   'calibur',
#   'aspirin',
#   'betablocker',
#   'statin',
#   'pt',
#   'propofol',
#   'succ',
#   'rocuronium',
#   'fentanyl',
#   'glycopyrrolate',
#   'propofol',
#   'succinylcholine',
#   'glycopyrrolate',
#   'troponin',
#   'raloxifene',
#   'nicotine',
#   'alprazolam',
#   'alprazolam',
#   'vitamin d2',
#   'raloxifene',
#   'sumatriptan succinate'],
#  111882: ['compazine',
#   'zosyn',
#   '35yf',
#   'metoprolol',
#   'metoprolol',
#   'imuran',
#   'imuran',
#   'ondansteron x 2',
#   'ceftriaxone',
#   'azithromycin',
#   'etoh',
#   'dp',
#   'notdone trop - t',
#   'cytoxan',
#   'milrinone',
#   'lisinopril',
#   'amlodipine',
#   'pt',
#   'torsemide',
#   'bblocker',
#   'plaquenil',
#   'imuran',
#   'prednisone',
#   'plaquenil',
#   'cytoxan',
#   'solumedrol',
#   'solumedrol',
#   'atovaquone',
#   'cytoxan',
#   'cytoxan',
#   'imuran',
#   'tx',
#   'asa',
#   'cytoxan',
#   'cytoxan',
#   'creatinine',
#   'hydralazine',
#   'hydralazine',
#   'lisinopril',
#   'hydralazine',
#   'cytoxan',
#   'ivig',
#   'hydralazine',
#   'hydralazine',
#   'pantoprazole',
#   'prednisone',
#   'vitamin d',
#   'ferrous sulfate',
#   'multivitamin',
#   'cyanocobalamin',
#   'folic acid',
#   'furosemide',
#   'plaquenil',
#   'metoprolol',
#   'carvedilol',
#   'carvedilol',
#   'imuran',
#   'folic acid',
#   'calcium carbonate',
#   'cholecalciferol',
#   'acetaminophen',
#   'atovaquone',
#   'ferrous sulfate',
#   'nystatin',
#   'amlodipine',
#   'spironolactone',
#   'prednisone',
#   'hydrocortisone',
#   'lisinopril',
#   'torsemide',
#   'plaquenil',
#   'vitamin d',
#   'lisinopril',
#   'torsemide'],
#  106361: ['dicloxacillin',
#   'lisinopril',
#   'vioxx',
#   'pmh',
#   'lactate',
#   'aspirin',
#   'cpap #',
#   'aaox2',
#   'aca igg',
#   'aca igm',
#   'ammonia - 18',
#   'b2micro',
#   'pmh',
#   'seroquel',
#   'seroquel',
#   'seroquel',
#   'haldol',
#   'vanc',
#   'cefepime',
#   'flagyl',
#   'cogentin',
#   'ativan',
#   'ceftriaxone',
#   'avnrt',
#   'metoprolol',
#   'statin',
#   'statin',
#   'statin',
#   'statin',
#   'haldol',
#   'seroquel',
#   'cogentin x 2',
#   'ativan',
#   'prn ativan',
#   'seroquel',
#   'benzos',
#   'seroquel',
#   'seroquel',
#   'ativan',
#   'metoprolol',
#   'losartan',
#   'furosemide',
#   'clonidine patch',
#   'hydralazine',
#   'simvastatin',
#   'simvastatin',
#   'clopidogrel',
#   'albuterol',
#   'tiotropium',
#   'symbicort',
#   'advair',
#   'glyburide',
#   'miconazole',
#   'lorazepam',
#   'amlodipine',
#   'clopidogrel',
#   'plavix',
#   'furosemide',
#   'glyburide',
#   'lorazepam',
#   'losartan',
#   'metoprolol er',
#   'pantoprazole',
#   'quetiapine',
#   'seroquel',
#   'simvastatin',
#   'calcium carbonate',
#   'ergocalciferol',
#   'vitamin d2',
#   'ferrous sulfate',
#   'multivitamin',
#   'senna - 8',
#   'saline',
#   'spiriva',
#   'ibuprofen',
#   'nystatin',
#   'acetaminophen',
#   'amlodipine',
#   'clopidogrel',
#   'glyburide',
#   'losartan',
#   'pantoprazole',
#   'senna',
#   'clonidine',
#   'saline',
#   'tiotropium bromide',
#   'hfa',
#   'ibuprofen',
#   'nystatin',
#   'acetaminophen',
#   'furosemide',
#   'ergocalciferol',
#   'ferrous sulfate',
#   'metoprolol tartrate',
#   'hydralazine',
#   'seroquel',
#   'hydralazine',
#   'metoprolol',
#   'seroquel',
#   'lorazepam simvastatin',
#   'hydralazine',
#   'metoprolol',
#   'seroquel',
#   'hydralazine',
#   'metoprolol tartrate',
#   'seroquel'],
#  166834: ['prilosec',
#   'baso',
#   'morphine',
#   'morphine',
#   'ct - a',
#   'prbcs',
#   'prbcs',
#   'clindamycin',
#   'clindamycin',
#   'cxr',
#   'clindamycin',
#   'levofloxacin',
#   'levofloxacin',
#   'augmentin',
#   'azithromycin',
#   'prilosec',
#   'levofloxacin',
#   'omeprazole',
#   'docusate sodium',
#   'oxycodone',
#   'acetaminophen',
#   'ibuprofen'],
#  150068: ['nitrofurantoin',
#   'sc insulin',
#   'levophed gtt',
#   'abx',
#   'prbc',
#   'pendind',
#   'fluconazole'],
#  119069: ['decadron',
#   'lovenox',
#   'dexadron',
#   'navelbine',
#   'subfalcine',
#   'subfalcine',
#   'subfalcine',
#   'prn hydralazine',
#   'falcine',
#   'dexamethasone',
#   'lovenox',
#   'lovenox',
#   'zoloft',
#   'keppra',
#   'aggrenox',
#   'zocor',
#   'protonix',
#   'decadron',
#   'ativan',
#   'sertraline',
#   'levetiracetam',
#   'simvastatin',
#   'senna',
#   'pantoprazole',
#   'docusate sodium',
#   'trimethoprim - sulfamethoxazole',
#   'insulin lispro',
#   'dexamethasone',
#   'oxycodone',
#   'acetaminophen',
#   'metoprolol tartrate',
#   'lovenox'],
#  131903: ['captopril'],
#  113824: ['clindamycin',
#   'creatinine',
#   'allopurinol',
#   'etoh',
#   'aox3',
#   'aox3',
#   'angap - 16',
#   'totbili',
#   'uricacd',
#   'totbili',
#   'hydroxyurea',
#   'allopurinol',
#   'cytarabine',
#   'idarubicin',
#   'voriconazole',
#   'ot',
#   'pt',
#   'meropenem',
#   'aztreonam',
#   'aztrenonam',
#   'voriconazole',
#   'calcium carbonate',
#   'cod liver oil',
#   'multivitamin',
#   'otc',
#   'voriconazole',
#   'voriconazole',
#   'acetaminophen',
#   'aspirin',
#   'calcium carbonate',
#   'metoprolol succinate',
#   'acyclovir',
#   'acyclovir',
#   'cytarabine',
#   'voriconazole',
#   'acyclovir'],
#  100579: ['ceftriaxone',
#   'cabg',
#   'ceftriaxone',
#   'vancomycin',
#   'cdiff',
#   'tylenol',
#   'nstemi',
#   'vancomycin',
#   'zosyn',
#   'mic',
#   'ampicillin',
#   'ampicillin',
#   'sulbactam',
#   'cefazolin',
#   'ceftazidime',
#   'ceftriaxone',
#   'cefuroxime',
#   'ciprofloxacin',
#   'gentamicin',
#   'meropenem',
#   'piperacillin',
#   'piperacillin',
#   'tobramycin',
#   'trimethoprim',
#   'sulfa',
#   'ceftriaxone',
#   'morbilloform drug',
#   'ceftriaxone',
#   'tobramycin',
#   'tobra',
#   'amiodarone',
#   'coumadin',
#   'statin',
#   'aspirin',
#   'coumadin',
#   'atorvastatin',
#   'docusate sodium',
#   'amiodarone',
#   'chlorhexidine gluconate',
#   'senna',
#   'docusate sodium',
#   'aspirin',
#   'amiodarone',
#   'ranitidine hcl',
#   'albuterol sulfate',
#   'atorvastatin',
#   'lisinopril',
#   'acetaminophen',
#   'camphor - menthol',
#   'miconazole nitrate',
#   'metoprolol tartrate',
#   'citalopram',
#   'acetylcysteine',
#   'heparin',
#   'heparin',
#   'heparin',
#   'heparin',
#   'heparin',
#   'heparin',
#   'tobramycin sulfate',
#   'warfarin',
#   'chlorhexidine gluconate',
#   'trazodone',
#   'oxycodone',
#   'acetaminophen',
#   'coumadin hx',
#   'tobramycin'],
#  103926: ['codeine',
#   'vasotec',
#   'cortisporin',
#   'ciloxan',
#   'atenolol',
#   'trop0 . 06',
#   'prbcs',
#   'lasix',
#   'heparin gtt',
#   'etoh',
#   '6f',
#   '6f',
#   'nitro gtt',
#   'aspirin',
#   'statin',
#   'plavix',
#   'rbc',
#   'iv furosemide',
#   'lasix',
#   'diuril',
#   'furosemide',
#   'prbcs',
#   'azithromycin',
#   'prednisone',
#   'glargine',
#   'glargine',
#   'amlodopine',
#   'atorvastatin',
#   'furosemide',
#   'glimepiride',
#   'cyanocobalamin',
#   'amaryl',
#   'acetaminophen',
#   'aspirin',
#   'amlodipine',
#   'cyanocobalamin',
#   'atorvastatin',
#   'clopidogrel',
#   'metoprolol tartrate',
#   'lidoderm',
#   'nitroglycerin',
#   'pentoxifylline',
#   'sig',
#   'valsartan',
#   'isosorbide dinitrate'],
#  100922: ['ciprofloxacin',
#   'zomig',
#   'lactulose',
#   'lactate',
#   'lactate',
#   'lactate',
#   'ucx',
#   'tigecycline',
#   'meropenem',
#   'imipenem',
#   'amikacin',
#   'ampicillin',
#   'ampicillin',
#   'sulbactam',
#   'cefazolin',
#   'ceftazidime',
#   'ceftriaxone',
#   'ciprofloxacin',
#   'gentamicin',
#   'imipenem',
#   'meropenem',
#   'nitrofurantoin',
#   'piperacillin',
#   'tetracycline',
#   'tobramycin',
#   'trimethoprim',
#   'sulfa',
#   'bcx',
#   'amikacin',
#   'ampicillin',
#   'ciprofloxacin',
#   'gentamicin',
#   'tobramycin',
#   'amikacin',
#   'ciprofloxacin',
#   'gentamicin',
#   'potassium hydroxide',
#   'ruq',
#   'lactulose',
#   'rifaximin',
#   'nitrofurantoin',
#   'amikacin',
#   'nitrofurantoin',
#   'colistin',
#   'tetracycline',
#   'lactulose',
#   'octreotride',
#   'midodrine',
#   'albumin',
#   'citalopram',
#   'mycophenolate mofetil',
#   'omeprazole',
#   'rifaximin',
#   'ursodiol',
#   's / p'],
#  105778: ['diovan',
#   'iv lopressor',
#   'heparin 1000u',
#   'hydralazine',
#   'zofran',
#   'dopamine',
#   'dopamine',
#   'etoh',
#   'lcx',
#   'nitroglycerine',
#   'metoprolol',
#   'nitroglycerin',
#   'hydralazine',
#   'aspirin',
#   'hctz',
#   'metoprolol',
#   'metoprolol',
#   'lescol',
#   'aspirin',
#   'docusate sodium',
#   'fluticasone',
#   'imipramine hcl',
#   'metoprolol tartrate',
#   'oxycodone',
#   'pantoprazole',
#   'cholestyramine - sucrose',
#   'meclizine',
#   'acetaminophen',
#   'lisinopril',
#   'lisinopril'],
#  191162: ['methylene blue',
#   'heliox',
#   'propofol',
#   'ctab',
#   'basos',
#   'fdg',
#   'methylene blue',
#   'cpap',
#   'mirtazapine',
#   'propofol',
#   'sinus tach',
#   'vanc',
#   'zosyn',
#   'guaifenesin',
#   'lidocaine',
#   'docusate sodium',
#   'ipratropium bromide',
#   'fentanyl',
#   'albuterol sulfate',
#   'acetylcysteine',
#   'enoxaparin',
#   'metoclopramide',
#   'metoprolol tartrate',
#   'morphine',
#   'senna',
#   'lidocaine',
#   'diphenhyd',
#   'codeine - guaifenesin',
#   'mirtazapine'],
#  124917: ['etoh',
#   'ctab',
#   'ctab',
#   'asa - neg ethanol',
#   'bnzodzpn - neg',
#   'barbitrt - neg',
#   'barbitrt - neg',
#   'mthdone',
#   'urean - 18',
#   'hco3 - 26',
#   'cpap',
#   'cxr',
#   'ceftriaxone',
#   'vanc',
#   'cipro',
#   'lasix',
#   'propofol',
#   'heparin sub - cu',
#   'famotidine',
#   'albuterol',
#   'sertraline',
#   'clonazepam',
#   'sertraline',
#   'pantoprazole',
#   'albuterol sulfate'],
#  108901: ['cipro',
#   'baso',
#   'barbitr - neg',
#   'tricycl - neg',
#   'bnzodzp - neg',
#   'barbitr - neg',
#   'tricycl - neg',
#   'cephalosporins',
#   'aztreonam',
#   'esbl',
#   'mic',
#   'ampicillin',
#   'ampicillin',
#   'sulbactam',
#   'cefazolin',
#   'ceftazidime',
#   'ceftriaxone',
#   'ciprofloxacin',
#   'gentamicin',
#   'meropenem',
#   'piperacillin',
#   'tobramycin',
#   'trimethoprim',
#   'sulfa',
#   'cephalosporins',
#   'aztreonam',
#   'esbl',
#   'mic',
#   'ampicillin',
#   'ampicillin',
#   'sulbactam',
#   'cefazolin',
#   'ceftazidime',
#   'ceftriaxone',
#   'ciprofloxacin',
#   'gentamicin',
#   'meropenem',
#   'piperacillin',
#   'tobramycin',
#   'trimethoprim',
#   'sulfa',
#   'osh c / b',
#   'vanco',
#   'cefepime',
#   'esbl',
#   'vancomycin',
#   'meropenem',
#   'vap',
#   'meropenem',
#   'ciprofloxacin',
#   'vanco',
#   'cefepime',
#   'metoprolol',
#   'lisinopril',
#   'metoprolol',
#   'lasix',
#   'lasix',
#   'coumadin',
#   'lovenox',
#   'coumadin',
#   'metoprolol',
#   'chlorhexidine gluconate',
#   'albuterol sulfate',
#   'ipratropium bromide',
#   'metoprolol tartrate',
#   'furosemide',
#   'oxycodone',
#   'acetaminophen',
#   'acetylcysteine',
#   'albuterol sulfate',
#   'warfarin',
#   'coumadin',
#   'heparin gtt',
#   'lansoprazole',
#   'lisinopril',
#   'simvastatin',
#   'heparin',
#   'bisacodyl',
#   'docusate sodium',
#   'ipratropium bromide',
#   'simvastatin',
#   'oxycodone',
#   'acetaminophen',
#   'chlorhexidine gluconate',
#   'cholecalciferol',
#   'calcium carbonate',
#   'metoprolol tartrate',
#   'acetylcysteine',
#   'enoxaparin',
#   'albuterol sulfate',
#   'furosemide',
#   'warfarin',
#   'famotidine',
#   'meropenem',
#   'vancomycin'],
#  104107: ['amiodarone',
#   'amiodarone',
#   'ctab',
#   'hcv',
#   'itp',
#   'hcv',
#   'coumadin',
#   'coumadin',
#   'acetaminophen',
#   'aspirin',
#   'docusate sodium',
#   'oxycodone',
#   'acetaminophen',
#   'ranitidine hcl',
#   'warfarin',
#   'metoprolol tartrate',
#   'magnesium hydroxide',
#   'bisacodyl',
#   'lasix',
#   'lasix',
#   'citalopram',
#   'atorvastatin',
#   'humulin'],
#  110342: ['tb',
#   'lactate',
#   'chloride - 107',
#   'calcium phos',
#   'tb',
#   'tb',
#   'clindamycin',
#   'erythromycin',
#   'gentamicin',
#   'levofloxacin',
#   'oxacillin',
#   'ceftriaxone',
#   'azithromycin',
#   'ceftriaxone',
#   'cefpodoxime',
#   'azithromycin',
#   'cefpodoxime',
#   'cefpodoxime',
#   'azithromycin',
#   'cefpodoxime',
#   'azithromycin'],
#  118243: ['ativan',
#   'ativan',
#   'ecotrin',
#   'lopressor',
#   'acetaminophen',
#   'docusate sodium',
#   'famotidine',
#   'alendronate',
#   'cholecalciferol',
#   'acetaminophen',
#   'levetiracetam',
#   'oxycodone',
#   'dexamethasone',
#   'docusate',
#   'colace',
#   'motrin',
#   'aspirin',
#   'advil',
#   'ibuprofen',
#   'keppra',
#   'prilosec',
#   'protonix',
#   'pepcid'],
#  177370: ['sulfa',
#   'sulfonamides',
#   'tape',
#   'ativan',
#   'dilantin',
#   'dilantin',
#   'levofloxacin',
#   'dilantin',
#   'dilantin',
#   'benadryl',
#   'solumedrol',
#   'tylenol',
#   'motrin',
#   'abx',
#   'tapazole',
#   'bartholin',
#   'dilantin held',
#   'keppra',
#   'dilantin',
#   'famotidine',
#   'vp',
#   'clobetasol',
#   'benadryl',
#   'sarna',
#   'atarax',
#   'po',
#   'acetaminophen',
#   'motrin',
#   'po',
#   'levofloxacin',
#   'phenytoin sodium',
#   'clobetasol',
#   'hydrocortisone',
#   'ibuprofen',
#   'levetiracetam',
#   'nystatin',
#   'prednisone',
#   'dilantin',
#   'dilantin',
#   'keppra'],
#  157609: ['vincristine',
#   'nortriptyline',
#   'ceftazidime',
#   'daptomycin',
#   'azithromycin',
#   'vincristine',
#   'mtx',
#   'cytarabine',
#   'mtx',
#   'vincristine',
#   'vincristine',
#   'ivig',
#   'lovenox',
#   'methadone',
#   'etoh',
#   'gen : nad',
#   'ctab',
#   'b2micro',
#   'decadron',
#   'acyclovir',
#   'vancomycin',
#   'cefepime',
#   'metoprolol',
#   'furosemide',
#   'nitroglycerin',
#   'morphine',
#   'citalopram',
#   'pregabalin',
#   'nortriptyline',
#   'tizanidine',
#   'lorazepam prn',
#   'polyethylene glycol',
#   'senna',
#   'docusate sodium',
#   'bisacodyl',
#   'lactulose',
#   'acetaminophen',
#   'ondansetron',
#   'magnesium hydroxide',
#   'lovenox',
#   'multivitamins',
#   'clotrimazole',
#   'miconazole'],
#  195689: ['ca - gluconate',
#   'acetaminophen',
#   'ibuprofen',
#   'lisinopril',
#   'nsaids',
#   'potassium citrate',
#   'lasix',
#   'bicarb',
#   'tamsulosin',
#   'kayexalate',
#   'insulin',
#   'bicarbonate',
#   'tamsulosin',
#   'amlodipine',
#   'metoprolol succinate',
#   'quinapril',
#   'tamsulosin',
#   'statin',
#   'quinapril',
#   'metformin',
#   'glipizide',
#   'tamsulosin',
#   'quinipril',
#   'metformin',
#   'glipizide',
#   'aspirin',
#   'ezetimibe',
#   'quinapril',
#   'metformin',
#   'rosuvastatin calcium',
#   'amlodipine',
#   'amlodipine',
#   'rosuvastatin calcium',
#   'aspirin',
#   'tamsulosin',
#   'tamsulosin',
#   'acetaminophen',
#   'acetaminophen',
#   'docusate sodium',
#   'docusate sodium',
#   'ezetimibe',
#   'glargine',
#   'tamsulosin'],
#  106038: ['methadone',
#   'bp',
#   'vancomycin',
#   'zosyn',
#   'adenexal',
#   'methadone',
#   'beta -',
#   'nitroglycerin',
#   'levothyroxine',
#   'anti - hypertensives',
#   'simvastatin',
#   'bicarb',
#   'kayexelate',
#   'heparin',
#   'heparin',
#   'ckmb',
#   'asa',
#   'simvastatin',
#   'bblocker',
#   'acei',
#   'levothyroxine',
#   'levothyroxine',
#   'keppra',
#   'gabapentin',
#   'methadone',
#   'fluoxetine',
#   'bp',
#   'omeprazole',
#   'levetiracetam',
#   'fluticasone',
#   'levothyroxine',
#   'levothyroxine',
#   'gabapentin',
#   'clonazepam',
#   'methadone',
#   'fluoxetine',
#   'calcium acetate',
#   'aspirin',
#   'simvastatin',
#   'omeprazole',
#   'folic acid',
#   'trazodone',
#   'levothyroxine',
#   'lisinopril'],
#  190056: ['propoxyphene',
#   'pyridium',
#   'bupropion',
#   'darvon',
#   'claritin',
#   'codeine',
#   'moexipril',
#   'toradol',
#   'solumedrol',
#   'baso',
#   'indx',
#   'notdone ctropnt',
#   'ecg',
#   'vancomycin',
#   'flagyl',
#   'levofloxacin',
#   'solumedrol',
#   "mdi ' s",
#   'tpa',
#   'morphine',
#   'morphine',
#   'levo',
#   'flagyl',
#   'vancomycin',
#   'c . diff',
#   'htn',
#   'sc heparin',
#   'pantoprazole',
#   'paxil',
#   'paroxetine hcl',
#   'zolpidem tartrate',
#   'camphor - menthol',
#   'salmeterol xinafoate',
#   'ipratropium bromide',
#   'metoprolol tartrate',
#   'isosorbide dinitrate',
#   'albuterol sulfate',
#   'bisacodyl',
#   'bismuth subsalicylate',
#   'ibuprofen',
#   'pantoprazole sodium',
#   'guaifenesin',
#   'phenergan',
#   'morphine sulfate',
#   'roxanol',
#   'ativan',
#   'ativan',
#   'sig',
#   'sig',
#   'dulcolax'],
#  103639: ['vitamin k',
#   'tobacco',
#   'etoh',
#   'etoh',
#   'vitamin k',
#   'vitamin k',
#   'rifaximin',
#   'nadolol',
#   'lactulose',
#   'rifaximin',
#   'nadolol',
#   'thiamine hcl',
#   'folic acid',
#   'sevelamer',
#   'pantoprazole',
#   'hydromorphone'],
#  130076: ['dalteparin',
#   'fragmin',
#   'heparin',
#   'cea - barrett',
#   'heparin',
#   'zyprexa',
#   'cxr',
#   'propofol',
#   'fentanyl',
#   'fio2',
#   '- pt',
#   'vancomycin',
#   'ciprofloxacin',
#   'cefepime',
#   'heparin',
#   'trach',
#   'valium - sbp',
#   'fentanyl',
#   'heparin',
#   'heparin',
#   'dilantin',
#   'heparin',
#   'bactrim',
#   'atovaquone',
#   'bactrim',
#   'bactrim',
#   'tyylenol',
#   'lasix',
#   'lasix',
#   'digoxin',
#   'phenylepinephrine',
#   'bactrim',
#   'sl',
#   'cta',
#   'metoprolol',
#   'solumedrol',
#   'metoprolol',
#   'hdyrocortisone 50 q12',
#   'vanco',
#   'levo',
#   'cefepine',
#   'propofol',
#   'benefiber',
#   '- po flagyl',
#   'bleomycin',
#   'sucralfate',
#   'sbp',
#   'propofol',
#   'dilantin',
#   'phenytoin',
#   'dilantin',
#   'cxr',
#   'vanco',
#   'zosyn',
#   'bactrim',
#   'phenytoin',
#   'prednisone',
#   'vitamin d',
#   'iron',
#   'folic acid',
#   'dalteparin',
#   'mesalamine 4',
#   'phenytoin',
#   'metoprolol',
#   'isosorbide'],
#  178331: ['erythromycin',
#   'coumadin',
#   'coumadin',
#   'tah - bso',
#   'gi : bs',
#   'rlq',
#   'pta',
#   'heparin',
#   'prbcs',
#   'coumadin',
#   'aspirin',
#   'cad',
#   'aspirin',
#   'atenolol',
#   'diovan',
#   'lisinopril',
#   'fentanyl',
#   'haldol',
#   'atenolol',
#   'atenolol',
#   'diovan',
#   'sig',
#   'aspirin',
#   'venlafaxine hcl',
#   'sig',
#   'hydrochlorothiazide',
#   'lisinopril',
#   'prilosec',
#   'trazodone hcl',
#   'coumadin'],
#  113200: ['prbc',
#   'ctab',
#   'digoxin -',
#   'asa',
#   'plavix',
#   'asa',
#   'plavix',
#   'fosamax',
#   'fosamax',
#   'aspirin',
#   'plavix',
#   'aspirin',
#   'urea',
#   'captopril',
#   'carvedilol',
#   'statin',
#   'plavix',
#   'citalopram',
#   'trazadone',
#   'fosamax',
#   'fosamax',
#   'captopril',
#   'citalopram',
#   'digoxin',
#   'captopril',
#   'citalopram hydrobromide',
#   'folic acid',
#   'levothyroxine sodium',
#   'levothyroxine sodium',
#   'silver sulfadiazine',
#   'digoxin',
#   'lorazepam',
#   'trazodone hcl',
#   'furosemide',
#   'simvastatin',
#   'docusate sodium',
#   'plavix',
#   'aspirin',
#   'fosamax',
#   'fosamax'],
#  109866: ['zosyn',
#   'protonix 40',
#   'afib',
#   'ativan',
#   'ativan',
#   'tpn',
#   'tylenol',
#   "diltiazem er 360 '",
#   "ramipril 5 '",
#   'celebrex',
#   'heparin',
#   'lasix',
#   'ramipril',
#   'diltiazem hcl',
#   'acetaminophen',
#   'sig',
#   'aspirin'],
#  107872: ['nafcillin',
#   'milrinone',
#   'torsemide',
#   'nafcillin',
#   'ivs',
#   'presyncope',
#   'b & wh',
#   'warfarin',
#   'mediastinum',
#   'torsemide',
#   'milrinone',
#   'torsemide',
#   'nafcillin',
#   'nafcillin',
#   'milrinone',
#   'dobutamine',
#   'dobutamine',
#   'ydralazine',
#   'isordil',
#   'pt',
#   'chf',
#   'torsemide',
#   'crt - d',
#   'lv lead',
#   'dobutamine',
#   'dobutamine',
#   'nafcillin',
#   'nafcillin',
#   'nafcillin',
#   'metoprolol',
#   'carvedilol',
#   'asa',
#   'statin',
#   'carvedilol',
#   'dobutamine',
#   'nafcillin',
#   'aspirin',
#   'glargine',
#   'pravastatin',
#   'carvedilol',
#   'hydralazine',
#   'isosorbide mononitrate',
#   'torsemide',
#   'torsemide',
#   'aspirin',
#   'isosorbide mononitrate',
#   'pravastatin',
#   'hydralazine',
#   'hydralazine',
#   'bicarb',
#   'dobutamine',
#   'dobutamine',
#   'dobutamine',
#   'torsemide',
#   'torsemide',
#   'hydroxyzine',
#   'potassium chloride',
#   'potassium chloride',
#   'heparin',
#   'heparin',
#   'heparin',
#   'milrinone',
#   'dobutamine',
#   'dobutamine'],
#  122093: ['sulfonamides',
#   'interferon',
#   'rebetron',
#   'peg - intron',
#   'ribavirin',
#   'etoh',
#   'jp',
#   'steroids',
#   'cellcept',
#   'prograf',
#   'prograf',
#   'thorazine',
#   'bactrim',
#   'pentamidine',
#   'pamidronate',
#   'clotrimazole',
#   'furosemide',
#   'spironolactone',
#   'fluconazole',
#   'prednisone',
#   'docusate sodium',
#   'famotidine',
#   'metoprolol tartrate',
#   'mycophenolate mofetil',
#   'valganciclovir',
#   'oxycodone',
#   'acetaminophen'],
#  102136: ['etoh',
#   'ua',
#   'utox',
#   'benzos',
#   'valium',
#   'ativan',
#   'etoh',
#   'aaox2',
#   'baso',
#   'totbili',
#   'totbili',
#   'ammonia - 32',
#   'hbcab',
#   'barbitr - neg',
#   'tricycl - neg',
#   'barbitr - neg',
#   'zyprexa',
#   'ativan iv',
#   'pt',
#   'etoh',
#   'benzo',
#   'mvi',
#   'folate',
#   'thiamine',
#   'b vits',
#   'etoh',
#   'benzos',
#   'haldol',
#   'vistaril',
#   'lexapro',
#   'inderal',
#   'topamax',
#   'etoh',
#   'ativan',
#   'folic acid',
#   'folic acid',
#   'thiamine hcl',
#   'librium',
#   'thiamine',
#   'vitamin b complex',
#   'folic acid',
#   'topamax',
#   'vistaril',
#   'lexapro'],
#  104095: ['bactrim',
#   'cogentin',
#   'lithium',
#   'glucose',
#   'imodium',
#   'metamucil',
#   'nystatin',
#   'miconazole',
#   'mag oxide',
#   'oscal',
#   'medroline',
#   'vitd',
#   'levothyroxine',
#   'zyprexa',
#   'heparin',
#   'folate',
#   'heparin',
#   'olanzapine',
#   'olanzapine',
#   'calcium carbonate',
#   'acetaminophen',
#   'metoprolol tartrate',
#   'levothyroxine',
#   'protonix',
#   'ondansetron',
#   'sig',
#   'dulcolax',
#   'fluconazole',
#   'miconazole nitrate',
#   'loperamide',
#   'metamucil powder sig'],
#  182003: ['haloperidol',
#   'valium',
#   'citalopram',
#   'olanzapine',
#   'flomax',
#   'zyprexa',
#   'citalopram',
#   'bisacodyl',
#   'detrol',
#   'robitussin 1',
#   'plavix',
#   'miralax',
#   'vit b12',
#   'zyprexa',
#   'citalopram',
#   'bisacodyl',
#   'detrol',
#   'robitussin 1',
#   'plavix',
#   'miralax',
#   'vit b12',
#   'flomax'],
#  153141: ['lisinopril',
#   'diovan',
#   'metformin',
#   'integrilin',
#   'plavix',
#   'plavix',
#   'heparin gtt',
#   'plavix load',
#   'nitro gtt',
#   'lima - lad',
#   'svg - pda',
#   'lima - lad',
#   'hco3 - 35',
#   'urean - 23',
#   'hco3 - 32',
#   'hco3 - 25',
#   'plavix',
#   'heparin',
#   'nitro gtt',
#   'heparin gtt',
#   'integrillin gtt',
#   'plavix',
#   'integrillin gtt',
#   'heparin gtt',
#   'integrillin',
#   'integrillin',
#   'integrillin',
#   'integrillin',
#   'heparin gtt',
#   'integrillin',
#   'plavix',
#   'heparin gtt',
#   'asa 325',
#   'pt',
#   'cipro',
#   'cipro',
#   'statin',
#   'aspirin',
#   'tamsulosin',
#   'tamsulosin',
#   'oxycodone',
#   'acetaminophen',
#   'docusate sodium',
#   'claritin',
#   'docusate sodium',
#   'aspirin',
#   'atorvastatin',
#   'amiodarone',
#   'metoprolol tartrate',
#   'spironolactone',
#   'acetaminophen',
#   'ranitidine hcl',
#   'fluconazole',
#   'integrillin'],
#  107139: ['ceftriaxone',
#   'piperacillin sodium',
#   'tazobactam',
#   'ct',
#   'etoh',
#   'ugib',
#   'atorvastatin',
#   'mirtazapine',
#   'levofloxacin',
#   'metoprolol',
#   'methylprednisolone',
#   'fentanyl',
#   'heparin'],
#  110445: ['dilantin',
#   'dilantin',
#   'dilantin',
#   'prilosec',
#   'iodine',
#   'tegretol',
#   'tegretol',
#   'dilantin',
#   'zantac',
#   'benadryl',
#   'dilantin',
#   'dilantin',
#   'zantac',
#   'atenolol'],
#  172474: ['atenolol',
#   'zestril',
#   'prilosec',
#   'celexa',
#   'rocaltrol',
#   'renagel',
#   'morphine pca',
#   'p . o',
#   'atenolol',
#   'dopamine',
#   'gamma globulin',
#   'colace',
#   'dulcolax',
#   'lasix',
#   'lasix',
#   'thymoglobulin',
#   'cellcept',
#   'solu - medrol',
#   'zenapax',
#   'rapamune',
#   'zenapax',
#   'atenolol',
#   'zestril',
#   'protonix',
#   'celexa',
#   'rocaltrol',
#   'renagel',
#   'cellcept',
#   'prednisone',
#   'bactrim',
#   'colace',
#   'amphojel',
#   'ganciclovir',
#   'rapamune',
#   'nystatin'],
#  102324: ['nstemi',
#   'ceftriaxone',
#   'decadron',
#   'insulin 3',
#   'cta b',
#   'phos - 78',
#   'glucose - 188',
#   'left parietovertex',
#   'ferritn - 131',
#   'ldlcalc - 50',
#   'plavix',
#   'statin',
#   'coumadin',
#   'lovenox',
#   'lovenox',
#   'coumadin',
#   'afib',
#   'icu',
#   'c5 - 6',
#   'bld cx',
#   'po',
#   'sodium',
#   'asa',
#   'plavix',
#   'statin',
#   'coumadin',
#   'fen',
#   'atorvastatin',
#   'citalopram',
#   'ranitidine hcl',
#   'hydrochlorothiazide',
#   'losartan',
#   'furosemide',
#   'isosorbide mononitrate',
#   'lovenox 60',
#   'clopidogrel',
#   'coumadin',
#   'aspirin',
#   'toprol',
#   'atorvastatin',
#   'citalopram',
#   'ranitidine hcl',
#   'hydrochlorothiazide',
#   'furosemide',
#   'losartan',
#   'aspirin',
#   'clopidogrel',
#   'warfarin',
#   'isosorbide mononitrate',
#   'c5 - 6'],
#  114452: ['keppra', 'keppra', 'keppra', 'keppra'],
#  113813: ['peg - interferon',
#   'ribavirin',
#   'radiofrequency ablation',
#   'codeine',
#   'nadolol',
#   'morphine',
#   'unasyn',
#   'bactrim',
#   'fluconazole',
#   'ganciclovir',
#   'lasix',
#   'prednisone',
#   'prednisone',
#   'prednisone',
#   'cellcept',
#   'solu - medrol',
#   'solu - medrol',
#   'solu - medrol',
#   'fluconazole',
#   'bactrim',
#   'protonix',
#   'percocet',
#   'cellcept',
#   'neoral',
#   'prednisone',
#   'insulin'],
#  115347: ['epinephrine',
#   'aspirin',
#   'basos',
#   'epinephrine',
#   'epinephrine',
#   'hemoclip',
#   'epinephrine',
#   'protonix gtt',
#   'diltiazem',
#   'po diltiazem',
#   'diltiazem',
#   'lasix',
#   'lasix',
#   'aspirin',
#   'lasix',
#   'metoprolol',
#   'lisinopril',
#   'citalopram',
#   'pantoprazole',
#   'diltiazem hcl',
#   'sig',
#   'citalopram',
#   'aspirin',
#   'metoprolol',
# ...
#   'latanoprost',
#   'xalatan',
#   'levothyroxine',
#   'losartan',
#   'metolazone',
#   'potassium chloride',
#   'protonix',
#   'sertraline',
#   'zoloft',
#   'vancomycin'],
#  177721: ['bactrim ds',
#   'micu',
#   'carboplatin',
#   'gemcitabine',
#   'bevacizumab',
#   'avastin',
#   'vanc',
#   'cefepime',
#   "foley ' d",
#   'baso',
#   'alkphos - 94',
#   'uricacd',
#   'totbili',
#   'cefazolin',
#   'piperacillin',
#   'tazobactam',
#   'mic',
#   'ampicillin',
#   'ampicillin',
#   'sulbactam',
#   'cefazolin',
#   'ceftazidime',
#   'ceftriaxone',
#   'ciprofloxacin',
#   'gentamicin',
#   'meropenem',
#   'piperacillin',
#   'tazo',
#   'tobramycin',
#   'trimethoprim',
#   'sulfa',
#   'quinolones',
#   'mic',
#   'gentamicin',
#   'levofloxacin',
#   'nitrofurantoin',
#   'oxacillin',
#   'trimethoprim',
#   'sulfa',
#   'gemcitabine',
#   'bevacizumab',
#   'avastin',
#   'vanc',
#   'cefepime',
#   'cefepime',
#   'ciprofloxacin',
#   'avastin',
#   'heparin gtt',
#   'carboplatin',
#   'gemcitabine',
#   'bevacizumab',
#   'avastin',
#   'lisinopril',
#   'lisinopril',
#   'docusate sodium',
#   'lisinopril',
#   'ciprofloxacin',
#   'senna',
#   'started - augmentin',
#   'ciprofloxacin'],
#  110499: ['tbi',
#   'cytoxan',
#   'steroid',
#   'ampicillin',
#   'geotrichum',
#   'etoh',
#   'baso',
#   'hco3 - 40',
#   'angap - 10',
#   'totbili',
#   'dirbili',
#   'indbili',
#   'uricacd -',
#   'sildenafil',
#   'albumin',
#   'lasix',
#   'chlorthiazide',
#   'metolazone',
#   'sildenafil',
#   'levofloxacin',
#   'ciprofloxacin',
#   'quinolone',
#   'cefepime',
#   'vancomycin',
#   'cefepime',
#   'flagyl',
#   'meropenem',
#   'adenosine',
#   'adenosine',
#   'verapimil',
#   'verapimil',
#   'iv heparin',
#   'coumadin',
#   'sildenafil',
#   'iv heparin',
#   'warfarin',
#   'vitamin d',
#   'vitamin d',
#   'vitamin d',
#   'bisphosphonate',
#   'cyclosporin',
#   'refresh eye drops',
#   'atenolol',
#   'hydralazine',
#   'prednisone',
#   'valtrex',
#   'vfend',
#   'benzonatate',
#   'azithromycin',
#   'zolpidem',
#   'oxycodone',
#   'odansetron'],
#  112832: ['demerol',
#   'droperidol',
#   'penicillamine',
#   'streptomycin',
#   'ampicillin',
#   'flecanide',
#   'premarin',
#   'flecainide',
#   'flecanide',
#   'coumadin',
#   'diamox',
#   '2 u prbc',
#   'coumadin',
#   'coumadin',
#   'allopurinol',
#   'diazepam',
#   'aspirin',
#   'calcium carbonate',
#   'hydromorphone',
#   'atorvastatin',
#   'allopurinol',
#   'colchicine',
#   'diltiazem hcl',
#   'fluticasone',
#   'furosemide',
#   'diazepam',
#   'gabapentin',
#   'gabapentin',
#   'hydralazine',
#   'metoprolol succinate',
#   'omeprazole',
#   'sertraline',
#   'spironolactone',
#   'acetaminophen',
#   'coumadin',
#   'mwf',
#   'metronidazole',
#   'zofran',
#   'coumadin',
#   'pcp',
#   'coumadin'],
#  101215: ['penicillin',
#   'etoh',
#   'seperate',
#   'esmolol',
#   'lisinopril',
#   'ciprofloxacin',
#   'vancomycin',
#   'atorvastatin',
#   'aspirin',
#   'furosemide',
#   'potassium chloride',
#   'pantoprazole',
#   'labetalol'],
#  117871: ['aspirin',
#   'toprol',
#   'oxycodone',
#   'acetaminophen',
#   'aspirin',
#   'docusate sodium',
#   'simvastatin',
#   'metoprolol tartrate',
#   'camphor - menthol',
#   'ascorbic acid',
#   'folic acid'],
#  125867: ['heparin',
#   'acetaminophen',
#   'olanzapine',
#   'docusate',
#   'senna',
#   'carbidopa',
#   'levodopa',
#   'levothyroxine',
#   'valsartan',
#   'hydrochlorothiazide 80',
#   'lithium'],
#  110068: ['glucose - 133',
#   'basos',
#   'ce',
#   'nicotine patch',
#   'ibuprofen',
#   'prilosec',
#   'po',
#   'tetracycline',
#   'bismuth subsalicylate',
#   'metronidazole'],
#  127741: ['vancomycin',
#   'azithromycin',
#   'ceftriaxone',
#   'ibuprofen',
#   'totbili',
#   'iv vancomycin',
#   'cefepime',
#   'ciprofloxacin',
#   'levofloxacin',
#   'linezolid',
#   'rvr',
#   'aspirin',
#   'aspirin',
#   'aspirin',
#   'aspirin',
#   'linezolid',
#   'levofloxacin',
#   'codeine - guaifenesin',
#   'diltiazem',
#   'linezolid'],
#  190444: ['reglan',
#   'sorbitol',
#   'aspirin',
#   'hydrochlorothiazide',
#   'duoneb',
#   'baso',
#   'vanc',
#   'zosyn',
#   'vancomycin',
#   'morphine',
#   'klonopin prn',
#   'vancomycin',
#   'mirtazapine',
#   'furosemide',
#   'digoxin',
#   'digoxin',
#   'po',
#   'lumigan',
#   'klonopin',
#   'prednisone',
#   'prednisone',
#   'vitamin d3',
#   'protonix',
#   'metoprolol tart',
#   'fluticasone',
#   'tylenol',
#   'klonopin',
#   'klonopin',
#   'albuterol',
#   'tramadol',
#   'bisacodyl',
#   'prednisone',
#   'lumigan',
#   '- lactulose',
#   'amitryptiline',
#   'furosemide',
#   'digoxin',
#   'citalopram',
#   'multivitamin',
#   'levaquin',
#   'prednisone',
#   'miralax',
#   'metoprolol tartrate',
#   'protonix',
#   'fluticasone',
#   'tylenol',
#   'clonazepam',
#   'albuterol sulfate',
#   'prednisone',
#   'bimatoprost',
#   'amitriptyline',
#   'digoxin',
#   'citalopram',
#   'bisacodyl',
#   'lactulose',
#   'sig',
#   'lasix',
#   'vitamin d2',
#   'mirtazapine',
#   'furosemide',
#   'tramadol'],
#  174037: ['sulfonamide',
#   'etoh',
#   'ativan',
#   'lactate',
#   'etoh',
#   'icu',
#   'insulin',
#   'imipenem',
#   'vancomycin',
#   'imipenem',
#   'vancomycin d',
#   'imipenem',
#   'nafcillin',
#   'imipenem',
#   'vanco',
#   'zosyn',
#   'lasix',
#   'afib',
#   'amiodarone',
#   'cta',
#   'metoprolol',
#   'icu',
#   'toprol',
#   'lisinopril',
#   'oxycodone',
#   'acetaminophen',
#   'loperamide',
#   'trazodone',
#   'guaifenesin',
#   'lorazepam',
#   'lorazepam',
#   'lisinopril',
#   'metoprolol succinate',
#   'pantoprazole',
#   'albuterol sulfate',
#   'ipratropium bromide',
#   'amiodarone',
#   'amlodipine',
#   'lasix'],
#  192877: ['penicillins',
#   'morphine',
#   'warfarin',
#   'prbcs',
#   'fibrinoge - 304',
#   'warfarin',
#   'coumadin',
#   'a - fibb',
#   'clindamycin',
#   'coumadin',
#   'statin',
#   'coumadin',
#   'aldactone',
#   'aldacton',
#   'creatinine',
#   'spironolactone',
#   'omeprazole',
#   'atorvastatin',
#   'calcium acetate',
#   'sucralfate',
#   'metoprolol tartrate',
#   'furosemide',
#   'pantoprazole',
#   'spironolactone',
#   'coumadin',
#   'coumadin',
#   'coumadin'],
#  186134: ['augmentin',
#   'biaxin',
#   'sulfa',
#   'sulfonamides',
#   'naprosyn',
#   'motrin',
#   'ruq',
#   'levaquin',
#   'pt',
#   'tylenol',
#   'vancomycin',
#   'solumedrol',
#   'levaquin',
#   'morphine',
#   'benadryl',
#   'ruq',
#   'lactate',
#   'pcn',
#   'augmentin',
#   'gentamicin',
#   'ciprofloxacin 500 q12',
#   'morphine',
#   'levaquin',
#   'morphine',
#   'motrin',
#   'benadryl prn',
#   'famotidine',
#   'prednisone',
#   'creatinine',
#   'prednisone',
#   'albuterol sulfate',
#   'ipratropium bromide',
#   'montelukast',
#   'fluticasone',
#   'prednisone',
#   'pantoprazole',
#   'acetaminophen',
#   'albuterol sulfate',
#   'ipratropium bromide',
#   'montelukast',
#   'fluticasone',
#   'prednisone',
#   'pantoprazole',
#   'acetaminophen',
#   'oxycodone',
#   'acetaminophen',
#   'ciprofloxacin'],
#  175593: ['fentanyl',
#   'midazolam',
#   'asbestos',
#   'glucose - 111',
#   'prbc',
#   'lorazepam',
#   'pulse ox',
#   'pantoprazole',
#   'pantoprazole',
#   'tamsulosin',
#   'tamsulosin',
#   'ciprofloxacin',
#   'lisinopril',
#   'pantoprazole',
#   'pantoprazole',
#   'tamsulosin',
#   'tamsulosin',
#   'ciprofloxacin',
#   'lisinopril',
#   'metoprolol'],
#  151904: ['codeine',
#   'narcan',
#   'narcan',
#   'methadone',
#   'methadone',
#   'vicod',
#   'valium',
#   'baclofen',
#   'baclofen',
#   'gabapentin',
#   'vancomycin',
#   'cftx',
#   'midazolam',
#   'baclofen',
#   'baclofen',
#   'c3 - c6',
#   'atropine',
#   'scopalomine',
#   'midodrine',
#   'benzodiazepine',
#   'diazepam',
#   'methadone',
#   'cipro',
#   'abx',
#   'methadone',
#   'diazepam',
#   'eeg',
#   'cymbalta',
#   'cymbalta',
#   'albuterol',
#   'diazepam',
#   'methadone',
#   'albuterol',
#   'ivf',
#   'coumadin',
#   'cpap',
#   'methadone',
#   'lidocaine',
#   'valium',
#   'gabapentin',
#   'vitamin c',
#   'vitamin d',
#   'miralax',
#   'mucinex',
#   'coumadin',
#   'lasix',
#   'spironolactone',
#   'vicodin',
#   'ketoconazole',
#   'nystatin',
#   'clobetasol',
#   'cymbalta',
#   'citalopram',
#   'methadone',
#   'albuterol',
#   'famotidine',
#   'methadone',
#   'gabapentin',
#   'ascorbic acid',
#   'cholecalciferol',
#   'bisacodyl',
#   'warfarin',
#   'warfarin',
#   'lasix',
#   'spironolactone',
#   'vicodin',
#   'ketoconazole',
#   'clobetasol',
#   'famotidine',
#   'albuterol sulfate',
#   'methadone',
#   'ciprofloxacin',
#   'amoxicillin',
#   'lidocaine',
#   'diazepam',
#   'midodrine',
#   'baclofen',
#   'cymbalta',
#   'cymbalta',
#   'baclofen',
#   'midodrine',
#   'scopolamine',
#   'cymbalta',
#   'mucinex',
#   'methadone',
#   'valium',
#   'baclofen'],
#  195784: ['hepatitis c', 'dirbili', 'indbili', 'radiofrequency'],
#  123771: ['aspirin',
#   'integra',
#   'afib',
#   'coumadin',
#   'clobetasol prn',
#   'finasteride 5',
#   'furosemide 40',
#   'warfarin 5',
#   'cl - - 105',
#   'cl - - 101',
#   'cl - - 101',
#   'calcium',
#   'cl - - 101',
#   'cl - - 101',
#   'freeca',
#   'asa - neg ethanol',
#   'bnzodzpn - neg',
#   'barbitrt - neg',
#   'fibrinoge - 310',
#   'daptomycin',
#   'daptomycin',
#   'daptomycin',
#   'ampicillin',
#   'daptomycin',
#   'linezolid',
#   'vancomycin',
#   'barium',
#   'nectar',
#   'icu',
#   'fentanyl',
#   'propofol',
#   'iv dilaudid',
#   'afib',
#   'albuterol',
#   'lasix',
#   'albumin',
#   'vanc',
#   'zosyn',
#   'clinda',
#   'clindamycin',
#   'vancomycin',
#   'lovenox',
#   'xeroform',
#   'kerlix',
#   'allopurinol 100',
#   'atenolol 50',
#   'clobetasol prn',
#   'finasteride 5',
#   'furosemide 40',
#   'warfarin 5',
#   'acetaminophen',
#   'albuterol',
#   'allopurinol',
#   'atenolol',
#   'docusate sodium',
#   'enoxaparin sodium',
#   'finasteride',
#   'folic acid',
#   'thiamine',
#   'lansoprazole',
#   'oxycodone',
#   'terazosin',
#   'simvastatin'],
#  120301: ['g - tube',
#   'aox2',
#   'albumin',
#   'fdg',
#   'lacunar',
#   'pneumomediastinum',
#   'tracheostomy',
#   'eos',
#   'totbili',
#   'etoh',
#   'docetaxel',
#   'cisplatin',
#   '5fu',
#   'olanzapine',
#   'po',
#   'heparin ggt',
#   'cefepime',
#   'vancomycin',
#   'xrt',
#   'cetuximab',
#   'cetuximab',
#   'trach',
#   'enoxaparin',
#   'acyclovir',
#   'xrt',
#   'vancomycin',
#   'cefepime',
#   'metronidazole',
#   'guaifenesin',
#   'tramadol',
#   'acetaminophen prn',
#   'bacitracin',
#   'polymyxin b',
#   'vzv',
#   'acyclovir',
#   'gabapentin',
#   'gabapentin',
#   'acetaminophen',
#   'tramadol prn',
#   'cetuximab',
#   'caphasol',
#   'maalox',
#   'diphenhydramine',
#   'lidocaine',
#   'cetuximab',
#   'heparin gtt',
#   'aspirin',
#   'heparin gtt',
#   'enoxaparin',
#   'heparin gtt',
#   'heparin 5000',
#   'heparin sc ppx',
#   'furosemide',
#   'metolazone',
#   'loperamide',
#   'furosemide',
#   'metolazone',
#   'insulin glargine',
#   'amlodipine',
#   'metoprolol',
#   'amlodipine',
#   'amlodipine',
#   'lisinopril',
#   'lisinopril',
#   'pvcs',
#   'metoprolol',
#   'statin',
#   'citalopram',
#   'miconazole',
#   'gabapentin',
#   'acetaminophen prn',
#   'furosemide',
#   'gabapentin',
#   'lansoprazole',
#   'lisinopril',
#   'omeprazole',
#   'lansoprazole',
#   'prochlorperazine maleate',
#   'ondansetron hcl',
#   'amlodipine',
#   'nystatin',
#   'simvastatin',
#   'fluticasone',
#   'bisacodyl',
#   'miconazole nitrate',
#   'lidocaine - diphenhyd',
#   'loperamide',
#   'folic acid',
#   'cholecalciferol',
#   'chlorhexidine gluconate',
#   'acyclovir',
#   'heparin',
#   'acetaminophen',
#   'metoprolol tartrate',
#   'tramadol',
#   'citalopram',
#   'lisinopril',
#   'senna',
#   'magnesium hydroxide',
#   'gabapentin',
#   'docusate sodium',
#   'polyethylene glycol',
#   'acetaminophen',
#   'cetuximab',
#   'cetuximab',
#   'cetuximab',
#   'docetaxel',
#   'cisplatin',
#   '5fu',
#   'cetuximab',
#   'acyclovir',
#   'cetuximab',
#   'cetuximab'],
#  111923: ['ativan',
#   'lidocaine',
#   'basos',
#   'lactate',
#   'lactate',
#   'ativan',
#   'dilantin',
#   'dilantin',
#   'ativan',
#   'dilantin',
#   'dilantin',
#   'dilantin',
#   'cefepime',
#   'vanco',
#   'dilantin',
#   'metoprolol',
#   'alendronate',
#   'doxepin',
#   'advair diskus',
#   'methenamine hippurate',
#   'paroxetine',
#   'dilantin',
#   'ranitidine',
#   'spiriva',
#   'levocarnitine',
#   'alendronate sodium',
#   'cefepime',
#   'cefepime',
#   'phenytoin infatab',
#   'dilantin',
#   'tiotropium bromide',
#   'vancomycin',
#   'vancomycin',
#   'docusate sodium',
#   'doxepin hcl',
#   'paroxetine',
#   'cyanocobalamin',
#   'bisacodyl',
#   'metoprolol tartrate',
#   'dilantin',
#   'lorazepam',
#   'lorazepam',
#   'phenytoin infatab',
#   'pseudobulbar',
#   'dilantin'],
#  114923: ['sulfa',
#   'sulfonamides',
#   'coumadin',
#   'cipro',
#   'flagyl',
#   'pafib',
#   'etoh',
#   'coumadin',
#   'coumadin',
#   'lactate',
#   'pantoprazole',
#   'sarna',
#   'pantoprazole',
#   'propafenon',
#   'diltiazem',
#   'enalapril',
#   'tylenol',
#   'oxycodone',
#   'diltiazem hcl',
#   'enalapril maleate',
#   'furosemide',
#   'propafenone',
#   'oxycodone',
#   'acetaminophen',
#   'propafenone',
#   'sig',
#   'sig',
#   'docusate sodium',
#   'aspirin',
#   'enalapril maleate',
#   'furosemide',
#   'rhythmol sr',
#   'furosemide',
#   'lasix'],
#  130440: ['pneumovax',
#   'warfarin',
#   'etoh',
#   'ivf',
#   'metronidazole',
#   'levofloxacin',
#   'vancomycin',
#   'etoh',
#   'pneumococcal vaccine',
#   'pneumococcal vaccine',
#   'beta blocker',
#   'vanco',
#   'flagyl',
#   'infitlrate',
#   'lasix',
#   'pneumovax',
#   '2 - 3l',
#   'pt',
#   'flecainide',
#   'metoprolol',
#   'heparin',
#   'metoprolol',
#   'divalproex',
#   'olanzapine',
#   'topirimate',
#   'citalopram',
#   'flecainide',
#   'acetaminophen',
#   'hexavitamin',
#   'flecainide',
#   'aspirin',
#   'pantoprazole',
#   'divalproex',
#   'divalproex',
#   'olanzapine',
#   'topiramate',
#   'citalopram',
#   'pneumovax',
#   'pneumovax',
#   'beta blocker',
#   'metoprolol'],
#  118510: ['codeine',
#   'doxycycline',
#   'bigeminy',
#   'caltco2',
#   'vancomycin',
#   'cipro',
#   'flagyl',
#   'zofran',
#   'protonix',
#   'reglan',
#   'iv lasix',
#   'morphine',
#   'pca',
#   'erythromycin',
#   'lorazepam',
#   'ativan',
#   'sertraline',
#   'hydrocodone',
#   'acetaminophen',
#   'tylenol',
#   'acetaminophen',
#   'acetaminophen',
#   'pantoprazole',
#   'aspirin',
#   'ondansetron',
#   'lorazepam',
#   'prochlorperazine maleate',
#   'ibuprofen',
#   'acetaminophen'],
#  174150: ['imodium',
#   'lactate',
#   'kayexalate',
#   'cefepime',
#   'zofran',
#   'tylenol',
#   'kayexalate',
#   'navelbine',
#   'cetuximab',
#   'oxaliplatin',
#   'avastin',
#   'sorafenib',
#   'unasyn',
#   'lasix',
#   'ivf',
#   'hctz',
#   'verpamil',
#   'lisinopril',
#   'glipizide',
#   'verapamil',
#   'lisinopril',
#   'lovastin',
#   'prilosec',
#   'vitamin c',
#   'multivitamin po',
#   'hydrochlorothiazide',
#   'reglan',
#   'naproxen',
#   'hexavitamin',
#   'hydrochlorothiazide',
#   'verapamil',
#   'lisinopril',
#   'glipizide',
#   'metformin',
#   'nebulizer',
#   'albuterol - ipratropium',
#   'lovastatin',
#   'prilosec',
#   'augmentin'],
#  107047: ['bactrim',
#   'dicloxacillin',
#   'levofloxacin',
#   'pmh',
#   'vancomycin',
#   'cefepime',
#   'methotrexate',
#   'hydrocort',
#   'cytarabine',
#   'coag - neg',
#   'aaox3',
#   'totbili',
#   'totbili',
#   'uricacd',
#   'ciprofloxacin',
#   'gentamicin',
#   'tobramycin',
#   'cefepime',
#   'vanco',
#   'cefepime',
#   'vancomycin',
#   'flagyl',
#   'ampicillin',
#   'daptomycin',
#   'levofloxacin',
#   'linezolid',
#   'ampicillin',
#   'amp',
#   'methotrexate',
#   'cefepime',
#   'gentamicin',
#   'linezolid',
#   'gentamicin',
#   'linezolid',
#   'linezolid',
#   'amp',
#   'cefepime',
#   'cytarabine',
#   'cytarabine',
#   'vinorelbine',
#   'acyclovir',
#   'fluconazole',
#   'pentamidine',
#   'metoprolol',
#   'lovenox',
#   'levothyroxine',
#   'citalopram',
#   'acyclovir',
#   'clonazepam',
#   'levothyroxine',
#   'pyridoxine',
#   'docusate sodium',
#   'hydromorphone',
#   'enoxaparin',
#   'filgrastim',
#   'dexamethasone',
#   'clonazepam',
#   'levothyroxine',
#   'pyridoxine',
#   'docusate sodium',
#   'nystatin',
#   'senna',
#   'sig',
#   'gabapentin',
#   'oxycodone',
#   'hydromorphone',
#   'dexamethasone',
#   'citalopram',
#   'metoprolol tartrate',
#   'metoprolol',
#   'celexa',
#   'acyclovir',
#   'fluconazole'],
#  115157: ['dopamine',
#   'levofed',
#   'totbili',
#   'minoxidil',
#   'levophed',
#   'levophed',
#   'coumadin',
#   'carvedilol',
#   'spironolactone',
#   'ekg',
#   'troponin',
#   'asa',
#   'plavix',
#   'atorvostatin',
#   'atenolol',
#   'atn',
#   'dopamine',
#   'lasix gtt',
#   'atenolol',
#   'creatinine',
#   'azotemia',
#   'coumadin',
#   'warfarin',
#   'warfarin',
#   'insulin',
#   'po',
#   'hydralazine',
#   'minoxidil',
#   'coumadin',
#   'plavix',
#   'benicar',
#   'aspirin',
#   'atenolol',
#   'isosorbide mononitrate',
#   'spironolactone',
#   'folic acid',
#   'hydralazine',
#   'coumadin',
#   'gabapentin',
#   'minoxidil',
#   'pletal',
#   'cilostazol',
#   'aldactone',
#   'atorvastatin',
#   'clopidogrel',
#   'aspirin',
#   'warfarin',
#   'insulin nph',
#   'furosemide',
#   'enoxaparin',
#   'folic acid',
#   'ct',
#   'ct',
#   'warfarin',
#   'warfarin',
#   'furosemide',
#   'enoxaparin',
#   'atorvastatin',
#   'warfarin',
#   'plavix',
#   'aspirin',
#   'folic acid',
#   'minoxidil',
#   'hydralazine',
#   'isosorbide',
#   'mononitrate',
#   'spironolactone',
#   'cilostazol',
#   'atenolol',
#   'enoxaparin']}

# %%
certain_adv_entities
# Out:
# {108809: ['abdominal pain',
#   'chest and abdominal pain',
#   'odynophagia',
#   'mediastinal contours',
#   'bibasilar atelectasis',
#   'prominence of the central pulmonary vasculature',
#   'pneumothorax',
#   'mediastinal prominence',
#   'chest ct of the chest',
#   'emphysema',
#   'coronary calcification',
#   'gallbladder',
#   'cbd',
#   'hydronephrosis',
#   'sigmoid diverticula',
#   'ventral hernia',
#   'ulceration',
#   'ulcerating atherosclerotic plaques',
#   'focal irregularity',
#   'ectasia',
#   'aortic aneurysm',
#   'hemorrhagic',
#   'diverticulosis',
#   'coronary artery calcifications',
#   'hemorrhage',
#   'edema',
#   'mass',
#   'mass effect',
#   'infarction',
#   'paranasal sinuses',
#   'hemorrhage',
#   'mass',
#   'mass effect',
#   'acute infarction',
#   'bibasilar atelectasis',
#   'effusions',
#   'nodules',
#   'pneumothorax',
#   'pericardial fluid',
#   'coronary artery calcification',
#   'cbd',
#   'diverticula',
#   'ascites',
#   'high - density thickening of the aortic wall',
#   'hematoma',
#   'descending aorta ulceration',
#   'focal aortic aneurysm',
#   'distal infrarenal aortic aneurysm',
#   'diverticulosis',
#   'coronary artery calcifications',
#   'emphysema',
#   'epigastric pain',
#   'ct of the chest',
#   'bilateral pleural effusions',
#   'atherosclerotic calcification',
#   'pericardial effusion',
#   'left adrenal nodule',
#   'hydronephrosis',
#   'foley',
#   'descending colon diverticulosis',
#   'patent celiac trunk',
#   'aortic ulcerations',
#   'distal infrarenal aortic aneurysm',
#   'right adrenal nodule',
#   'delerious',
#   'upper abdominal pain',
#   'retro sternal pain',
#   'compressive thrombus',
#   'abdominal pain',
#   'urinary tract infection',
#   'constipation',
#   'groin puncture',
#   'numbness',
#   'coldness',
#   'pain'],
#  115143: ['allergies',
#   'abdominal pain',
#   'nausea',
#   'vomitting',
#   'nausea',
#   'abdominal pain',
#   'sinusitis',
#   'sinus infection',
#   'epigastric abdominal pain',
#   'sinusitis',
#   'increased nausea',
#   'hematemesis',
#   'polydypsia',
#   'sweats',
#   'chills',
#   'weight loss',
#   'orthopnea',
#   'bowel of bladder dysfunction',
#   'limb weakness',
#   'sensory changes',
#   'hypoglycemia',
#   'sweating',
#   'palpitations',
#   'anxiety',
#   'periperal neuropathy',
#   'scleral icterus',
#   'effusion',
#   'pneumothorax',
#   'acute pulmonary process',
#   'nausea',
#   'epigastric pain',
#   'vomitting',
#   'hematemesis',
#   'dka',
#   'eye problems',
#   'kidney disease',
#   'worse leg numbness',
#   'heart disease',
#   'irritated the lining of your stomach',
#   'vomitting',
#   'abdominal pain',
#   'stomach pain'],
#  159079: ['tracheal - bronchial atresia',
#   'subglottic stenosis',
#   'brown phlegm',
#   'tracheal stenosis',
#   'stridor',
#   'hypoxic',
#   'bradycardic',
#   'right lung hypoplasia',
#   'sinusitis',
#   'seizure disorder',
#   'sclera anicteric',
#   'rales',
#   'organomegaly',
#   'pneumothorax',
#   'pulmonary parenchymal infiltrate',
#   'acute pulmonary abnormalities',
#   'hypoplasia',
#   'tracheomalacia',
#   'subglotic stenosis',
#   'laryngospasm',
#   'respiratory distress',
#   'subglottic edema',
#   'hoarseness',
#   'body rash'],
#  102027: ['diarrhea',
#   'diarrhea',
#   'chest pain',
#   'bloody stools',
#   'epistaxis',
#   'hematemesis',
#   'hypothyroidism',
#   'small bilateral pleural effusions',
#   'pneumothorax',
#   'diarrhea',
#   'hypotension',
#   'hypotensive',
#   'hypotension',
#   'cad',
#   'cabg x2',
#   'hypotension',
#   'bleeding of r big toe',
#   'qid prn pain',
#   'limb pain',
#   'hypotension 3',
#   'myocardial infarction',
#   'hypothyroidism 5',
#   'dizziness',
#   'chest pain',
#   'blood in stool',
#   'vomiting blood',
#   'blood in urine'],
#  102296: ['low hematocrit',
#   'diarrhea',
#   'vomiting',
#   'gi bleed',
#   'sinus tachycardia',
#   'inferior myocardial infarction',
#   'pulmonary edema',
#   'acute hematocrit drop',
#   'guaiac positive stool',
#   'chronic anemia',
#   'hypernatremia',
#   'hypernatremia',
#   'aphasia',
#   'right sided weakness',
#   'gi bleed',
#   'cataracts',
#   'glaucoma',
#   'guaiac + stools',
#   'hypernatremia',
#   'hemiparesis',
#   'aphasia',
#   'dementia',
#   'hypertension',
#   'glaucoma',
#   'cataracts',
#   'blood count',
#   'bleeding from your gi tract'],
#  114976: ['decreased mental status',
#   'respiratory failure',
#   'congestive heart failure',
#   'coronary artery disease',
#   'allergies',
#   'bibasilar crackles',
#   'bilateral edema',
#   'pneumonia',
#   'congestive heart failure flare',
#   'diabetes mellitus'],
#  128041: ['syncope',
#   'generalized seizure',
#   'generalized convulsion',
#   'generalized convulsion',
#   'coagulopathy',
#   'aneurysms',
#   'aneurysms',
#   'right lower facial droop',
#   'subarachnoid hemorrhage',
#   'aneurysm',
#   'aneurysms',
#   'aneurysm',
#   'regional systolic dysfunction',
#   'mitral regurgitation',
#   'left ica stenosis',
#   'pleural calcifications',
#   'atelectasis',
#   'gastric pull - up',
#   'increased echogenicity',
#   'biliary abnormality',
#   'subarachnoid hemorrhage',
#   'myoclonic jerks',
#   'intraparenchimal bleed',
#   'bleed',
#   'left mca infarct',
#   'thromboembolization',
#   'retroperitoneal bleed',
#   'worsening anemia',
#   'tachycardic',
#   'retroperitoneal hematoma',
#   'hypotensive',
#   'respiratory failure',
#   'increased respiration rate',
#   'pna',
#   'leukocytosis',
#   'klebsiella',
#   'serratia',
#   'staph aureus',
#   'leukocytosis',
#   'erythema',
#   'swelling',
#   'left frontotemporal intraparenchymal hemorrhage',
#   'subarachnoid hemorrhage',
#   'dysarthric',
#   'right lower facial droop',
#   'seizures',
#   'intracranial hemorrhage',
#   'stroke',
#   'weakness',
#   'visual changes',
#   'lightheadedness',
#   'shortness of breath'],
#  123244: ['back pain',
#   'chest pain',
#   'shortness of breath',
#   'sweats',
#   'hemoptysis',
#   'night sweats',
#   'changes in vision',
#   'headache',
#   'shortness of breath',
#   'chest pain',
#   'vomiting',
#   'abdominal pain',
#   'diarrhea',
#   'numbness',
#   'back pain',
#   'holosystolic murmur',
#   'tenderness to palpation',
#   'cyanosis',
#   'edema',
#   'decreased visual acuity',
#   'lid lag',
#   'nystagmus',
#   'ptosis',
#   'trapezius',
#   'brachioradialis',
#   'decreased patellar reflexes',
#   'paraspinal mass',
#   'epidural mass',
#   'granulomatous disease',
#   'spondylolisthesis',
#   'focal disc protrusion',
#   'paraspinal mass',
#   'kyphotic angulation of the thoracic spine',
#   'emphysematous changes in the lungs',
#   'aortic calcifications',
#   'gallbladder',
#   'left adrenal gland nodule',
#   'retroperitoneal lymphadenopathy',
#   'calcifications',
#   'diastolic dysfunction',
#   'right ventricular cavity size',
#   'aortic valve stenosis',
#   'aortic regurgitation',
#   'systolic prolapse',
#   'mitral regurgitation',
#   'pericardial effusion',
#   'mural thickening',
#   'centrilobular emphysema',
#   'focal pleural thickening',
#   'lung nodules',
#   'bibasilar hydrostatic interstitial edema',
#   'pneumothorax',
#   'vacuolated cytoplasm',
#   'epidural mass',
#   'bradycardic arrest',
#   'complete heart block',
#   'upper extremity venous clot',
#   'delerium',
#   'back pain',
#   'decreased patellar reflexes',
#   'leg weakness',
#   'sensory deficits',
#   'bowel / bladder incontinence',
#   'epidural mass',
#   'hemoptysis',
#   't7 collapse',
#   'staph aureus',
#   'endocarditis',
#   'lung nodules',
#   'inflammation',
#   'chest pain',
#   'lateral st depressions',
#   'asystole',
#   'bradycardia',
#   'anemia',
#   'hemoptysis',
#   'hematemesis',
#   'melena',
#   'hematochezia',
#   'guaiac positive stool',
#   'delirium',
#   'diarrhea',
#   'diarrhea',
#   'iliac artery dissections',
#   'clot',
#   'shortness of breath',
#   'hypokalemia',
#   'standing potassium repletion',
#   'acute blood loss anemia hypokalemia hypocalcemia',
#   'illiac artery dissections'],
#  111458: ['nausea',
#   'abdominal crampy pain',
#   'radiologic and biochemical progression',
#   'hypothyroidism',
#   'cerebrovascular accident',
#   'jaundice',
#   't wave abnormalities',
#   'bilateral pulmonary nodules',
#   'small bilateral pleural effusions',
#   'atelectasis',
#   'pneumothorax',
#   'intracranial hemorrhage',
#   'encephalomalacia',
#   'diarrhea',
#   'diarrhea',
#   'profuse diarrhea',
#   'acutely hypotensive',
#   'aspiration pneumonia',
#   'acute decompensation',
#   'worsening renal function',
#   'microperforations',
#   'sbp',
#   'acute renal failure',
#   'bandemia'],
#  110863: ['generalized weakness',
#   'odynophagia',
#   'odynophagia',
#   'odynophagia',
#   'odynophagia',
#   'dysphagia',
#   'pancytopenia',
#   'pleural effusion',
#   'pneumonia',
#   'bilateral pleural effusions',
#   'fever',
#   'chills',
#   'blurry vision',
#   'diplopia',
#   'loss of vision',
#   'photophobia',
#   'headache',
#   'sinus tenderness',
#   'rhinorrhea',
#   'congestion',
#   'chest pain',
#   'palpitations',
#   'lower extremity edema',
#   'cough',
#   'shortness of breath',
#   'wheezes',
#   'vomiting',
#   'diarrhea',
#   'constipation',
#   'abdominal pain',
#   'melena',
#   'hematemesis',
#   'hematochezia',
#   'bruising',
#   'lymphadenopathy',
#   'stool',
#   'urine incontinence',
#   'rashes',
#   'skin breakdown',
#   'numbness',
#   'upper gi bleed',
#   'right pleural effusion',
#   'pulmonary vascular congestion',
#   'atelectatic changes',
#   'pleural effusion',
#   'confusion',
#   'dyspnea',
#   'odynophagia',
#   'generalized weakness',
#   'wheezing',
#   'coughs',
#   'chf',
#   'tachypnea',
#   'delirium',
#   'head bleed',
#   'uremia',
#   'hypotension',
#   'odynophagia',
#   'mucositis',
#   'thrush',
#   'pancytopenic',
#   'thrombocytopenia'],
#  188551: ['dementia',
#   'worsened shortness of breath',
#   'pulmonary embolus',
#   'slurred speech',
#   'hypertension',
#   'asthma',
#   'peripheral neuropathy',
#   'dementia',
#   'grimmaces',
#   'intraparenchymal hemorrhage',
#   'herniation',
#   'large left frontoparietal intraparenchymal hemorrhage',
#   'midline shift',
#   'uncal herniation',
#   'ich',
#   'increased weakness',
#   'worsened facial droop',
#   'fever'],
#  101331: ['allergies',
#   'hypothermia',
#   'bradycardia',
#   'thrombocytopenia',
#   'organomegaly',
#   'guaiac negative',
#   'pancytopenia',
#   'hypothyroidism',
#   'hypothyroidism',
#   'pancytopenia',
#   'hyponatremic',
#   'constipation',
#   'bradycardia',
#   'overdry',
#   'hypothyroidism',
#   'pancytopenia',
#   'anemia',
#   'leukopenia',
#   'thrombocytopenia',
#   'bradycardia',
#   'hypothermia',
#   'constipation',
#   'bradycardia',
#   'acute renal failure',
#   'chronic renal insufficiency',
#   'left lower lobe pneumonia',
#   'chest pain',
#   'shortness of breath',
#   'palpitations',
#   'confusion',
#   'dizziness',
#   'decreased urine or stool output',
#   'lightheadedness',
#   'loss of consciousness'],
#  109667: ['hypotension',
#   'fever',
#   'nhl t - cell',
#   'hypotension',
#   'fever',
#   'watery diarrhea',
#   'pruritic rash',
#   'chills',
#   'flushing',
#   'dysuria',
#   'cloudy urine',
#   'renal failure',
#   'hypercholesterolemia 4',
#   'congenital abnormalities of the fingers',
#   'generalized arthralgias',
#   'fibromyalgia 7',
#   'glaucoma 8',
#   'lymphomatoid granulomatosis',
#   'cns lymphoma',
#   'obese abdomen',
#   'rash',
#   'sinus tachycardia',
#   'platelike atelectasis',
#   'reactive lymphadenopathy',
#   'hypotension',
#   'fever',
#   'hypotension',
#   'anaphylactic reaction',
#   'anaphylactic reaction',
#   'dizziness',
#   'fever',
#   'headache',
#   'nausea',
#   'vomiting',
#   'rash'],
#  106629: ['allergies',
#   'heart murmur dysphagia',
#   'rash',
#   'respiratory distress',
#   'disoriented',
#   'diahrrea',
#   'anxiety',
#   'leucocytosis',
#   'acidosis',
#   'vomiting',
#   'diahrrea',
#   'mental status change',
#   'nausea',
#   'vomiting',
#   'diarrhea',
#   'runny nose',
#   'confusion'],
#  116451: ['cirrhosis',
#   'hcc',
#   'esophageal varices',
#   'portal hypertensive gastropathy',
#   'rectal varices',
#   'mother - colon cancer',
#   'nd',
#   'patent vasculature',
#   'patent vasculature',
#   'focal fluid collections',
#   'pneumobilia',
#   'hypertensive',
#   'rhonchi',
#   'fluid oveloaded',
#   'foley',
#   "lft ' s increased",
#   'stricture',
#   'hyperglycemia',
#   'vna'],
#  102365: ['dyspnea',
#   'renal failure',
#   'anemia',
#   'fluid overload',
#   'edema',
#   'fatigue',
#   'lightheadness',
#   'pillow orthopnea',
#   'cough',
#   'vomiting',
#   'abdominal pain',
#   'melena',
#   'brbpr',
#   'peripheral edema',
#   'sinus tenderness',
#   'rhinorrhea',
#   'congestion',
#   'nausea',
#   'vomiting',
#   'diarrhea',
#   'abdominal pain',
#   'sinus node dysfunction',
#   'tricuspid regurgitation',
#   'chronic obstructive pulmonary disease',
#   'idiopathic pulmonary fibrosis',
#   'chronic kidney disease',
#   'anemia',
#   'hypertension',
#   'hypercholesterolemia',
#   'hypothyroidism',
#   'sclera anicteric',
#   'increased pigmentation bilateral cheeks',
#   'dry oral mucosa',
#   'tachycardia',
#   'decreased breath sounds',
#   'pitting edema',
#   'pleural effusions',
#   'parenchymal opacities',
#   'cholelithiasis',
#   'diverticulitis',
#   'sludge',
#   'acute cholecystitis',
#   'dilated hepatic veins',
#   'acute intracranial abnormality',
#   'diffuse cerebral atrophy',
#   'focal high grade dysplasia',
#   'worsening dyspnea',
#   'acute renal failure',
#   'fluid overload',
#   'brown stool',
#   'anemia',
#   'perforation',
#   'hypoxemic respiratory failure',
#   'dyspnea',
#   'diuresis',
#   'epistaxis',
#   'bloody post - nasal drip',
#   'dyspneic',
#   'rul hap',
#   'progressive respiratory distress',
#   'respiratory distress',
#   'mucus plug',
#   'pulmonary edema',
#   'respiratory distress',
#   'hypoxia',
#   'acidemia',
#   'rising wbc',
#   'decreased stool output',
#   'epistaxis',
#   'acute renal failure',
#   'oscillating renal function',
#   'hypovolemia',
#   'esophageal varices',
#   'pulmonary fibrosis',
#   'hypernatremia',
#   'hypernatremic',
#   'c . difficile infection',
#   'gi bleed',
#   'arrythmia',
#   'hypernatremia',
#   'left kidney mass',
#   'respiratory compromise',
#   'colonic lesion'],
#  107251: ['macrobid',
#   'hyperlipidemia',
#   'chf',
#   'dizziness',
#   'hypotension',
#   'vt',
#   'vt',
#   'presyncopal attacks',
#   'chest pain',
#   'palpitations',
#   'diarrhoea',
#   'vomiting',
#   'dark stool',
#   'vomiting',
#   'abdominal pain',
#   'rbbb',
#   'lafb',
#   'left atrial abnormality',
#   'sclera anicteric',
#   'pallor',
#   'xanthalesma',
#   'chest wall deformities',
#   'scoliosis',
#   'kyphosis',
#   'crackles',
#   'wheezes',
#   'rhonchi',
#   'abdominial bruits',
#   'femoral bruits',
#   'ventricular premature beats',
#   'right bundle - branch block',
#   'left anterior fascicular block',
#   'st - t wave abnormalities',
#   'ventricular ectopy',
#   'pulmonary congestion',
#   'rbbb',
#   'left atrial abnormality',
#   'akinesis',
#   'aneursymal deformity of apical walls',
#   'mitral regurgitation',
#   'pasp',
#   'diffuse bulge of abdomen',
#   'umbilical hernia',
#   'bowel obstruction',
#   'left ventricular enlargement',
#   'left ventricular aneurysm',
#   'right lower lobe nodule',
#   'multiple renal hypodensities',
#   'atrial septal defect',
#   'thrombus',
#   'ventricular septal defect',
#   'mitral regurgitation',
#   'pericardial effusion',
#   'hyper',
#   'orthopnea',
#   'rbbb',
#   'lafb',
#   'left atrial abnormality',
#   'atrial tachycardia',
#   'progressive second degree heart block',
#   'septic picture',
#   'worsening renal failure',
#   'anasarca',
#   'acute wound dehiscence',
#   'cardiac arrest',
#   'arrythmias',
#   'diuresis',
#   'hypotension',
#   'fevers',
#   'skin breakdown',
#   'blood loss',
#   'dark stool',
#   'groin wounds'],
#  109191: ['subcutaneous nodules',
#   'melanoma',
#   'right groin subcutaneous nodules',
#   'subcutaneous nodules',
#   'tachypnea',
#   'stridor',
#   'respiratory distress',
#   'hypoxia',
#   'hypotensive',
#   'clostridium difficile diarrhea',
#   'diarrhea',
#   'acute renal failure',
#   'hyperbilirubinemia',
#   'transaminitis',
#   'thrombocytopenic',
#   'metabolic acidosis',
#   'respiratory failure',
#   'coagulopathy',
#   'myocarditis',
#   'respiratory failure',
#   'acute renal failure',
#   'pain'],
#  164366: ['fever',
#   'vomiting',
#   'diarrhea',
#   'fevers',
#   'pruritis',
#   'abdominal pain',
#   'nausea',
#   'vomiting',
#   'diarrhea',
#   'fever',
#   'chills',
#   'diverticulitis',
#   'appendicitis',
#   'watery diarrhea',
#   'dyslipidemia',
#   'peptic ulcer disease',
#   'low back pain',
#   'gastritis',
#   'depression',
#   'right ventricular chamber size',
#   'aortic regurgitation',
#   'mitral valve prolapse',
#   'pericardial effusion',
#   'sclera anicteric',
#   'cyanosis',
#   'edema',
#   'rash',
#   'appendicitis',
#   'bowel obstruction',
#   'free air',
#   'diverticulosis of the sigmoid',
#   'nausea',
#   'vomting',
#   'diarrhea',
#   'weakness',
#   'fevers',
#   'chills',
#   'pruritis',
#   'abdominal pain',
#   'fever',
#   'tachycardia',
#   'hypotension',
#   'elevated lactate',
#   'pruritis',
#   'facial erythema',
#   'abdominal pain',
#   'diarrhea',
#   'vomiting',
#   'hypotension',
#   'hyperlipidemia',
#   'anaphylaxis',
#   'coronary artery disease',
#   'hypertension',
#   'hypercholesterolemia',
#   'allergy',
#   'nausea',
#   'vomiting',
#   'shortness of breath',
#   'palpitations',
#   'throat swelling'],
#  112747: ['aortic stenosis',
#   'aortic valve stenosis',
#   'chest pain',
#   'dyspnea',
#   'syncope',
#   'palpitations',
#   'orthopnea',
#   'pnd',
#   'pedal edema',
#   'aortic stenosis',
#   'myocardial infarction',
#   'dyslipidemia',
#   'hypertension',
#   'hypothyroid',
#   'bleeding',
#   'transmitted murmur',
#   'lymphadenopathy',
#   'bibasilar crackles',
#   'warm tr edema',
#   'erythema',
#   'thrombus',
#   'atrial septal defect',
#   'right ventricular chamber size',
#   'atheroma',
#   'aortic regurgitation',
#   'mitral regurgitation',
#   'urinary retention',
#   'aortic stenosis',
#   'myocardial infarction',
#   'dyslipidemia',
#   'hypertension',
#   'hypothyroid',
#   'bleeding',
#   'sternal pain',
#   'erythema'],
#  106621: ['altered mental status',
#   'polyuria',
#   'ruq tenderness',
#   'stool incontinence',
#   'dyspneic',
#   'altered mental status',
#   'hypoxic respiratory failure',
#   'lp',
#   'dyspnea',
#   'diabetes insipidus',
#   'velcade',
#   'lytic bone lesions',
#   'diabetes insipidus - dx',
#   'hypertension',
#   'hypercholesterolemia 7',
#   'osteoarthritis s / p',
#   'dm',
#   'hepatosplenomegaly',
#   'cyanosis',
#   'edema',
#   'lp',
#   'altered mental status',
#   'meningitis',
#   'afebrile',
#   'multiple myeloma',
#   'psychosis',
#   'diabetes insipidus',
#   'pe and pa hypertension',
#   'gait instability',
#   'hypertension',
#   'change in mental status',
#   'paroxysmal atrial fibrillation',
#   'hypertension',
#   'osteoarthritis s / p',
#   'obstructive pulmonary disease'],
#  114735: ['allergies',
#   'drowsiness',
#   'seizures',
#   'cough',
#   'dyspnea',
#   'bradycardia',
#   'hypothermia',
#   'cough',
#   'drowsiness',
#   'diarrhea',
#   'bradycardia',
#   'grand mal seizure',
#   'qt - prolongation',
#   'av - block',
#   'rhythmic right shoulder jerks',
#   'contact dermatitis',
#   'normocephalic',
#   'conjunctival pallor',
#   'scleral icterus',
#   'vertical nystagmus',
#   'asterixis',
#   'diffuse atrophy of the brain parenchyma',
#   'acute large vascular territory infarct',
#   'effusions',
#   'pneumothorax',
#   'neuro',
#   'apnea',
#   'rash',
#   'hypothermia',
#   'hypothermia',
#   'sepsis',
#   'seizure frequency'],
#  114836: ['malnourishment',
#   'eleveated',
#   'phos',
#   'meropenum',
#   'bile leak',
#   'acute cellular rejection',
#   'biliary obstruction',
#   'luminal stenosis',
#   'biliary obstruction',
#   'ischemia',
#   'severe bilateral upper and lower extremity tremors',
#   'ataxic gait',
#   'tfts',
#   'left hemipheric lesions',
#   'pleiocytosis',
#   'nephrogenic systemic fibrosis',
#   'nephrogenic fibrosing dermopathy',
#   'tremors',
#   'biliary stricture',
#   'tremors',
#   'nausea',
#   'vomiting',
#   'worsening tremors',
#   'abdominal pain',
#   'diarrhea'],
#  109566: ['low urine output',
#   'hypertension',
#   'dyslipidemia',
#   'peripheral neuropathy',
#   'arrhythmia',
#   'acute distress',
#   'sanguinous drainage',
#   'eccymosis medial',
#   'calf tenderness',
#   'engorged pulmonary vasculature',
#   'atelectasis',
#   'hematuria',
#   'urinary retention',
#   'erythema',
#   'low urine output',
#   'anemia',
#   'focal neurologic deficits',
#   'cad',
#   'hyperlipidemia',
#   'increased swelling',
#   'decreased sensation',
#   'shaking chills',
#   'increasing redness',
#   'chest pain',
#   'constipation',
#   'deep vein thrombosis',
#   'blood clots',
#   'redness',
#   'thick yellow drainage'],
#  101857: ['black tarry stools',
#   'hematemasis',
#   'clots',
#   'n / v',
#   'abdominal pain',
#   'chest pain',
#   'sob',
#   'rhonchi',
#   'crackles',
#   'edema neuro',
#   'asterixis',
#   'patent portal vein',
#   'varices',
#   'portal hypertension',
#   'ascites',
#   'acute cardiopulm processes',
#   'minor right basilar atelectasis',
#   'small right pleural effusion',
#   'hydronephrosis',
#   'calculi',
#   'ascites',
#   'varices',
#   'granularity',
#   'friability',
#   'erythema',
#   'congestion',
#   'abnormal vascularity',
#   'duodenum',
#   'bleeding',
#   'rising bili / inr',
#   'hepatorenal syndrome',
#   'renal failure',
#   'upper gi bleed',
#   'esophageal variceal bands',
#   'granularity',
#   'friability',
#   'erythema',
#   'congestion',
#   'abnormal vascularity',
#   'hydronephrosis',
#   'infarcts',
#   'ischemia',
#   'hypotension',
#   'cirrhosis',
#   'thrombocytopenia',
#   'alcoholic cirrhosis',
#   'acute alcoholic hepatitis 3',
#   'variceal bleed',
#   'acute renal failure',
#   'liver cirrhosis',
#   'variceal bleed',
#   'abdominal pain',
#   'bright red blood per rectum',
#   'melanotic stools'],
#  160707: ['normal pressure hydrocephalus',
#   'pancytopenia',
#   'develoepd fe overload',
#   'neutropenic fevers',
#   'dry dcough',
#   'watery eyes',
#   'cough',
#   'dyspnea',
#   'sore throat',
#   'ear pain',
#   'diarrhea',
#   'sweating',
#   'anemia',
#   'low platelet count',
#   'parenchymal edema',
#   'mass effect',
#   'cavernous carotid calcifications',
#   'left adrenal nodule',
#   'diverticulosis',
#   'cerebritis',
#   'pres',
#   'hygromas',
#   'subdural hematomas',
#   'cavitation',
#   'left adrenal gland lesion',
#   'focal wall motion abnormality',
#   'global free wall hypokinesis',
#   'mitral regurgitation',
#   'pericardial effusion',
#   'febrile neutropenia',
#   'renal failure',
#   'metabolic acidosis',
#   'worsening confusion',
#   'febrile',
#   'increased respiratory distress',
#   'renal failure',
#   'febrile',
#   'altered mental status',
#   'tachycardia',
#   'hypertension',
#   'hypoxia',
#   'hypotensive',
#   'shock liver',
#   'dic',
#   'pulseless electrical activity',
#   'pulseless electrical activity',
#   'sublingual prn chest pain'],
#  127356: ['respiratory distress',
#   'chest pain',
#   'respiratory distress',
#   'chest pain',
#   'abd pain',
#   'mast cell activation syndrome',
#   'holosyst murmur',
#   'edema',
#   'pneumothorax',
#   'mast cell degranulation syndrome',
#   'masth cell degranulation syndrome',
#   'erosive osteoarthritis',
#   'anemia',
#   'chest pain',
#   'nausea',
#   'vomiting',
#   'shortness of'],
#  103293: ['low platelets',
#   'low platelets',
#   'thrombocytopenia',
#   'malaise',
#   'dyspnea',
#   'melena',
#   'chills',
#   'headaches',
#   'sinus tenderness',
#   'rhinorrhea',
#   'congestion',
#   'palpitations',
#   'cough',
#   'wheezing',
#   'vomiting',
#   'diarrhea',
#   'constipation',
#   'abdominal pain',
#   'dysuria',
#   'arthralgias',
#   'myalgias',
#   'rashes',
#   'skin breakdown',
#   'excoriations',
#   'acute promyelocytic leukemia',
#   'tachycardia',
#   'dic',
#   'pulmonary edema',
#   'delirium',
#   'elevated bilirubin',
#   'tumor lysis syndrome',
#   'tls',
#   'dic',
#   'acute drops in fibrinogen',
#   'increase in ldh',
#   'increase in bilirubin',
#   'hypoxia',
#   'fluffy infiltrate',
#   'ards',
#   'subdural hematomas',
#   'decline in mental status',
#   'confusion',
#   'uremia',
#   'acute renal failure',
#   'autodiuresing',
#   'abdominal compartment syndrome',
#   'elevated bladder pressures',
#   'decreased urine output',
#   'tachycardia',
#   'coagulopathy',
#   'right sided basal ganglia infarct',
#   'neutropenic',
#   'pericardial effusion',
#   'anterior pericardial effusion',
#   'cirrhosis',
#   'cirrhosis',
#   'cirrhosis'],
#  178143: ['abdominal pain',
#   'vomiting',
#   'colostomy',
#   'abdominal pain',
#   'vomiting',
#   'chills',
#   'fevers',
#   'abdominal ct',
#   'hypoactive bowel sounds',
#   'jaundice',
#   'cyanosis',
#   'gross dermatitis',
#   'ecchymoses',
#   'abdominal pain',
#   'nausea',
#   'adhesions',
#   'gastroenteritis',
#   'cholecystitis',
#   'cholangitis',
#   'leukocytosis',
#   'possibile pneumobilia',
#   'biliary - enteric anastomosis',
#   'respiratory failure',
#   'blood loss',
#   'acute renal failure',
#   'vomiting',
#   'ostomy',
#   'ileus',
#   'pneumothorax',
#   'abdominal pain',
#   'small bowel obstruction',
#   'chest pain',
#   'pressure',
#   'vomiting',
#   'dehydrated',
#   'dry mouth',
#   'rapid heartbeat',
#   'shaking chills'],
#  160574: ['hypotension',
#   'renal failure',
#   'right knee pain',
#   'myalgias',
#   'fatigue',
#   'acute infarct',
#   'ica',
#   'renal failure',
#   'hypotension',
#   'r . sided back / leg pain',
#   'diffuse myalgias',
#   'hypotensive',
#   'diastolic chf',
#   'pancolitis',
#   'peptic ulcer disease',
#   'alcoholic cirrhosis',
#   'pulmonary embolus',
#   'cervical disc disease',
#   'neuro',
#   'polymorphonuclear leukocytes',
#   'hydronephrosis',
#   'foley catheter balloon',
#   'free pelvic fluid',
#   'abnormal pelvic or inguinal lymphadenopathy',
#   'pneumothorax',
#   'degenerative changes',
#   'spinal stenosis',
#   'discitis',
#   'osteomyelitis',
#   'discitis',
#   'osteomyelitis',
#   'spinal cord compression',
#   'marrow edema',
#   'compression fracture',
#   'discitis',
#   'osteomyelitis',
#   'discitis',
#   'osteomyelitis',
#   'right ventricular chamber size',
#   'trace aortic regurgitation',
#   'mitral valve prolapse',
#   'pericardial effusion',
#   'hemorrhage',
#   'pulmonary embolism',
#   'coronary artery calcifications',
#   'sinus tachycardia',
#   'inferior myocardial infarction',
#   'osteomyelitis',
#   'hypotension',
#   'fever',
#   'leukocytosis',
#   'hypotension',
#   'organ dysfunction',
#   'arf',
#   'abscess',
#   'diskitis',
#   'osteomyelitis',
#   'hypotension',
#   'cortisol stimulation',
#   'acute kidney injury',
#   'ckd',
#   'chest pressure',
#   'acute ischemic changes',
#   'hypotension',
#   'lantus',
#   'pancreatic insufficiency',
#   'mental status changes',
#   'hemorrhage',
#   'altered mental status',
#   'tia',
#   'pancreatic insufficieny',
#   'chest pains',
#   'fevers',
#   'shortness of breath',
#   'worsening leg pain',
#   'diarrhea'],
#  117156: ['brbpr',
#   'abdominal discomfort',
#   'gi bleed',
#   'clotty red bm',
#   'cp',
#   'edema',
#   'pulm edema',
#   'mesenteric ischemia',
#   'left renal hypodense cyst',
#   'colonic diverticulosis',
#   'small internal hemorrhoids',
#   'diverticulosis',
#   'internal hemorrhoids',
#   'diverticulum',
#   'cecum',
#   'gib',
#   'cp',
#   'gastrointestinal bleed',
#   'bloody bowel movements',
#   'chest pain',
#   'angina',
#   'hypotension',
#   'gi bleed',
#   'diabetes mellitus ii',
#   'oral hypoglycemics',
#   'gi bleed',
#   'hyperlipidemia',
#   'gastroesophageal reflux discharge'],
#  106939: ['allergies',
#   'abdominal pain',
#   'epigastric abdominal pain',
#   'abdominal pain',
#   'abdominal pain',
#   'vomiting',
#   'diarrhea',
#   'abdominal pain',
#   'transmetacarpal amputation',
#   'premature coronary artery disease',
#   'cavitary lesion',
#   'kidney lesions',
#   'plasmablastic lymphoma',
#   'opacification',
#   'ventricular septal defect',
#   'aortic regurgitation',
#   'mitral valve prolapse',
#   'mitral regurgitation',
#   'pulmonary artery systolic hypertension',
#   'pericardial effusion',
#   'tamponade',
#   'abdominal pain',
#   'hiv',
#   'plasmablastic lymphoma',
#   'tumor lysis syndrome',
#   'methemoglobinemia',
#   'bilateral inguninal herias',
#   'abdominal pain',
#   'fevers',
#   'chills',
#   'nausea',
#   'vomiting',
#   'diarrhea',
#   'abdominal pain',
#   'chest pain',
#   'shortness of breath'],
#  106064: ['lower back pain',
#   'urinary incontinence',
#   'chills',
#   'nausea',
#   'vomiting',
#   'cellulitis',
#   'furunculosis',
#   'discovertebral osteomyelitis',
#   'spinal stenosis',
#   'headache',
#   'chest pain',
#   'tightness',
#   'palpitations',
#   'abdominal pain',
#   'dysuria',
#   'myalgias',
#   'hepatitis c cirrhosis',
#   'cirrhosis',
#   'lymphadenopathy',
#   'ventral hernia',
#   'umbilical hernia',
#   'blood hbsag - negative',
#   'acute cardiopulmonary abnormality',
#   'nodular opacity',
#   'thrombocytopenia',
#   'arf',
#   'hypotension',
#   'thrombocytopenia',
#   'leukopenia',
#   'anemia',
#   'albicans',
#   'atn',
#   'thrombocytopenia',
#   'leukopenia',
#   'cbc',
#   'lfts',
#   'acute renal failure',
#   'uremic symptoms',
#   'thrombocytopenia',
#   'r conjunctival bleeding',
#   'renal dysfunction',
#   'thrombocytopenic',
#   'cirrhotic',
#   'bone marrow suppression',
#   'leukopenia',
#   'hypotensive',
#   'hypotensive episodes',
#   'left lateral thigh pain',
#   'bruise',
#   'lenis',
#   'acute left scrotal pain',
#   'r testicular lesion',
#   'testicular torsion',
#   'orchitis',
#   'acute kidney stone',
#   'inguinal hernia',
#   'testicular cystic lesion',
#   'hypoglycemic',
#   'gi bleeding',
#   'acute renal failure',
#   'hyponatremia',
#   'euvolemic',
#   'hypotension',
#   'pneumoboots',
#   'chills',
#   'chest pain',
#   'shortness of breath',
#   'severe back pain',
#   'increasing pain radiating down'],
#  104468: ['allergies',
#   'hypotension',
#   'anemia',
#   'hypotension',
#   'bradycardia',
#   'atrial flutter',
#   'gangrenous',
#   'atrial tachycardia',
#   'dementia',
#   'hypertension',
#   'lower back pain',
#   'osteoarthritis',
#   'anicteric sclera',
#   'bradycardia',
#   'hypotension',
#   'bradycardia',
#   'hypotensive',
#   'hypothyroidism',
#   'chest pain',
#   'palpatations',
#   'fainting',
#   'shortness of breath'],
#  109527: ['pancreatitis',
#   'pain s / p',
#   'fever',
#   'pancreatitis',
#   'multifocal pneumonia',
#   'pseudocyst',
#   'abscess',
#   'biliary duct dilation',
#   'pancreatic duct dilation',
#   'bilateral patchy infiltates',
#   'fever',
#   'chills',
#   'headache',
#   'sinus tenderness',
#   'rhinorrhea',
#   'congestion',
#   'cough',
#   'shortness of breath',
#   'wheezing',
#   'chest pain',
#   'chest pressure',
#   'palpitations',
#   'weakness',
#   'nausea',
#   'vomiting',
#   'diarrhea',
#   'abdominal pain',
#   'hypothyroidism',
#   'polymyositis',
#   'sclera anicteric',
#   'organomegaly',
#   'acute pancreatitis',
#   'abscess',
#   'pancreatic hemorrhage',
#   'necrosis',
#   'tiny left pleural effusions',
#   'ct',
#   'pericardial effusion',
#   'calcifications',
#   'bilateral pleural effusions',
#   'right lower lobe lung nodule',
#   'cardiomegaly',
#   'acute renal failure',
#   'hep b',
#   'rpr',
#   'afebrile',
#   'small lung nodule',
#   'maculo papular rash',
#   'rash',
#   'increased mediastinal lymphadenpathy',
#   'pancreatitis',
#   'pneumonia',
#   'pancreatitis',
#   'acute renal failure',
#   'fevers'],
#  114004: ['hematuria',
#   'brbpr',
#   'hematuria',
#   'dysuria',
#   'melena',
#   'abdominal pain',
#   'nausea',
#   'vomiting',
#   'hypotension',
#   'sinus 60 na',
#   'cystitis',
#   'headache',
#   'sinus tenderness',
#   'rhinorrhea',
#   'congestion',
#   'cough',
#   'shortness of breath',
#   'wheezing',
#   'chest pain',
#   'chest pressure',
#   'palpitations',
#   'weakness',
#   'nausea',
#   'vomiting',
#   'diarrhea',
#   'constipation',
#   'abdominal pain',
#   'sclera anicteric',
#   'pale conjunctiva',
#   'central pulmonary vascular engorgement',
#   'retroperitoneal hematoma',
#   'hypodense lesions',
#   'enlarged prostate',
#   'hematuria',
#   'ua',
#   'dysuria',
#   'qtc'],
#  143451: ['chest pain',
#   'labile',
#   'hypertension',
#   'coronary artery disase',
#   'ischemic cardiomyopathy',
#   'chest pain',
#   'vomiting',
#   'diarrhea',
#   'diaphoresis',
#   'joint pains',
#   'cough',
#   'hemoptysis',
#   'black stools',
#   'red stools',
#   'rigors',
#   'ankle edema',
#   'palpitations',
#   'syncope',
#   'sclera anicteric',
#   'pallor',
#   'xanthalesma',
#   'chest wall deformities',
#   'scoliosis',
#   'kyphosis',
#   'crackles',
#   'wheezes',
#   'rhonchi',
#   'abdominial bruits',
#   'xanthomas',
#   'left anterior fascicular block',
#   'sinus bradycardia',
#   'hypokinesis of the basal inferolateral wall',
#   'right ventricular chamber size',
#   'aortic stenosis',
#   'trace aortic regurgitation',
#   'mitral valve prolapse',
#   'mitral regurgitation',
#   'pericardial effusion',
#   'mitral regurgitation',
#   'mild pulmonary artery systolic hypertension',
#   'systemic arterial hypertension',
#   'chest pain',
#   'chest pain',
#   'glaucoma',
#   'chest pain',
#   'palpitations',
#   'shortness of breath',
#   'nausea',
#   'vomiting',
#   'fevers',
#   'chills'],
#  102629: ['chest pain',
#   'pain',
#   'substernal chest pain',
#   'chest pain',
#   'palpitations',
#   'syncope',
#   'multivessel disease',
#   'arthritis',
#   'kidney stones',
#   'premature coronary artery disease',
#   'cardiac death',
#   'edema',
#   'thrombus',
#   'pericardial effusion',
#   'thrombus',
#   'atheroma',
#   'aortic valve stenosis',
#   'aortic regurgitation',
#   'pericardial effusion',
#   'biventricular funtion',
#   'mediastinal widening',
#   'right basilar atelectasis',
#   'pneumothorax',
#   'small bowel dilation',
#   'hyperostosis of the lumbar spine',
#   'calcifications',
#   'small bowel dilation',
#   'chest pain',
#   'abdominal pain',
#   'nausea',
#   'abdominal distention',
#   'small bowel dilation',
#   'ileus',
#   'coronary artery disease',
#   'arthritis',
#   'kidney stones',
#   'erythema'],
#  130153: ['agitation anxiety', 'elopment'],
#  108949: ['diarrhea', 'pneumonia'],
#  115267: ['hypoxia',
#   'cognitive defects',
#   'sensitivities',
#   'erythematous skin reaction',
#   'resp distress',
#   'seizures',
#   'vision changes',
#   'rhinorrhea',
#   'congestion',
#   'sore throat',
#   'cough',
#   'shortness of breath',
#   'chest pain',
#   'abdominal pain',
#   'vomiting',
#   'diarrhea',
#   'constipation',
#   'brbpr',
#   'melena',
#   'hematochezia',
#   'dysuria',
#   'hematuria',
#   'multiple sclerosis',
#   'thyromegaly',
#   'heent - perrla',
#   'left temporal sharp features',
#   'seizures',
#   'seizures',
#   'worsening basilar atelectasis',
#   'large pleural effusion',
#   'pneumothorax',
#   'global atrophy',
#   'diffuse atrophy of the corpus callosum',
#   'large pleural effusions',
#   'pneumothorax',
#   'uti',
#   'seizures',
#   'central apenea',
#   'acidemia',
#   'central apnea',
#   'tachycardic',
#   'febrile',
#   'post - ictal state',
#   'apnea',
#   'hypercarbia',
#   'rash',
#   'red rash',
#   'facial swelling',
#   'airway obstruction',
#   'thrombocytopenia',
#   'rashes',
#   'urinary tract infection',
#   'seizures'],
#  168936: ['hypotension',
#   'rash',
#   'hypotension',
#   'total body itchiness',
#   'trunk and arm erythema',
#   'menigismus',
#   'cough',
#   'shortness of breath',
#   'dysuria',
#   'n / v / d',
#   'cellulitis',
#   'palpitations',
#   'dysuria',
#   'hypertension',
#   'hypothyroidism',
#   'gout',
#   'ascites',
#   'bil exophthalmus',
#   'nodule',
#   'patent portal veins',
#   'patent hepatic veins and artery',
#   'rash',
#   'hypotension',
#   'hypotension',
#   'fever',
#   'adrenal insuficiency',
#   'acute renal failure',
#   'morbilliform rash',
#   'anaphylactic shock',
#   'hepatocellular carcinoma',
#   'renal failure',
#   'hypothyroid',
#   'increased palpable right lower thyroid lobe',
#   'rash'],
#  185800: ['allergies',
#   'hypotension',
#   'osteoporosis',
#   'ovarian cysts',
#   'hypotensive',
#   'st depressions',
#   'hypotension',
#   'bradycardia',
#   'chest pain',
#   'sob',
#   'palpitations',
#   'lightheadedness',
#   'headache',
#   'hcv cirrhosis',
#   'giant cell arteritis',
#   'rales',
#   'organomegaly',
#   'edema',
#   'thyromegaly',
#   'carotid bruits',
#   'ascites',
#   'st depression',
#   'cardiac event',
#   'cardiac event',
#   'right ventricular chamber size',
#   'aortic valve stenosis',
#   'aortic regurgitation',
#   'mitral valve prolapse',
#   'pericardial effusion',
#   'bilateral basilar opacities',
#   'pneumothorax',
#   'pleural effusion',
#   'ostial lesion',
#   'intramyocardial segment of',
#   'athersclerosis',
#   'left ventricular diastolic heart failure',
#   'hypotensive',
#   'bradycardia',
#   'tachycardic',
#   'bradycardia',
#   'st depressions',
#   'coronary artery disease',
#   'jaundice',
#   'encephalopathy',
#   'ascites',
#   'esophageal varices',
#   'osteoporosis',
#   'hypotension',
#   'bradycardia'],
#  111882: ['sle',
#   'nephrotic syndrome',
#   'vomiting',
#   'diarrhea',
#   'shortness of breath',
#   'tachycardia',
#   'diarrhea',
#   'diarrhea',
#   'nausea',
#   'vomiting',
#   'dry heaves',
#   'worsening shortness of breath',
#   'pillow orthopnea',
#   'diarrhea',
#   'worsening systolic function',
#   'diarrhea',
#   'nausea',
#   'nausea',
#   'dry heaves',
#   'worsening shortness of breath',
#   'orthopnea',
#   'increased blood pressures',
#   'tachycardia',
#   'blood clot',
#   'nausea',
#   'vomiting',
#   'shortness for breath',
#   'orthopnea',
#   'diarrhea',
#   'palpitations',
#   'tingling',
#   'abdominal pain',
#   'constipation',
#   'hematemesis',
#   'hematochezia',
#   'pancytopenia',
#   'moon facies',
#   'malar rash',
#   'cva tenderness',
#   'hepatosplenomegaly',
#   'pitting edema',
#   'bibasilar effusions',
#   'increased hilar infiltrates',
#   'sinus tachycardia',
#   'atrial septal defect',
#   'masses',
#   'thrombi',
#   'ventricular septal defect',
#   'aortic valve stenosis',
#   'aortic regurgitation',
#   'mitral valve prolapse',
#   'mitral regurgitation',
#   'pericardial effusion',
#   'global left ventricular hypokinesis',
#   'right ventricular chamber size',
#   'aortic regurgitation',
#   'mitral valve prolapse',
#   'mitral regurgitation',
#   'pericardial effusion',
#   'left ventricular wall thicknesses',
#   'global left ventricular hypokinesis',
#   'right ventricular chamber size',
#   'aortic regurgitation',
#   'mitral valve prolapse',
#   'mitral regurgitation',
#   'tricuspid regurgitation',
#   'pulmonary artery systolic hypertension',
#   'pulmonic regurgitation',
#   'pericardial effusion',
#   'shortness of breath',
#   'tachycardia',
#   'cardiomyopathy',
#   'peripartum cardiomyopathy',
#   'pillow orthopnea',
#   'paroxysmal noctural dyspnea',
#   'throat tightness',
#   'membranous nephropathy',
#   'facial rash',
#   "sjogren ' s syndrome",
#   "raynaud ' s phenomenon",
#   'pleuritis',
#   'cardiomyopathy',
#   'renal failure',
#   'nausea',
#   'diarrhea',
#   'gut edema',
#   'thrombocytopenia',
#   'thrombocytopenia',
#   'platelet drop',
#   'thrombocytopenia',
#   'prothrombotic state',
#   'membranous nephropathy',
#   'lupus nephritis',
#   'worsening renal failure',
#   'joint pain',
#   'anemia',
#   'joint pain',
#   'wednesday - friday',
#   'cardiomyopathy',
#   'cardiomyopathy',
#   'heart failure'],
#  106361: ['cipro cystitis',
#   'hallucinations',
#   'lupus',
#   'vascular dementia',
#   'hallucinations',
#   'auditory hallucinations',
#   'insomnia',
#   'racing thoughts',
#   'rhinorrhea',
#   'abdominal pain',
#   'constipation',
#   'left shoulder pain',
#   'left knee pain',
#   'chest pain',
#   'nausea',
#   'vomiting',
#   'dysuria',
#   'head ct',
#   'neurologic symptoms',
#   'restrictive lung disease',
#   'discoid lupus erythematosus #',
#   'dementia',
#   'hiatal hernia',
#   'cellulitis',
#   'seizures',
#   'small bowel obstruction',
#   'crackles',
#   'edema',
#   'hyperpigmented macule',
#   'erythema',
#   'flat affect',
#   'blood lupus - neg',
#   'cardiomegaly',
#   'deep vein thrombosis',
#   'muscle edema',
#   'myonecrosis',
#   'small bone infarcts',
#   'coronary calcifications',
#   'aortic pathology',
#   'acute infarct',
#   'intracranial hemorrhage',
#   'mass lesion',
#   'generalized cerebral atrophy',
#   'hemorrhage',
#   'leg pain',
#   'hallucinations',
#   'delirium',
#   'stuporous',
#   'febrile',
#   'diaphoretic',
#   'svt',
#   'neuroleptic malignant syndrome',
#   'delirium',
#   'supraventricular tachycardia',
#   'svt',
#   'hypoxic',
#   'pulmomary edema',
#   'bone infarct',
#   'amyloidosis',
#   'myopathy',
#   'edema',
#   'ankle pain',
#   'erythemia',
#   'masked facies',
#   'shortness of breath',
#   'candidal rash',
#   'tid prn',
#   'hallucinations',
#   'altered mental status',
#   'shortness of breath',
#   'altered mental status',
#   'muscular side effects',
#   'hallucinations',
#   'altered mental status',
#   'shortness of breath',
#   'altered mental status',
#   'muscular side effects',
#   'hallucinations',
#   'altered mental status',
#   'shortness of breath',
#   'altered mental status',
#   'muscular side effects'],
#  166834: ['allergies',
#   'dysgerminoma of the right ovary',
#   'pelvic and para - aortic lymph node dissection',
#   'disgerminoma of the right ovary',
#   'torsion of the right ovary',
#   'disgerminoma of the ovary',
#   'disgerminoma',
#   'thromboembolic disorder',
#   'gerd',
#   'irregular menstrual cycles',
#   'thrush',
#   'mucositis',
#   'hepato',
#   'splenomegaly',
#   'cyanosis',
#   'edema',
#   'mass',
#   'orbital edema',
#   'extremity edema',
#   'pulmonary embolus',
#   'bilateral lower lobes',
#   'lingular atelectasis',
#   'tachycardia',
#   'tachycardic',
#   'hypercarbia',
#   'atelectasis',
#   'atelectasis',
#   'full neck',
#   'pulmonary embolism',
#   'bilateral peribronchovascular opacities',
#   'sinus tachycardia',
#   'sinus tachycardia',
#   'tachycardia',
#   'tachycardia',
#   'apiration pneumonia',
#   'afebrile',
#   'bibasilar opacities',
#   'nausea',
#   'nausea and vomiting',
#   'heavy vaginal bleeding',
#   'chest pain',
#   'trouble breathing',
#   'drowsy'],
#  150068: ['hypotension',
#   'hyperglycemia',
#   'increased leukocytosis',
#   'hyponatremia',
#   'hyperkalemia',
#   'lll consolidations'],
#  119069: ['allergies',
#   'nausea',
#   'vomiting',
#   'fatigue',
#   'left internal capsule stroke',
#   'left temporal grade',
#   'lethargic',
#   'aphasic',
#   'myopathy',
#   'urinary incontinence',
#   'emesis',
#   'right lower extremity dvt',
#   'chest pain',
#   'shortness of breath',
#   'syncopal episodes',
#   'progressive left peduncle herniation',
#   'aphasia 5',
#   'rale',
#   'rhonchi',
#   'edema bilaterlly',
#   'worsening vasogenic edema',
#   'midline shift',
#   'effacement of the ipsilateral lateral ventrical',
#   'myopathy',
#   'myopathy',
#   'edema',
#   'adenocarcinoma of the lung',
#   'cerebral vascular accident',
#   'mental status change weakness'],
#  131903: [],
#  113824: ['abscessed teeth',
#   'fever',
#   'cough',
#   'shortness of breath',
#   'abdominal pain',
#   'dysuria',
#   'stiff neck',
#   'pheresis',
#   'dyspnea',
#   'headache',
#   'osteopenia',
#   'myocardial infarction',
#   'petechiae',
#   'crackles',
#   'hepatosplenomgaly',
#   'petechiae',
#   'crackles',
#   'hepatosplenomgaly',
#   'blood smear',
#   'multiple nucleoli',
#   'rare granules',
#   'acute myelogeneous leukemia',
#   'typhlitis',
#   'neutropenic colitis',
#   'nodule',
#   'inflammatory fat stranding',
#   'neutropenic colitis',
#   'left lower lobe pulmonary nodule',
#   'low grade fever',
#   'dental abscess',
#   'anemia',
#   'thrombocytopenia',
#   'leukostasis',
#   'ischemic cva',
#   'hypotension',
#   'hypotension',
#   'dental abcess',
#   'leukemia cutis',
#   'rash',
#   'bowel wall thickening',
#   'edema',
#   'loose stools',
#   'pulmonary nodule',
#   'high white blood cell count',
#   'acute myelogenous leukemia',
#   'left facial droop',
#   'left arm weakness',
#   'neutropenic colitis',
#   'rash'],
#  100579: ['low - grade fever',
#   'pt',
#   'soft tissue stranding',
#   'soft tissue stranding',
#   'aortic insufficiency',
#   'escherichia coli',
#   'gynecomastia',
#   'bilateral pleural effusion',
#   'right lower lobe opacity',
#   'left retrocardiac atelectasis',
#   'cellulitis',
#   'allergic reaction'],
#  103926: ['chest pain',
#   'venous hemofiltration',
#   'anemia',
#   'angina',
#   'hemorrhoidal bleed',
#   'orthopnea',
#   'pnd',
#   'chest pain',
#   'myalgias',
#   'joint pains',
#   'cough',
#   'hemoptysis',
#   'black stools',
#   'rigors',
#   'orthopnea',
#   'palpitations',
#   'syncope',
#   'neuropathy',
#   'hyperparathyroidism',
#   'osteoarthritis #',
#   'anemia #',
#   'sclera anicteric',
#   'pallor',
#   'xanthalesma',
#   'chest wall deformities',
#   'scoliosis',
#   'kyphosis',
#   'external hemorrhoids',
#   'red blood',
#   'right femoral bruit',
#   'stasis dermatitis',
#   'ulcers',
#   'xanthomas',
#   'coronary artery disease',
#   'distal septal akinesis',
#   'apical hypokinesis',
#   'right ventricular chamber size',
#   'aortic stenosis',
#   'aortic regurgitation',
#   'mitral valve prolapse',
#   'mitral regurgitation',
#   'pericar dial effusion',
#   'regional left ventricular systolic dysfunction',
#   'mitral regurgitation',
#   'fibroid uterus',
#   'ct chest',
#   'ct abdomen',
#   'coronary calcifications',
#   'pericardial effusion',
#   'pneumothorax',
#   'fat density left adrenal lesion',
#   'degenerative changes',
#   'multifocal hemorrhage',
#   'hemorrhagic pneumonia',
#   'hemorrhage',
#   'coronary calcifications',
#   'nephropathy',
#   'bleeding cath',
#   'chest pain',
#   'rp bleed',
#   'gi bleed',
#   'ct chest',
#   'diffuse alveolar hemorrhage',
#   'diabetes mellitus',
#   'nephropathy',
#   'nephropathy',
#   'chest pain',
#   'shortness of breath'],
#  100922: ['foley',
#   'encephalopathy',
#   'portal vein thrombosis',
#   'chronic lymphedema',
#   'psorasis',
#   'allergic rhinitis',
#   'dysfunctional uterine bleeding',
#   'adnexal masses',
#   'staph epidermatis bactermia',
#   'auto - immune hepatitis',
#   'liver failure',
#   'scleral icterus',
#   'rales',
#   'organomegaly',
#   'dark urine',
#   'afb',
#   'afb',
#   'sinus tachycardia',
#   'r wave',
#   'portal vein thrombus',
#   'trace pleural effusions',
#   'renal stone',
#   'hydronephrosis',
#   'obstruction',
#   'consolidative airspace opacities',
#   'pulmonary edema',
#   'anemia',
#   'diffuse anasarca',
#   'distended ivc',
#   'blood loss',
#   'acute intracranial abnormality',
#   'abdominal ascites',
#   'carbapenemase - resistant e . coli',
#   'hepatorenal syndrome',
#   'thrombocytopenia',
#   'worsening coagulation',
#   'mia',
#   'hypernatremia',
#   'hypercalcemia',
#   'hypoxic respiratory failure',
#   'bloody secretions',
#   'disseminated intravascular coagulation',
#   'hepatic encephalopathy',
#   'fulminant hepatic failure',
#   'hypernatremia',
#   'hypercalcemia',
#   'autoimmune hepatitis',
#   'chronic lymphedema',
#   'psorasis',
#   'allergic rhinitis',
#   'dysfunctional uterine bleeding',
#   'adnexal masses'],
#  105778: ['hypotension',
#   'aortic stenosis',
#   'diastolic ventricular dysfunction',
#   'hypertensive',
#   'left leg pain',
#   'cramping',
#   'nausea',
#   'vomiting',
#   'abdominal pain',
#   'chest pain',
#   'orthopnea',
#   'ankle edema',
#   'palpitations',
#   'syncope',
#   'presyncope',
#   'calf cramping',
#   'stenosis',
#   'elevated systemic pressures',
#   'aortic stenosis',
#   'diastolic ventricular dysfunction',
#   'left axis deviation',
#   'left anterior fascicular block',
#   'right ventricular chamber size',
#   'aortic valve stenosis',
#   'aortic regurgitation',
#   'pericardial effusion',
#   'aortic stenosis',
#   'anginal symptoms',
#   'ecg changes',
#   'ectasia of the iliac arteries',
#   'bilateral renal cortical thinning',
#   'bilateral renal hypodensities',
#   'uterine calcifications',
#   'hypotension',
#   'hyperlipidemia',
#   'tylenol arthritis pain',
#   'hyperlipidemia',
#   'hypotension',
#   'chest pain',
#   'shortness of breath',
#   'lightheadedness'],
#  191162: ['allergies',
#   'dyspnea',
#   'methemoglobinemia',
#   'dysphagia',
#   'tracheal dilitation',
#   'dyspnea',
#   'chills',
#   'hypoxic',
#   'mia',
#   'reduction in methemeglobin',
#   'squamous cell carcinoma of the esophagus',
#   'tracheal compression',
#   'hypercalcemia',
#   'hypertension',
#   'metastatic colon cancer',
#   'soft tissue attenuation',
#   'right vocal cord paralysis',
#   'methemeglobinemia',
#   'methemeglobinemia',
#   'cough',
#   'difficulty breathing',
#   'talking',
#   'dysphagia',
#   'transient hypotension',
#   'hypovolemia',
#   'prerenal',
#   'diarrhea'],
#  124917: ['respiratory arrest',
#   'decreased rectal tone',
#   'acute intracranial process',
#   'small frontal subgaleal soft tissue hematoma',
#   'linear lucency',
#   'acute subluxation',
#   'diffuse ground - glass opacities',
#   'pleural effusion',
#   'pneumothorax',
#   'diffuse increased echotexture of the liver',
#   'cholecystitis',
#   'gallstones',
#   'respiratory failure',
#   'respiratory failure',
#   'muscular paralysis',
#   'hypoxic',
#   'streptococcus pneumoniae',
#   'groin and back erythema',
#   'diarrhea',
#   'hepatic steatosis',
#   'alcoholic pancreatitis',
#   'respiratory difficulty',
#   'pancreatitis'],
#  108901: ['allergies',
#   'altered mental status',
#   'unresponsiveness',
#   'tracheal laceration',
#   'pes',
#   'ams',
#   'unresponsiveness',
#   'pleural effusions',
#   'congestive heart failure',
#   'arthritis',
#   'odontoid fracture',
#   'hyperlipidemia',
#   'normocephalic',
#   'acute intracranial pathology',
#   'acute vascular territorial infarction',
#   'acute infarct',
#   'global parenchymal atrophy',
#   'vascular engorgement',
#   'respiratory distress',
#   'granulation tissue',
#   'left retrocardiac opcaity',
#   'increasing sputum',
#   'urine cx',
#   'esbl e . coli',
#   'altered mental status',
#   'hypotension',
#   'bradycardia',
#   'volume overload',
#   'c2 fracture'],
#  104107: ['coronary artery disease',
#   'critical aortic',
#   'thrombocytopenic purpura',
#   'coronary artery disease',
#   'aortic stenosis',
#   'hyperlipidemia',
#   'atrial fibrillation',
#   'pulmonary fibrosis',
#   'stenosis',
#   'stenosis',
#   'thrombocytopenia',
#   'splenomegaly',
#   'thrombocytopenia',
#   'chronic thrombocytopenia',
#   'atrial fibrillation'],
#  110342: ['allergies',
#   'hemoptysis',
#   'hemoptysis',
#   'fevers',
#   'malaise',
#   'chills',
#   'chest pain',
#   'palpitations',
#   'edema',
#   'orthopnea',
#   'vomiting',
#   'abdominal pain',
#   'abdominal swelling',
#   'diarrhea',
#   'constipation',
#   'hematemesis',
#   'hematochezia',
#   'rash',
#   'pruritus',
#   'myalgias',
#   'arthralgias',
#   'back pain',
#   'numbness of extremities',
#   'dizziness',
#   'lightheaded',
#   'vertigo',
#   'respiratory symptoms',
#   'scleral jaundice',
#   'multifocal airspace opacities',
#   'hemorrhage',
#   'calcified nodule',
#   'negative afbs',
#   'peribronchovascular opacities',
#   'vomited blood',
#   'black stools',
# ...
#   'redness'],
#  101215: ['dizziness',
#   'diaphoresis',
#   'premature coronary artery disease',
#   'focal hypokinesis of the apical free wall',
#   'aortic regurgitation',
#   'mitral regurgitation',
#   'bioprosthesis',
#   'valvular ai',
#   'renal arterial abnormality',
#   'subtotal arch',
#   'coagulopathic',
#   'worsening pericardial effusion',
#   'altered mental status',
#   'hypertensive',
#   'pneumonia',
#   'wound infection'],
#  117871: ['chest pain',
#   'chest pain',
#   'osteoarthritis',
#   'lumbar disc disease',
#   'hypercholesterolemia',
#   'thrombus',
#   'atrial septal defect',
#   'right ventricular chamber size',
#   'atheroma',
#   'aortic regurgitation',
#   'iabp',
#   'chest pain',
#   'right pneumothorax',
#   'right lung rexpanded',
#   'pleural effusion',
#   'coronary artery disease',
#   'hyperlipidemia'],
#  125867: [],
#  110068: ['maroon bowel movements',
#   'syncopal episode',
#   'gastric mass',
#   'vomiting',
#   'hematemesis',
#   'fever',
#   'chills',
#   'lightheadedness',
#   'chest pain',
#   'shortness of breath',
#   'vascular congestion',
#   'emphysema',
#   'cor pulmonale',
#   'duodenal',
#   'syncope',
#   'gi bleed',
#   'gastritis',
#   'ulcer in the posterior bulb',
#   'lung nodule',
#   'ct chest'],
#  127741: ['myalgia',
#   'cough',
#   'palpitations',
#   'parapneumonic effusion',
#   'anicteric sclerae',
#   'bronchial breath sounds',
#   'nystagmus',
#   'pneumonia',
#   'right pleural effusion',
#   'left base retrocardiac opacity',
#   'right pleural effusion',
#   'multilobar pneumonia',
#   'fever',
#   'shortness of breath',
#   'hypotension',
#   'palpitations',
#   'hemoptysis',
#   'blood streaked sputum',
#   'hemoptysis',
#   'multifocal pneumonia'],
#  190444: ['abdominal pain',
#   'esophageal ulcer',
#   'restless leg syndrome',
#   'abdominal pain',
#   'abdominal pain',
#   'non - bloody vomiting',
#   'nausea',
#   'pericholecystic fluid',
#   'sore throat',
#   'cough',
#   'sinus tenderness',
#   'fibromyalgia',
#   'spinal stenosis',
#   'osteoporosis',
#   'glaucoma',
#   'esophageal uler',
#   'hiatal hernia',
#   'dyslipidemia',
#   'atrophic gastritis',
#   'polymyalgia rheumatica',
#   'pulmonary fibrosis',
#   'pericardial effusion',
#   'constipation',
#   'anemia',
#   'hip arthritis',
#   'rotator cuff orthopathy',
#   'insomnia',
#   'cholecystitis',
#   'acute intracranial process',
#   'cholecystitis',
#   'thoracic compression fractures',
#   'acalculous cholecystitis',
#   'nausea',
#   'vomiting',
#   'abdominal pain',
#   'cholecystitis',
#   'abdominal pain',
#   'nausea',
#   'sepsis',
#   'acalculous cholecystitis',
#   'dilated gall bladder',
#   'downtrending white count',
#   'diarrhea',
#   'diarrhea',
#   'urinary retention',
#   'anxiety',
#   'restless leg syndrome',
#   'polymyalgia rheumatica',
#   'adrenal insufficiency'],
#  174037: ['cholelithiasis',
#   'acute pancreatitis',
#   'epigastric pain',
#   'abnormal lfts',
#   'alcoholic hepatitis',
#   'tremulousness',
#   'jaundiced',
#   'bilateral pleural effusions',
#   'icteric sclera',
#   'cervical lymphadenopathy',
#   'trachea',
#   'jaundiced',
#   'hemorrhagic pancreatitis',
#   'pancreatic ductal dilatation',
#   'acute intracranial hemorrhages',
#   'edema',
#   'masses',
#   'mass effect',
#   'intracranial abnormalities',
#   'hemorrhage',
#   'infarction',
#   'adipose accumulation',
#   'bilateral pleural effusions',
#   'narrowing of the splenic vein',
#   'peripancreatic phlegmon',
#   'focal wall motion abnormality',
#   'right ventricular chamber size',
#   'valvular aortic stenosis',
#   'increased stroke volume',
#   'aortic regurgitation',
#   'mitral valve prolapse',
#   'pulmonary artery systolic hypertension',
#   'hemorrhagic pancreatitis',
#   'pulmonary embolism',
#   'interval worsening',
#   'chest ct',
#   'acute severe hemorrhagic pancreatitis',
#   'pancreatitis',
#   'pancreatic necrosis',
#   'pancreatitis',
#   'necrotic pancreatitis',
#   'peripancreatic inflammation',
#   'acute lung injury',
#   'bilat pleural effusions',
#   'anasarca',
#   'ascites',
#   'pneumonia',
#   'altered mental status',
#   'diuresis',
#   'loculated left upper lobe effusion',
#   'bilateral pleural effusions',
#   'anterior loculated left pleural effusion',
#   'fevers',
#   'rigors',
#   'sweats',
#   'ct chest',
#   'cough',
#   'loculated left upper lobe effusion',
#   'left anterior loculated effusion',
#   'pulmonary edema',
#   'acute lung injury',
#   'interstitial changes',
#   'pleural effusions',
#   'diuresis',
#   'hypotension',
#   'nasal skin necrosis',
#   'ophthalmic prn',
#   'acute lung injury',
#   'lung infection',
#   'anemia'],
#  192877: ['inr',
#   'hypotensive',
#   'light - headedness',
#   'chest pain',
#   'eccymoses',
#   'cardiomegaly',
#   'elevation of right hemidiaphragm',
#   'small pleural effusion',
#   'congestive heart failure',
#   'chronic pleural thickening',
#   'right basilar atelectasis',
#   'bilateral pleural effusions',
#   'bibasilar atelectasis',
#   'pneumonia',
#   'cardiomegaly',
#   'kyphotic angulation',
#   'bleeding',
#   'bleeding',
#   'stroke',
#   'atrial fibrillation',
#   'rebleed',
#   'elevated potassium',
#   'hypotension',
#   'hypotension',
#   'shortness of breath',
#   'weight gain',
#   'bleeding',
#   'chest pain',
#   'fainting',
#   'swelling'],
#  186134: ['obstructed kidney stone',
#   'hydronephrosis',
#   'gallstone',
#   'tachycardic',
#   'right hydronephrosis',
#   'right renal perinephric stranding',
#   'arm rash',
#   'eyelid edema',
#   'dysuria',
#   'hematuria',
#   'allergic fungal sinusitis',
#   'polyps uterine fibroids',
#   'sclera anicteric',
#   'pettechiae',
#   'suprapubic tenderness',
#   'right cva',
#   'flank pain',
#   'kidney abscess',
#   'allergy',
#   'rash',
#   'acute renal failure',
#   'nephrolithiasis',
#   'fevers',
#   'dizziness',
#   'shortness of breath'],
#  175593: ['gi bleed',
#   'abdominal distension',
#   'lower abdominal pain',
#   'blood per rectum',
#   'diverticular disease',
#   'gastrohepatic lymph nodes',
#   'gastric distension',
#   'tachy',
#   'abd',
#   'carotid bruit',
#   'umbilical hernia',
#   'enlarged firm prostate',
#   'cyanosis',
#   'edema',
#   'rashes',
#   'nodules',
#   'buttock rash',
#   'malignancy',
#   'foley',
#   'bleeding',
#   'esophageal mass',
#   'anemia',
#   'increased shortness of breath',
#   'chest pain'],
#  151904: ['seizure',
#   'quadriplegia',
#   'unresponsiveness',
#   'seizures',
#   'tremmors of b / l ues',
#   'pinpoint pupils',
#   'chrohic le edema',
#   'headache',
#   'neck stiffness',
#   'shortness of breath',
#   'cough',
#   'dyspnea',
#   'wheezing',
#   'chest pain',
#   'chest pressure',
#   'palpitations',
#   'abdominal pain',
#   'diarrhea',
#   'bioccipital epileptogenic foci',
#   'retrocardiac opacity',
#   'right lung base opacity',
#   'large pleural effusion',
#   'pneumothorax',
#   'pulmonary edema',
#   'epileptiform discharges',
#   'hypotension',
#   'bradycardia',
#   'hypotensive',
#   'hypotension',
#   'increased vagal tone',
#   'increased vagal tone',
#   'low respiratory rate',
#   'increased bradycardia',
#   'metabolic encephalopathy',
#   'clonic movements',
#   'flat affect',
#   'encephalopathy',
#   'seizure',
#   'toxic / metabolic derangements',
#   'syringx',
#   'syringx',
#   'diffuse cervical spinal cord atrophy',
#   'ivc thrombi',
#   'neb prn',
#   'seizure activity',
#   'somnolence',
#   'uti'],
#  195784: ['allergies',
#   'cirrhosis',
#   'hepatocellular carcinoma',
#   'liver parenchyma',
#   'fibrosis',
#   'thrombus',
#   'respiratory variation',
#   'thrombus',
#   'fatty change',
#   'acute cellular rejection'],
#  123771: ['subcutaneous fat and soft tissue debridement',
#   'left lower back wound',
#   'left lower leg wound',
#   'hyperlipidemia',
#   'stellate laceration',
#   'soft tissue defects',
#   'foci of subcutaneous air',
#   'pleural effusion',
#   'pneumothorax',
#   'pleural effusions',
#   'oropharyngeal residue',
#   'bilateral mangled extremities',
#   'absent radial pulse',
#   'neuro',
#   'oozing open wounds',
#   'edema',
#   'foley',
#   'necrotizing soft tissue infection',
#   'vre',
#   'left lower medial calf wound',
#   'prn constipation',
#   'chest pain'],
#  120301: ['hypopharyngeal mass',
#   'cataracts',
#   'pancreatitis',
#   'lethargic',
#   'distress',
#   'sclera anicteric',
#   'wheezes',
#   'yellow bilious',
#   'scrotal erythema',
#   'edema',
#   'hyperdense secretions',
#   'patulous upper esophagus',
#   'hypopharyngeal mass',
#   'cervical lymphadenopathy',
#   'airway narrowing',
#   'ascending aortic dilation',
#   'calcified splenic artery aneurysm',
#   'ischemic changes',
#   'multifocal consolidations',
#   'pulmonary edema',
#   'bilateral pleural effusions',
#   'pneumothorax',
#   'acute intracranial process',
#   'left basal ganglia lacunes',
#   'cystic mass',
#   'bony sclerosis',
#   'bilateral retropharyngeal and right masticator space masses',
#   'suboptimal image quality',
#   'bilateral layering pleural effusions',
#   'deep venous thrombosis',
#   'deep venous thrombosis',
#   'deep venous thrombosis',
#   'thickening of the pretracheal soft tissues',
#   'right parapharyngeal cystic mass',
#   'hypopharyngeal mass',
#   'blurring of the fat planes of the anterior neck',
#   'enlarged lymph nodes',
#   'worsening pleural effusions',
#   'parenchymal opacities',
#   'parenchymal opacity',
#   'pneumothorax',
#   'pneumothoraces',
#   'pulmonary congestive pattern',
#   'pneumothorax',
#   'parenchymal opacities',
#   'pulmonary edema',
#   'mediastinal widening',
#   'pneumothorax',
#   'small right pleural effusion',
#   'pharyngeal mass',
#   'diarrhea',
#   'severe cytopenias',
#   'fever',
#   'hypotension',
#   'acute kidney injury',
#   'hypotension',
#   'electrolyte abnormalities',
#   'left facial droop',
#   'clot',
#   'bleeding',
#   'bleeding',
#   'hemoptysis',
#   'bleeding',
#   'aspiration pneumonia',
#   'hypernatremia',
#   'bleeding',
#   'cough',
#   'hypotension',
#   'tachycardia',
#   'fever',
#   'hypoxia',
#   'tachypnea',
#   'lll pneumonia',
#   'worsening infiltrate',
#   'prn',
#   'eye pain',
#   'filamentary keratopathy',
#   'bleeding',
#   'hemoptysis',
#   'bleeding',
#   'n / v',
#   'severe cytopenias',
#   'sepsis',
#   'cva',
#   'acute cva',
#   'left face drooping',
#   'pfo',
#   'trach bleed',
#   'trach bleeding',
#   'acute renal failure',
#   'diarrhea',
#   'thrombocytopenia',
#   'hypersplenism',
#   'anasarca',
#   'hypoalbuminemia',
#   'hypertensive urgency',
#   'nasal congestion',
#   'scrotal erythema',
#   'hypernatremia',
#   'hyponatremia',
#   'lethargy',
#   'prn scrotal irritation',
#   'eye pain',
#   'constipation',
#   'hypopharyngeal squamous cell carcinoma',
#   'thrombocytopenia',
#   'hypokalemia',
#   'diarrhea',
#   'arrhythmia',
#   'mucositis',
#   'pneumonia',
#   'neutropenia',
#   'anemia',
#   'acute kidney failure',
#   'hemorrhage',
#   'arrhythmia',
#   'squamous cell carcinoma',
#   'high blood sugars',
#   'fevers',
#   'pneumonia',
#   'difficulty breathing',
#   'bleeding',
#   'rash',
#   'friday',
#   'cough'],
#  111923: ['allergies',
#   'seizures',
#   'seizures',
#   'leukodystrophy',
#   'rightsided weakness',
#   'generalized tonic clonic seizure',
#   'head ct',
#   'lat seizure',
#   'leukodystrophy',
#   'cerebral leukodystrophy',
#   'depression',
#   'facial droop',
#   'urine mucous',
#   'acute intracranial process',
#   'atrophy',
#   'pneumothorax',
#   'atherosclerotic calcifications of the aortic knob',
#   'displaced rib fractures',
#   'right basal atelectasis',
#   'retrocardiac atelectasis',
#   'focal parenchymal opacities',
#   'gtc',
#   'atrophy',
#   'acute intracranial process',
#   'seizure',
#   'leukocytosis',
#   'seizures',
#   'seizures',
#   'bilateral aspiration pneumonias',
#   'bilateral aspiration pneumonias'],
#  114923: ['procardia',
#   'diverticulosis',
#   'hypertension',
#   'hyperlipidemia',
#   'chronic diastolic chf',
#   'lower abd cramps',
#   'dark colored stool',
#   'nausea',
#   'dizziness',
#   'abdominal pain',
#   'lower abdominal tenderness',
#   'dark red blood',
#   'visual changes',
#   'sore throat',
#   'chest pain',
#   'shortness of breath',
#   'nausea',
#   'vomiting',
#   'abdominal pain',
#   'constipation',
#   'pruritis',
#   'dysuria',
#   'skin changes',
#   'pruritis',
#   'osteoarthritis #',
#   'tenosynovitis #',
#   'angina',
#   'cva',
#   'right ventricular chamber size',
#   'aortic stenosis',
#   'trace aortic regurgitation',
#   'atrial fibrillation',
#   'tachycardia',
#   'red blood',
#   'diverticula',
#   'diverticulosis',
#   'bleeding lesion',
#   'bright red blood',
#   'ischemic colitis',
#   'diverticular disease',
#   'diverticular bleeds',
#   'rash',
#   'gi bleed',
#   'bleed',
#   'chills',
#   'trouble breathing',
#   'chest pain',
#   'nausea',
#   'vomiting',
#   'diverticulosis'],
#  130440: ['achiness',
#   'cerebral aneurysm',
#   'gastroesophageal reflux disease',
#   'hepatitis',
#   'fe deficient anemia',
#   'atrial fibrillation',
#   'hypotensive',
#   'bradycardic',
#   'rigors',
#   'lightheadedness',
#   'neck stiffness',
#   'cough',
#   'sputum production',
#   'diarrhea',
#   'abdominal pain',
#   'dysuria',
#   'fever hypotension',
#   'shock',
#   'neuroleptic malignant syndrome',
#   'serotonin syndrome',
#   'hypotension',
#   'bradycardia',
#   'cough',
#   'sob',
#   'wheeze',
#   'crackles',
#   'fecal incontinence',
#   'incontinence',
#   'bradycardia',
#   'pneumoboots',
#   'bowel reg',
#   'hypotension',
#   'low blood pressure',
#   'slow heart rate',
#   'low blood pressure',
#   'fecal incontinence',
#   'chest pain',
#   'shortness of breath',
#   'palpitations',
#   'weakness',
#   'dizzyness'],
#  118510: ['right posterior cul - de - sac cyst',
#   'left ovarian cysts',
#   'endometrial lesion',
#   'endometrial hyperplasia',
#   'endometrial polyps',
#   'submucosal fibroids',
#   'left ovarian cysts',
#   'endometrial polyp',
#   'pelvic pain',
#   'oligomenorrhea',
#   'pelvic pain',
#   'dyspareunia',
#   'bm',
#   'arrhythmia',
#   'depression',
#   'mitral valve prolapse',
#   'left adnexal masses',
#   'consumptive coagulopathy',
#   'afebrile',
#   'nausea',
#   'flatus',
#   'edema',
#   'diuresis',
#   'abnormal vaginal discharge'],
#  174150: ['allergies',
#   'shortness of breath',
#   'hypotensive',
#   'hypoxemic',
#   'non - bloody diarrhea',
#   'chills',
#   'abdominal pain',
#   'hypoxic',
#   'hypotensive',
#   'dizziness',
#   'cerebrovascular',
#   'coronary artery disease',
#   'cervical lymphadenopathy',
#   'expiratory wheezes',
#   'gallops',
#   'cyanosis',
#   'edema',
#   'multifocal consolidations',
#   'dehydration',
#   'pneumonia',
#   'pneumonia',
#   'pulmonary edema',
#   'diarrhea',
#   'diarrhea',
#   'diarrhea',
#   'hypotension',
#   'glucophage',
#   'edema',
#   'shortness of breath',
#   'fevers',
#   'chills',
#   'edema'],
#  107047: ['hypotension',
#   'subclavian cvl',
#   'neutropenia',
#   'hypotension',
#   'cough',
#   'chest pain',
#   'shortness of breath',
#   'dysuria',
#   'myalgias',
#   'abdominal pain',
#   'diarrhea',
#   'echocardiogram',
#   'lp',
#   "burkitt ' s lymphoma",
#   'neutropenia',
#   'fever',
#   'bacteremia',
#   'hypothyroidism',
#   'hyperlipidemia',
#   'staph bacteremia',
#   'enterobacter bacteremia',
#   'cirrhosis',
#   'anterograde amnesia',
#   'mucositis',
#   'sigmoid diverticulosis',
#   'distention of the stomach',
#   'acute pulmonary embolism',
#   'nodular opacity',
#   'mitral regurgitation',
#   'endocarditis',
#   'endocarditis',
#   'abnormal septal motion',
#   'dvt',
#   'hypotensive',
#   'leukosuppression',
#   "burkitt ' s lymphoma",
#   'lp',
#   'bacteremia',
#   'right shoulder and arm pain',
#   'right hand weakness',
#   'tachycardic',
#   'tachycardia',
#   'thrombocytopenic',
#   'clot',
#   "burkitt ' s lymphoma"],
#  115157: ['allergies',
#   'pvd',
#   'lightheadedness',
#   'shortness of breath',
#   'chest pain',
#   'palpitations',
#   'vomiting',
#   'sweating',
#   'left sided facial droop',
#   'left hemianopsia',
#   'facial droop',
#   'elevated cardiac enzymes',
#   'hypotensive',
#   'rectal was',
#   'aortic aneurysm',
#   'aortic dissection',
#   'subclavian steal',
#   'left ventricular mass',
#   'thrombus',
#   'ventricular septal defect',
#   'global free wall hypokinesis',
#   'aortic valve stenosis',
#   'aortic regurgitation',
#   'mitral regurgitation',
#   'pulmonary artery systolic hypertension',
#   'hematoma',
#   'dissection',
#   'mucocele',
#   'hyperdense right renal mass',
#   'acute intrathoracic',
#   'enlarged pretracheal lymph node',
#   'sepsis',
#   'hypovolemia',
#   'hypotension',
#   'hypotension',
#   'wall hypokinesis',
#   'apical akinesis',
#   'cardiogenic shock',
#   'lv thrombus',
#   'subclavian steal',
#   'renal failure',
#   'hypotension',
#   'worsened renal function',
#   'confusion',
#   'dysarthria',
#   'facial droop',
#   'toxic metabolic encephalopathy',
#   'tia',
#   'enlarged pretracheal lymph node',
#   'hyperdense right renal mass',
#   'low blood pressure',
#   'worsened kidney function',
#   'low blood pressure',
#   'tia',
#   'mucocele',
#   'hyperdense right renal mass',
#   'enlarged pretracheal lymph node']}

# %%
sample_id, raw, annotated = load_entry(dataset,0)

# %%
from a2_spanbert import extract_adv_names_truth

# %%
extract_adv_names_truth(annotated)
# Out:
# ['delerious', 'very confused', 'acute delerium']

# %%
len(certain_adv_entities[sample_id])
# Out:
# 75

# %%
print(raw)
# Out:
# Admission Date:  [**2112-10-6**]              Discharge Date:   [**2112-10-14**]
#
# Date of Birth:  [**2055-4-7**]             Sex:   F
#
# Service: SURGERY
#
# Allergies:
# Ativan
#
# Attending:[**First Name3 (LF) 2777**]
# Chief Complaint:
# Abdominal Pain
#
# Major Surgical or Invasive Procedure:
# [**2112-10-10**] Thoracic Endovascular Aortic Aneurysm Repair
#
#
# History of Present Illness:
# HPI: 57F heavy smoker with recent admission [**2112-10-1**] - [**2112-10-3**]
# with
# chest and abdominal pain and odynophagia who was found to have
# circumferential mural thrombus in the supra-renal aorta on cross
# sectional imaging. At that time the aortic pathology was though
# to be chronic. Ultimately, her pain resolved with the initiation
# of a PPI and GI cocktail, and was discharged home after a 3 day
# hospital stay. On [**10-6**] she again presented to an OSH with
# abdominal pain where a CT abdomen was done which showed an
# aortic
# dissection. She was emergently transferred to [**Hospital1 18**] where a CTA
# of the torso confirmed an aortic dissection of the descending
# thoracic aorta (at the level of the left pulmonary vein) to just
# below the takeoff of the celiac. At the time of presentation to
# [**Hospital1 18**] she was not complaining of any abdominal pain and her
# vascular exam was unchanged (palpable bilateral upper and lower
# extremity pulses).
# .
#
#
# Past Medical History:
# Sinusitis
#
# Past Surgical History:
# Lap CCY, Tubal Ligation
#
# Social History:
# Married to retired police officer, 5 children. Current [**1-25**] PPD
# smoker with > 30 yr smoking history. No alcohol or IVDA.
#
#
# Family History:
# 89yo father with CHF
#
# Physical Exam:
# Physical Exam:
# Alert and oriented x 3
# VS:BP 110' 70's         HR  70-80's       RR stable / AF
# Carotids: 2+, no bruits or JVD
# COR; S1 S2
# Resp: Lungs clear
# Abd: Soft, non tender / obese / (+ BM)
# Ext: Pulses:  palpable DP /PT bilaterally /Feet warm,  well
# perfused.  No open areas
# Incisions: CDI
# Wounds: Left Right groin puncture site: Dressing clean dry and
# intact. Soft, no hematoma or ecchymosis
# Lumbar drian site intact / no drainage / no fluctuance
#
#
# Pertinent Results:
# [**2112-10-6**] PORTABLE CHEST
# FINDINGS:  The heart size is within normal limits.  The
# mediastinal contours are prominent.  The lungs are clear of
# consolidation, although there is minimal bibasilar atelectasis.
# There is prominence of the central pulmonary vasculature as
# well.  There is no large pleural effusion or pneumothorax.
#
# IMPRESSION:  Mediastinal prominence may represent an unfolded
# aorta, although correlation with subsequent torso CTA performed
# on the same date is recommended; minimal pulmonary vascular
# congestion and bibasilar atelectasis.
#
# [**2112-10-6**] ct chest
# CT OF THE CHEST WITH CONTRAST:  The thyroid gland is normal and
# symmetric in appearance.  The trachea and central airways are
# patent to the segmental level.
#
# Extensive emphysema is seen throughout the upper lungs.
# Bibasilar atelectasis is noted.
#
# The esophagus is normal.  There is no axillary, mediastinal, or
# hilar
# lymphadenopathy.
#
# A small amount of pericardial fluid in the superior recess is of
# relative low attenuation but slightly above that of simple fluid
# (20-25 [**Doctor Last Name **]). Coronary calcification is noted.
#
# CT OF THE ABDOMEN WITH CONTRAST:  The liver is normal in
# attenuation without focal lesion or intra- or extra-hepatic
# biliary ductal dilatation.  The gallbladder is surgically
# absent.  The CBD is mildly prominent, compatible with
# post-cholecystectomy state, measuring 11 mm, probably due to
# prior cholecystectomy.  The pancreas, spleen, and right adrenal
# gland are normal.
#
# A 9 mm hypodensity in the left adrenal gland (2:99) is
# indeterminate on this study but unchanged.  A 6 mm hypodense
# focus in the interpolar region of the right kidney is too small
# to characterize.  There is no hydronephrosis.
#
# The stomach, small and large bowel appear unremarkable with the
# exception of sigmoid diverticula without active inflammatory
# changes.  A fat-containing ventral hernia is noted.  There is no
# mesenteric or retroperitoneal adenopathy.  There is no free air
# or free fluid in the abdomen.
#
# CT OF THE PELVIS WITH CONTRAST:  The bladder is densely filled
# with contrast.  From the prior study, the uterus and ovaries are
# unremarkable.  The rectum is normal.  There is no pelvic or
# inguinal adenopathy.  There is no free pelvic fluid.
#
# OSSEOUS STRUCTURES:  There is no lytic or sclerotic bony lesion
# concerning for osseous malignancy.  Minimal multilevel
# degenerative changes are seen in the spine.
#
# CTA:  Extensive high density thickening of the aortic wall
# involving the
# descending aorta, beginning at the level of the left subclavian
# artery and
# extending to the level just below the renal arteries is similar
# or slightly progressed from the previous examination of [**9-30**] and
# compatible with intramural hematoma.  A new frank type B
# dissection flap across the lumen begins at the level of the left
# pulmonary vein (2:47) and extends just to the level just beyond
# the celiac artery.  The celiac artery appears to fill off the
# false lumen, with the remainder of the intra-abdominal arteries
# filling off the true lumen.  Minimal intramural hematoma
# involves the proximal superior mesenteric artery.  Multiple
# areas of intramural contrast extravasation and/or ulceration are
# new along the upper descending aorta within the intramural
# hematoma, but above formation of the flap (2:25, 2:39, 2:38 and
# 2:101).  There are ulcerating Atherosclerotic plaques and patchy
# calcification along the lower
# descending thoracic aorta.
#
# Just beyond the origin of the left common carotid and left
# subclavian there is focal irregularity (2:6 and 2:5), which are
# likely related to plaque at a site of vessel tortuosity.
#
# Axial measurements of the aortic lumen measure up to 35 x 31 mm
# in axial
# dimensions along the proximal descending aorta. Along the upper
# ascending
# aorta measurements up to 37 x 34 mm correspond to slight
# ectasia.
#
# An aortic aneurysm is seen (2:139) at the level of the inferior
# mesenteric
# artery takeoff, measuring 2.7 cm, distinct from the dissection
# and consistent with an incidental finding.
#
# BONES: There are no suspicious lytic or blastic lesions.
#
# IMPRESSION:
#
# 1.  Type B aortic dissection extending from the level of the
# left pulmonary vein to just beyond the celiac artery with the
# celiac artery filling off the false lumen.  Minimal fluid in the
# superior pericardial recess is mildly hyperdense, so a
# hemorrhagic component is possible although apparent measured
# increase in attenuation may be technical in etiology.
#
# 2.  Distal infrarenal aortic aneurysm just above the [**Female First Name (un) 899**] takeoff
# measuring 2.7 cm; attention in follow-up imaging is recommended
# for surveillance.
#
# 3.  Indeterminate 9 mm hypodense left adrenal lesion, but most
# likely benign, although not fully characterized.  Attention in
# follow-up imaging surveillance is recommended; alternatively if
# further characterization is desired at this time or before
# follow-up imaging of the dissection, dedicated CT or MR protocol
# could be considered.
#
# 4.  Diverticulosis without evidence of active inflammation.
#
# 5.  Coronary artery calcifications.
#
# Preliminary findings were discussed with Dr. [**Last Name (STitle) **] by Dr.
# [**First Name (STitle) **] in person at 2231 at the time of discovery on [**2112-10-6**].
#
# [**2112-10-7**] CT HEAD
# FINDINGS:  There is no evidence of hemorrhage, edema, mass, mass
# effect, or infarction.  The ventricles and sulci are normal in
# size and configuration.  The basal cisterns appear patent and
# there is preservation of [**Doctor Last Name 352**]-white matter differentiation.
#
# No fracture is identified.  The visualized paranasal sinuses,
# mastoid air
# cells and middle ear cavities are clear.  The globes are
# unremarkable.
#
# CONCLUSION:  No evidence of hemorrhage, mass, mass effect, or
# acute
# infarction.
#
# [**2112-10-10**]:  CT CHEST/ ABD/ PELVIS :
# FINDINGS:
#
# CT CHEST:  The visualized portion of the thyroid is unremarkable
# in
# appearance. There are multiple subcentimeter nodules in
# bilateral breasts.  The trachea is midline.  The airways are
# patent to the subsegmental level.
#
# There is severe centrilobular emphysema throughout the lungs
# with apical
# predilection.  There is bibasilar atelectasis.  There are no
# effusions,
# nodules or pneumothorax.
#
# There is no supraclavicular, axillary, mediastinal or hilar
# lymphadenopathy.
#
# Pericardial fluid is again noted, but is slightly decreased in
# amount from previous examination.  Coronary artery calcification
# is noted.  The heart and great vessels are otherwise
# unremarkable in appearance.
#
# CT ABDOMEN:  The liver is homogeneous in appearance with no
# focal lesions
# without intrahepatic biliary duct dilatation.  The gallbladder
# is surgically absent and the CBD is prominent measuring 1.2 cm
# in diameter compatible with post-cholecystectomy.  The pancreas
# and spleen are unremarkable in appearance. The right adrenal
# gland is unremarkable in appearance.  There is a stable 9-mm
# hypodensity in the left adrenal gland, likely representing
# adenoma.  There is a stable 6-mm hypodensity in the interpolar
# region of the right kidney that is too small to fully
# characterize by CT examination, but likely representing a simple
# cyst.  Otherwise, bilateral kidneys present symmetric uptake and
# excretion of contrast without hydronephrosis, stones, worrisome
# lesions or perinephric abnormalities.
#
# The stomach, duodenum and small bowel are unremarkable in
# appearance with no focal wall thickening or obstruction noted.
# There are scattered diverticula throughout the large intestine,
# predominantly located in the sigmoid colon.  There is no
# mesenteric or retroperitoneal lymphadenopathy.  There is no free
# air or ascites within the abdomen.  There is a fat-containing
# ventral hernia as well as a small umbilical hernia.
#
# CT PELVIS:  The uterus and bilateral ovaries are unremarkable in
# appearance.  There is a small amount of air within the bladder,
# compatible with recent instrumentation.  There is no pelvic or
# inguinal lymphadenopathy.  There is no free pelvic fluid.
#
# OSSEOUS STRUCTURES:  Degenerative changes are noted throughout
# the spine.  There are no focal lesions in the visualized osseous
# structures concerning for malignancy.
#
# CTA:  Again noted is extensive high-density thickening of the
# aortic wall
# beginning proximally at the level of the left subclavian artery
# and extending to just inferior of the renal arteries as well as
# dissection flap, beginning at the level of the left pulmonary
# vein and extending just beyond the celiac artery.  The extent of
# dissection is stable; however, there is increased amount of
# hematoma within the false lumen at the level of the celiac
# artery which is narrowing the false lumen and presenting mass
# effect on the true lumen.  Despite the increased mass effect,
# the celiac artery has preserved flow and is filling off of the
# false lumen.  The SMA and [**Female First Name (un) 899**] are patent, receiving flow from
# the true lumen.  There are multiple areas of descending aorta
# ulceration as well as atherosclerotic plaques, which are stable
# from previous examination.  Maximum dimensions of the aortic
# lumen within the ascending aorta measures 4.0 x 3.7 cm and in
# the descending aorta 3.5 x 3.5 cm, representing slight ectasia.
# Again noted is a focal aortic aneurysm at
# the level of the [**Female First Name (un) 899**] measuring 2.7 cm.
#
# IMPRESSION:
# 1.  Type B aortic dissection extending from the level of the
# left pulmonary vein to just beyond the celiac artery with the
# celiac artery filling from the false lumen.  Extent of
# dissection is unchanged; however, there is increased amount of
# clot in the false lumen, narrowing the false lumen, presenting
# greater mass effect on the true lumen.  However, flow is
# preserved.
# 2.  Distal infrarenal aortic aneurysm at the level of the [**Female First Name (un) 899**].
# 3.  9 mm hypodense lesion in the left adrenal gland, most likely
# representing an adenoma.  Attention on followup imaging is
# recommended.
# 4.  Diverticulosis.
# 5.  Coronary artery calcifications as well as multiple
# ulcerative
# atherosclerotic plaques within the aorta.
# 6.  Fat-containing umbilical as well as ventral hernia.
# 7.  Small right interpolar renal hypodensity too small to fully
# characterize by CT, but likely representing a simple cyst.
# 8.  Extensive emphysema.
# 9.  Small focus of air within the bladder that could represent
# recent
# instrumentation or infection.  Clinical correlation is
# recommended.
#
#  [**2112-10-11**] CT Chest abd pelvis
# Final Report INDICATION:  57-year-old woman with known type B
# dissection status post repair presents with epigastric pain,
# evaluate for flow within the SMA and celiac.
#
# COMPARISON:  CTA torso [**2112-10-10**].
#
# TECHNIQUE:  Helical axial MDCT images were obtained from the
# chest, abdomen and pelvis after the administration of IV
# contrast in the arterial phase.  Multiplanar reformatted images
# were obtained in the sagittal and coronal planes.
#
# DOSE REPORT:  Total DLP [**2074**].98 mGy-cm.
#
# FINDINGS:
#
# CT OF THE CHEST:  The visualized portion of the thyroid is
# unremarkable. The trachea is midline.  The airways are patent to
# the subsegmental levels.  Severe emphysematic changes are noted
# in bilateral lungs.  Bilateral pleural effusions are new since
# most recent prior examination.  There is adjacent opacification
# which most likely represents compressive atelectasis; however,
# infectious process cannot be completely excluded.
#
# There is atherosclerotic calcification involving the coronary
# vessels.  There is no evidence of pericardial effusion.
# Mediastinal, axillary and hilar lymph nodes do not meet CT size
# criteria for pathology.
#
# The heart and great vessels are otherwise unremarkable in
# appearance.
#
# CT OF THE ABDOMEN:  The liver is homogenous in appearance
# without evidence of focal liver lesions.  There is no evidence
# of intrahepatic biliary dilation.  The patient is status post
# cholecystectomy.  The spleen, pancreas and right adrenal gland
# are unremarkable. 9 mm left adrenal nodule is unchanged from the
# prior examination.  Bilateral kidneys show no evidence of
# hydronephrosis.
#
# Retroperitoneal and mesenteric lymph nodes do not meet CT size
# criteria for pathology.  There is no free air or free fluid
# within the abdomen.
#
# CT OF THE PELVIS:  The bladder contains a Foley.  Air within the
# bladder
# likely represents instrumentation.  The uterus appears
# unremarkable.  There is evidence of sigmoid and descending colon
# diverticulosis without evidence of diverticulitis.
#
# Bilateral pelvic side wall lymph nodes do not meet CT size
# criteria for
# pathology.  Small fat-containing ventral hernia is noted.
#
# CTA:  Patient is status post repair of type B dissection with
# EVAR stent graft extending from the level of the left subclavian
# artery and to just inferior to the origin of the renal arteries.
#  The dissection appears to extend into the celiac
# trunk(301:104); it is difficult to say if this was present on
# the prior study. Both sides of the dissection flap, however
# appear perfused homogenously with patent celiac trunk.  The SMA
# and [**Female First Name (un) 899**] are patent.  Again noted are areas of aortic ulcerations
# as well as atherosclerotic plaques stable from the prior
# examination.  Maximum dimension of the aortic lumen within the
# ascending aorta measures 2.8 x 3.6 cm and the 3.1 x 3.1 cm
# within the descending aorta.  Again
# noted is a focal aortic aneurysmal morphology at the level of
# the [**Female First Name (un) 899**]
# measuring 2.7 cm (3:140 and 602b:47).
#
# 3D reformations generated in the imaging lab of the aorta and
# endovascular stent include 3D MIP and VR rotations, curved
# reformatted images, and 3D measurements (below). These were
# reviewed in the interpretation of this examination.
#
# Measurements:
# Aortic valve: 3.8 cm
# Aortic cusps: 4.4 cm
# Ascending aorta/[**MD Number(3) 26547**]: 4.0 cm
# Ascending aorta/Proximal arch: 3.6 cm
# Proximal descending thoracic aorta/Distal arch (stent lumen +
# aorta wall): 2.8 cm Maximum, descending thoracic aorta (stent
# lumen + aorta wall): 5.0 cm Abdominal aorta, celiac trunk (stent
# lumen + aorta wall): 2.8 cm Abdominal aorta, SMA (stent lumen +
# aorta wall): 2.8 cm
#
# IMPRESSION:
#
# 1.  Status post repair of type B aortic dissection with EVAR
# stent graft
# extending from the level of the left subclavian artery to just
# below the
# origin of the renal arteries.
# 2.  Distal infrarenal aortic aneurysm at the level of the [**Female First Name (un) 899**],
# unchanged.
# 3.  Dissection appears to extend into the celiac trunk. Both
# sides of the
# dissection flap demonstrate homogenous perfusion with patency of
# celiac trunk SMA and [**Female First Name (un) 899**].
# 4. Unchanged 9 mm right adrenal nodule.
# 5. Bilateral pleural effusions with adjacent compressive
# atelectasis new from the prior exam.
# 6. Ventral fat containing hernia.
#
# [**2112-10-13**] CXR
# Final Report
# CHEST RADIOGRAPH
#
# INDICATION:  Fever, evaluation for pneumothorax and line
# position.
#
# FINDINGS:  As compared to the previous radiograph from [**10-12**], [**2112**], the venous introduction sheath on the right has been
# changed to a right internal jugular vein catheter.  The signs
# indicative of bilateral parenchymal opacities at the lung bases,
# most likely fluid overload, have decreased in severity.  The
# size of the cardiac silhouette, including the aortic stent
# graft, is unchanged.
#
#
#
#
#
# Brief Hospital Course:
# On [**10-6**] the pt presented to an OSH with abdominal pain where a
# CT abdomen was done which showed an aortic dissection. She was
# transferred to [**Hospital1 18**] and had a confirmatory CTA.  She was
# admitted to the ICU for blood pressure control and serial
# abdominal exams.
#
# At the time of presentation to [**Hospital1 18**] she was not complaining of
# any abdominal pain and her vascular exam was unchanged (palpable
# bilateral upper and lower extremity pulses).  She was agitated
# while in the ICU and received Ativan to which she became
# delerious.  She was seen by psychiatry for acute delerium and
# they asked to hold ativan and to use Hadol for any agitation.
#
# She remained stable and the plan was to manage her medially.
# She was transferred to the VICU.  On the morning of [**2112-10-10**] she
# was complaining of upper abdominal pain and retro sternal pain.
# Her VS were stable at that pt as was her EKG.  On exam she
# looked slightly pale without diaphoresis.  Her distal pulses
# were all palpable at that time. She was sent for stat CTA and
# then sent to prep and hold where she was consented for TEVAR.
# It was noted on the CT that she had extension of her dissection
# with possible compressive thrombus.
#
# She underwent the procedure without complication. She was
# recovered in the VICU and did well.  Her diet and activity were
# advanced. She was voiding freely and tolerating an oral diet.
# She ambulated without assistance.  Her follow up appts were
# scheduled.  She was councelled to follow up with her PCP within
# two weeks.
#
#
# Medications on Admission:
# Preadmission medications listed are correct and complete.
# Information was obtained from  last discharge.
# 1. Omeprazole 40 mg PO DAILY
# 2. Donnatol 10 mL PO BID:PRN abdominal pain
# 3. Atorvastatin 20 mg PO DAILY
# 4. Aspirin 325 mg PO DAILY
# 5. DiCYCLOmine 10 mg PO QID
#
#
# Discharge Medications:
# 1. Aspirin EC 325 mg PO DAILY
# 2. Atorvastatin 20 mg PO DAILY
# 3. DiCYCLOmine 10 mg PO QID
# 4. Omeprazole 40 mg PO DAILY
# 5. Acetaminophen-Caff-Butalbital [**1-25**] TAB PO Q6H:PRN headache
# RX *butalbital-acetaminophen-caff 50 mg-325 mg-40 mg [**1-25**]
# tablet(s) by mouth q 4 hours Disp #*30 Tablet Refills:*0
# 6. Ciprofloxacin HCl 500 mg PO Q12H Duration: 7 Days
# RX *ciprofloxacin [Cipro] 500 mg 1 tablet(s) by mouth twice a
# day Disp #*14 Tablet Refills:*0
# 7. Metoprolol Tartrate 12.5 mg PO BID
# hold for SBP < 100, HR < 60
# RX *metoprolol tartrate 25 mg 0.5 (One half) tablet(s) by mouth
# twice a day Disp #*30 Tablet Refills:*0
# 8. Donnatol 10 mL PO BID:PRN abdominal pain
#
#
# Discharge Disposition:
# Home
#
# Discharge Diagnosis:
# Aortic Dissection / Type B
# Intramural Aortic Thrombus
# complicated urinary tract infection
# delerium / acute / medication reaction
# headache
#
#
# Discharge Condition:
# Mental Status: Clear and coherent.
# Level of Consciousness: Alert and interactive.
# Activity Status: Ambulatory - Independent.
#
#
# Discharge Instructions:
# You were admitted to the hospital with a Type B Aortic
# Dissection
# You underwent a Envovascular repair of this aneurysm without
# complication. You were found to have a urinary tract infection
# and were started on antibiotics for this.  You also had a
# reaction to ATIVAN that caused you to be very confused - This is
# now listed in our system as an allergy to avoid this reaction
# again.
#
# Division of Vascular and Endovascular Surgery
# Endovascular Abdominal Aortic Aneurysm (AAA) Discharge
# Instructions
#
# MEDICATIONS:
# ??????	Take Aspirin 325mg (enteric coated) once daily
# ??????	Do not stop Aspirin unless your Vascular Surgeon instructs you
# to do so.
# ??????	Continue all other medications you were taking before surgery,
# unless otherwise directed
# ??????	You make take Tylenol or prescribed pain medications for any
# post procedure pain or discomfort
#
# WHAT TO EXPECT AT HOME:
# It is normal to have slight swelling of the legs:
# ??????	Elevate your leg above the level of your heart (use [**2-26**]
# pillows or a recliner) every 2-3 hours throughout the day and at
# night
# ??????	Avoid prolonged periods of standing or sitting without your
# legs elevated
# It is normal to feel tired and have a decreased appetite, your
# appetite will return with time
# ??????	Drink plenty of fluids and eat small frequent meals
# ??????	It is important to eat nutritious food options (high fiber,
# lean meats, vegetables/fruits, low fat, low cholesterol) to
# maintain your strength and assist in wound healing
# ??????	To avoid constipation: eat a high fiber diet and use stool
# softener while taking pain medication
#
# ACTIVITIES:
# ??????	When you go home, you may walk and go up and down stairs
# ??????	You may shower (let the soapy water run over groin incision,
# rinse and pat dry)
# ??????	Your incision may be left uncovered, unless you have small
# amounts of drainage from the wound, then place a dry dressing or
# band aid over the area that is draining, as needed
# ??????	No heavy lifting, pushing or pulling (greater than 5 lbs) for
# 1 week (to allow groin puncture to heal)
# ??????	After 1 week, you may resume sexual activity
# ??????	After 1 week, gradually increase your activities and distance
# walked as you can tolerate
# ??????	No driving until you are no longer taking pain medications
#
# CALL THE OFFICE FOR: [**Telephone/Fax (1) 90383**]
# ??????	Numbness, coldness or pain in lower extremities
# ??????	Temperature greater than 101.5F for 24 hours
# ??????	New or increased drainage from incision or white, yellow or
# green drainage from incisions
# ??????	Bleeding from groin puncture site
#
# FOR SUDDEN, SEVERE BLEEDING OR SWELLING (Groin puncture site or
# incision)
# ??????	Lie down, keep leg straight and have someone apply firm
# pressure to area for 10 minutes. If bleeding stops, call
# vascular office. If bleeding does not stop, call 911 for
# transfer to closest Emergency Room.
#
#
# Followup Instructions:
# Dr. [**Last Name (STitle) **] would like to see you in the office in one
# months time - an appointment has been made for you - if you need
# to change the date/time, please call the office at [**Telephone/Fax (1) **]
# thank you
#
# Provider: [**Name10 (NameIs) **] SCAN Phone:[**Telephone/Fax (1) 590**] Date/Time:[**2112-11-14**] 1:15
# Provider: [**First Name11 (Name Pattern1) **] [**Last Name (NamePattern4) 3469**], MD Phone:[**Telephone/Fax (1) 2625**]
# Date/Time:[**2112-11-14**] 2:45
#
# As always, please call your primary care physician for an
# appointment to be seen in the next two weeks to inform and
# update them of your care. I attempted to make an appointment for
# you but the office was closed.  This is very improtant that you
# follow up.
# Name: ATTAR,[**Female First Name (un) **]
# Address: [**Last Name (un) 28705**], [**Location (un) 28706**],[**Numeric Identifier 28707**]
# Phone: [**Telephone/Fax (1) 24306**]
# Fax: [**Telephone/Fax (1) 75010**]
#
#
#
# Completed by:[**2112-10-14**]

# %%
for adv in certain_adv_entities[sample_id]:
    print(adv)
# Out:
# abdominal pain
# chest and abdominal pain
# odynophagia
# mediastinal contours
# bibasilar atelectasis
# prominence of the central pulmonary vasculature
# pneumothorax
# mediastinal prominence
# chest ct of the chest
# emphysema
# coronary calcification
# gallbladder
# cbd
# hydronephrosis
# sigmoid diverticula
# ventral hernia
# ulceration
# ulcerating atherosclerotic plaques
# focal irregularity
# ectasia
# aortic aneurysm
# hemorrhagic
# diverticulosis
# coronary artery calcifications
# hemorrhage
# edema
# mass
# mass effect
# infarction
# paranasal sinuses
# hemorrhage
# mass
# mass effect
# acute infarction
# bibasilar atelectasis
# effusions
# nodules
# pneumothorax
# pericardial fluid
# coronary artery calcification
# cbd
# diverticula
# ascites
# high - density thickening of the aortic wall
# hematoma
# descending aorta ulceration
# focal aortic aneurysm
# distal infrarenal aortic aneurysm
# diverticulosis
# coronary artery calcifications
# emphysema
# epigastric pain
# ct of the chest
# bilateral pleural effusions
# atherosclerotic calcification
# pericardial effusion
# left adrenal nodule
# hydronephrosis
# foley
# descending colon diverticulosis
# patent celiac trunk
# aortic ulcerations
# distal infrarenal aortic aneurysm
# right adrenal nodule
# delerious
# upper abdominal pain
# retro sternal pain
# compressive thrombus
# abdominal pain
# urinary tract infection
# constipation
# groin puncture
# numbness
# coldness
# pain

# %%
raw
# Out:
# "Admission Date:  [**2112-10-6**]              Discharge Date:   [**2112-10-14**]\n\nDate of Birth:  [**2055-4-7**]             Sex:   F\n\nService: SURGERY\n\nAllergies:\nAtivan\n\nAttending:[**First Name3 (LF) 2777**]\nChief Complaint:\nAbdominal Pain\n\nMajor Surgical or Invasive Procedure:\n[**2112-10-10**] Thoracic Endovascular Aortic Aneurysm Repair\n\n\nHistory of Present Illness:\nHPI: 57F heavy smoker with recent admission [**2112-10-1**] - [**2112-10-3**]\nwith\nchest and abdominal pain and odynophagia who was found to have\ncircumferential mural thrombus in the supra-renal aorta on cross\nsectional imaging. At that time the aortic pathology was though\nto be chronic. Ultimately, her pain resolved with the initiation\nof a PPI and GI cocktail, and was discharged home after a 3 day\nhospital stay. On [**10-6**] she again presented to an OSH with\nabdominal pain where a CT abdomen was done which showed an\naortic\ndissection. She was emergently transferred to [**Hospital1 18**] where a CTA\nof the torso confirmed an aortic dissection of the descending\nthoracic aorta (at the level of the left pulmonary vein) to just\nbelow the takeoff of the celiac. At the time of presentation to\n[**Hospital1 18**] she was not complaining of any abdominal pain and her\nvascular exam was unchanged (palpable bilateral upper and lower\nextremity pulses).\n.\n\n\nPast Medical History:\nSinusitis\n\nPast Surgical History:\nLap CCY, Tubal Ligation\n\nSocial History:\nMarried to retired police officer, 5 children. Current [**1-25**] PPD\nsmoker with > 30 yr smoking history. No alcohol or IVDA.\n\n\nFamily History:\n89yo father with CHF\n\nPhysical Exam:\nPhysical Exam:\nAlert and oriented x 3\nVS:BP 110' 70's         HR  70-80's       RR stable / AF\nCarotids: 2+, no bruits or JVD\nCOR; S1 S2\nResp: Lungs clear\nAbd: Soft, non tender / obese / (+ BM)\nExt: Pulses:  palpable DP /PT bilaterally /Feet warm,  well\nperfused.  No open areas\nIncisions: CDI\nWounds: Left Right groin puncture site: Dressing clean dry and\nintact. Soft, no hematoma or ecchymosis\nLumbar drian site intact / no drainage / no fluctuance\n\n\nPertinent Results:\n[**2112-10-6**] PORTABLE CHEST\nFINDINGS:  The heart size is within normal limits.  The\nmediastinal contours are prominent.  The lungs are clear of\nconsolidation, although there is minimal bibasilar atelectasis.\nThere is prominence of the central pulmonary vasculature as\nwell.  There is no large pleural effusion or pneumothorax.\n\nIMPRESSION:  Mediastinal prominence may represent an unfolded\naorta, although correlation with subsequent torso CTA performed\non the same date is recommended; minimal pulmonary vascular\ncongestion and bibasilar atelectasis.\n\n[**2112-10-6**] ct chest\nCT OF THE CHEST WITH CONTRAST:  The thyroid gland is normal and\nsymmetric in appearance.  The trachea and central airways are\npatent to the segmental level.\n\nExtensive emphysema is seen throughout the upper lungs.\nBibasilar atelectasis is noted.\n\nThe esophagus is normal.  There is no axillary, mediastinal, or\nhilar\nlymphadenopathy.\n\nA small amount of pericardial fluid in the superior recess is of\nrelative low attenuation but slightly above that of simple fluid\n(20-25 [**Doctor Last Name **]). Coronary calcification is noted.\n\nCT OF THE ABDOMEN WITH CONTRAST:  The liver is normal in\nattenuation without focal lesion or intra- or extra-hepatic\nbiliary ductal dilatation.  The gallbladder is surgically\nabsent.  The CBD is mildly prominent, compatible with\npost-cholecystectomy state, measuring 11 mm, probably due to\nprior cholecystectomy.  The pancreas, spleen, and right adrenal\ngland are normal.\n\nA 9 mm hypodensity in the left adrenal gland (2:99) is\nindeterminate on this study but unchanged.  A 6 mm hypodense\nfocus in the interpolar region of the right kidney is too small\nto characterize.  There is no hydronephrosis.\n\nThe stomach, small and large bowel appear unremarkable with the\nexception of sigmoid div ...
